# %% [markdown]
# # Infant resting state fMRI preprocessing
# This notebook contains preprocessing tailored to infant resting state fMRI collected in 5-8 month olds.
#
# The processing steps for the fMRI broadly include:
# * Slice-time correction
# * Rigid realignment
# * Co-registration to the sMRI (T2-weighted structural MRI)
# * Artifact detection:
#     - Motion
#     - Global intensity outliers
# * De-noising to remove:
#     - Component noise associated with white matter and CSF
#     - component noise associated with motion
#     - Censoring/scrubbing of individual volumes detected as artifacts in the previous step
#     - Frame-wise displacement
# * Bandpass filtering
# * Spatial smoothing
# * Registration to infant sample template

# %%
#import packages
from os import listdir, makedirs
from os.path import isdir
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, MapNode        # pypeline engine
from nipype.interfaces.nipy.preprocess import Trim

from nipype.algorithms.rapidart import ArtifactDetect
from nipype.interfaces.fsl.preprocess import SliceTimer, MCFLIRT, FLIRT, FAST, SUSAN
from nipype.interfaces.fsl.utils import Reorient2Std, MotionOutliers, Merge
from nipype.interfaces.fsl.model import GLM
from nipype.interfaces.fsl.maths import ApplyMask, TemporalFilter
from nipype.interfaces.freesurfer import Resample, Binarize, MRIConvert
from nipype.algorithms.confounds import CompCor
from nipype.interfaces.afni.preprocess import Bandpass
from nipype.interfaces.afni.utils import AFNItoNIFTI
from nipype.algorithms.misc import Gunzip
from pandas import DataFrame, Series

#set output file type for FSL to NIFTI
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# Set study variables
setup='myelin'

if setup == 'myelin':
    studyhome = '/Volumes/iang/active/BABIES/BABIES_rest'
    raw_data = studyhome + '/subjDir'
    output_dir = studyhome + '/processed/preproc'
    workflow_dir = studyhome + '/workflows'
    template_brain = studyhome + '/templates/T2w_BABIES_template_2mm.nii.gz'
    template_wm = studyhome + '/templates/BABIES_wm_mask_2mm.nii.gz'
    template_mask = studyhome + '/templates/T2w_BABIES_template_2mm_mask.nii.gz'

if setup == 'Lucy':
    studyhome = '/share/iang/active/BABIES/BABIES_rest/'
    raw_data = studyhome + '/subjDir/'
    output_dir = studyhome + '/processed/preproc'
    workflow_dir = studyhome + '/workflows'
    template_brain = studyhome + '/templates/T2w_BABIES_template_2mm.nii.gz'
    template_wm = studyhome + '/templates/BABIES_wm_mask_2mm.nii.gz'
    template_mask = studyhome + '/templates/T2w_BABIES_template_2mm_mask.nii.gz'
    
elif setup =='Cat':
    studyhome = '/Users/catcamacho/Box/SNAP/BABIES'
    raw_data = studyhome + '/raw'
    output_dir = studyhome + '/BABIES_rest/processed/preproc'
    workflow_dir = studyhome + '/BABIES_rest/workflows'
    template_brain = studyhome + '/templates/T2w_BABIES_template_2mm.nii.gz'
    template_wm = studyhome + '/templates/BABIES_wm_mask_2mm.nii.gz'
    template_mask = studyhome + '/templates/T2w_BABIES_template_2mm_mask.nii.gz'

subjects_list = open(studyhome + '/misc/all_subjects.txt').read().splitlines()
#subjects_list = ['sham1','sham2']

proc_cores = 2 # number of cores of processing for the workflows
vols_to_trim = 4
interleave = False
TR = 2.5 # in seconds
slice_dir = 3 # 1=x, 2=y, 3=z
resampled_voxel_size = (2,2,2)
fwhm = 4 #fwhm for smoothing with SUSAN

#changed to match Pendl et al 2017 (HBM)
highpass_freq = 0.08 #in Hz
lowpass_freq = 0.1 #in Hz

mask_erosion = 1
mask_dilation = 1

# %%
## File handling Nodes

# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)

# Datasink- where our select outputs will go
substitutions = [('_subject_id_', '')]
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
datasink.inputs.substitutions = substitutions

# Data grabber- select fMRI and sMRI
if setup=='myelin':
    anat_template = {'struct': raw_data + '/{subject_id}/skulstripped_anat.nii.gz'}
    select_anat = Node(SelectFiles(anat_template), name='selectanat')

    func_template = {'func': raw_data + '/{subject_id}/rest*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s/rest*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'],
                                   template_args={'func':[['subject_id']]}),
                       name='select_func') 

if setup=='Lucy':
    anat_template = {'struct': raw_data + '{subject_id}/skullstripped_anat.nii.gz'}
    select_anat = Node(SelectFiles(anat_template), name='selectanat')

    func_template = {'func': raw_data + '{subject_id}/rest*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '%s/rest*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'],
                                   template_args={'func':[['subject_id']]}),
                       name='select_func') 
    
elif setup=='Cat':
    anat_template = {'struct': raw_data + '/{subject_id}/skullstripped_anat.nii.gz'}
    select_anat = Node(SelectFiles(anat_template), name='selectanat')

    func_template = {'func': raw_data + '/%s/rest_raw*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s/rest_raw*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')

# %%
## struct processing
# reorient to standard
reorientstruct = Node(Reorient2Std(), name='reorientstruct')

# convert files to nifti
reslice_struct = Node(MRIConvert(out_type='niigz',
                                 conform_size=2,
                                 crop_size=(128, 128, 128),
                                ),
                   name='reslice_struct')
# Segment structural scan
segment = Node(FAST(no_bias=True, 
                    segments=True, 
                    number_classes=3), 
               name='segment')

# register BOLD to anat
coregT2 = Node(FLIRT(out_matrix_file='xform.mat'),
           name='coregT2')

# apply transform to func
applyT2xform = Node(FLIRT(apply_xfm=True),
                    name='applyT2xform')

# register anat to template
reg_temp = Node(FLIRT(reference=template_brain, 
                      out_matrix_file='xform.mat',
                      out_file='preproc_anat.nii.gz'),
                name='reg_temp')

# apply transform to func
applyxform = Node(FLIRT(reference=template_brain,
                        apply_xfm=True, 
                        out_file='preproc_func.nii.gz'),
                  name='applyxform')

# %%
def combine_fd(fd_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import asarray, savetxt
    
    motion = open(fd_list[0]).read().splitlines()

    if len(fd_list)>1:
        for file in fd_list[1:]:
            temp = open(file).read().splitlines()
            motion = motion+temp

    motion = asarray(motion).astype(float)
    filename = 'FD_full.txt'
    savetxt(filename,motion)
    combined_fd = abspath(filename)
    return(combined_fd)


def combine_par(par_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import vstack, savetxt, genfromtxt
    
    motion = genfromtxt(par_list[0], dtype=float)
    if len(par_list)>1:
        for file in par_list[1:]:
            temp = genfromtxt(par_list[0], dtype=float)
            motion=vstack((motion,temp))
    
    filename = 'motion.par'
    savetxt(filename, motion, delimiter=' ')
    combined_par = abspath(filename)
    return(combined_par)

# %%
# Data QC nodes
def create_coreg_plot(epi,anat):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    coreg_filename='coregistration.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'coregistration to anatomy')
    display.add_edges(anat)
    display.savefig(coreg_filename) 
    display.close()
    coreg_file = os.path.abspath(coreg_filename)
    
    return(coreg_file)

def check_mask_coverage(epi,brainmask):
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    from nipype.interfaces.nipy.preprocess import Trim
    
    trim = Trim()
    trim.inputs.in_file = epi
    trim.inputs.end_index = 1
    trim.inputs.out_file = 'epi_vol1.nii.gz'
    trim.run()
    epi_vol = abspath('epi_vol1.nii.gz')
    
    maskcheck_filename='maskcheck.png'
    display = plotting.plot_anat(epi_vol, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'brainmask coverage')
    display.add_contours(brainmask,levels=[.5], colors='r')
    display.savefig(maskcheck_filename)
    display.close()
    maskcheck_file = abspath(maskcheck_filename)

    return(maskcheck_file)

make_coreg_img = Node(Function(input_names=['epi','anat'],
                               output_names=['coreg_file'],
                               function=create_coreg_plot), name='make_coreg_img')

make_checkmask_img = Node(
    Function(input_names=['epi','brainmask'],
             output_names=['maskcheck_file'],
             function=check_mask_coverage), name='make_checkmask_img')
make_checkmask_img.inputs.brainmask = template_mask

# %%
## Nodes for func preprocessing

# Reorient to standard space using FSL
reorientfunc = MapNode(Reorient2Std(), name='reorientfunc', iterfield=['in_file'])

# Trim first 4 volumes
trimvols = MapNode(Trim(begin_index=vols_to_trim), name='trimvols', iterfield=['in_file'])

# Motion correction
motion_correct = MapNode(MCFLIRT(save_plots=True, mean_vol=True), name='motion_correct', iterfield=['in_file'])

# Get frame-wise displacement for each run: in_file; out_file, out_metric_plot, out_metric_values
get_FD = MapNode(MotionOutliers(metric = 'fd',
                                out_metric_values = 'FD.txt',
                                out_metric_plot = 'motionplot.png',
                                no_motion_correction=False,
                                threshold=0.01),
                    name='get_FD', iterfield=['in_file'])

# Merge rest
merge = Node(Merge(dimension='t'), name='merge')

# Merge motion (6 params)
comb_par = Node(Function(input_names=['par_list'],
                         output_names=['combined_par'],
                         function=combine_par), name='comb_par')

# Merge FD
comb_fd = Node(Function(input_names=['fd_list'],
                         output_names=['combined_fd'],
                         function=combine_fd), name='comb_fd')

# Rigid body realignment
realignment = Node(MCFLIRT(), name='realignment')

#Slice timing correction based on interleaved acquisition using FSL
slicetime_correct = Node(SliceTimer(interleaved=interleave, 
                                    slice_direction=slice_dir,
                                    time_repetition=TR, 
                                    out_file='st_func.nii.gz'),
                         name='slicetime_correct')

# unzip the nifti for ART
gunzip = Node(Gunzip(), name='gunzip')

# Artifact detection for scrubbing/motion assessment
art = Node(ArtifactDetect(mask_type='file',
                          parameter_source='FSL',
                          norm_threshold=0.25, #mutually exclusive with rotation and translation thresh
                          zintensity_threshold=2,
                          use_differences=[True, False], 
                          mask_file=template_mask),
           name='art')
# Out:
# 180811-12:36:22,335 nipype.interface WARNING:
# 	 Unable to import ['nipy']; Trim interface may fail to run

# %%
## Preprocessing Workflow

# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                    (node2,node3,[('node2output','node3input')])
#                    ])

preprocwf = Workflow(name='preprocwf')
preprocwf.connect([(infosource,select_func,[('subject_id','subject_id')]), 
                   (select_func,reorientfunc,[('func','in_file')]),
                   (reorientfunc,trimvols,[('out_file','in_file')]),
                   (trimvols,motion_correct,[('out_file','in_file')]),
                   (trimvols,get_FD,[('out_file','in_file')]),
                   (motion_correct,merge,[('out_file','in_files')]),
                   (merge,realignment,[('merged_file','in_file')]),
                   (realignment,slicetime_correct,[('out_file','in_file')]),
                   (get_FD,comb_fd,[('out_metric_values','fd_list')]),
                   (motion_correct,comb_par,[('par_file','par_list')]),
                   (comb_par,art,[('combined_par','realignment_parameters')]),
                   (applyxform,gunzip,[('out_file','in_file')]),
                   (gunzip,art,[('out_file','realigned_files')]),
                   
                   (infosource,select_anat,[('subject_id','subject_id')]),
                   (select_anat,reorientstruct,[('struct','in_file')]),
                   (reorientstruct,reslice_struct,[('out_file','in_file')]),
                   (reslice_struct,coregT2,[('out_file','reference')]),
                   (reslice_struct,applyT2xform,[('out_file','reference')]),
                   (reslice_struct,reg_temp,[('out_file','in_file')]),
                   (reg_temp,applyxform,[('out_matrix_file','in_matrix_file')]),
                   (slicetime_correct,coregT2,[('slice_time_corrected_file','in_file')]),
                   (slicetime_correct,applyT2xform,[('slice_time_corrected_file','in_file')]),
                   (coregT2,applyT2xform,[('out_matrix_file','in_matrix_file')]),
                   (applyT2xform, applyxform,[('out_file','in_file')]),
                   (reg_temp,segment,[('out_file','in_files')]),
                   
                   (coregT2,make_coreg_img,[('out_file','epi')]),
                   (applyxform,make_checkmask_img,[('out_file','epi')]),
                   (reslice_struct,make_coreg_img,[('out_file','anat')]),
                   
                   (applyxform, datasink, [('out_file','preproc_func')]),
                   (reg_temp, datasink,[('out_file','preproc_anat')]),
                   (comb_fd, datasink, [('combined_fd','FD_out_metric_values')]),
                   (comb_par,datasink,[('combined_par','motion_params')]),
                   (segment,datasink,[('tissue_class_files','tissue_class_files')]),
                   (art,datasink, [('plot_files','art_plot_files')]),
                   (art,datasink, [('outlier_files','vols_to_censor')]),
                   (make_checkmask_img,datasink,[('maskcheck_file','maskcheck_image')]),
                   (make_coreg_img,datasink,[('coreg_file','coreg_image')])                   
                  ])
preprocwf.base_dir = workflow_dir
preprocwf.write_graph(graph2use='flat')
preprocwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 180811-12:36:25,56 nipype.workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/graph.png (graph2use=flat, simple_form=True).
# 180811-12:36:25,176 nipype.workflow INFO:
# 	 Workflow preprocwf settings: ['check', 'execution', 'logging', 'monitoring']
# 180811-12:37:32,197 nipype.workflow INFO:
# 	 Running in parallel.
# 180811-12:37:32,260 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 114 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:37:32,496 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.selectanat" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1078-L-T3/selectanat".
# 180811-12:37:32,652 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:37:32,679 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.select_func" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1078-L-T3/select_func".
# 180811-12:37:32,713 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:37:34,265 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 112 jobs ready. Free memory (GB): 6.80/7.20, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.select_func
#                        * preprocwf.selectanat
# 180811-12:37:34,989 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 180811-12:37:35,3 nipype.workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
# 180811-12:37:35,729 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.selectanat".
# 180811-12:37:35,905 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.select_func".
# 180811-12:37:36,254 nipype.workflow INFO:
# 	 [Job 0] Completed (preprocwf.selectanat).
# 180811-12:37:36,259 nipype.workflow INFO:
# 	 [Job 5] Completed (preprocwf.select_func).
# 180811-12:37:36,272 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 114 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:37:36,674 nipype.workflow INFO:
# 	 [Job 1] Cached (preprocwf.reorientstruct).
# 180811-12:37:37,27 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.selectanat" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1057-L-T3/selectanat".
# 180811-12:37:38,279 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 114 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.selectanat
# 180811-12:37:38,690 nipype.workflow INFO:
# 	 [Job 2] Cached (preprocwf.reslice_struct).
# 180811-12:37:39,416 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 180811-12:37:40,114 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.selectanat".
# 180811-12:37:40,271 nipype.workflow INFO:
# 	 [Job 23] Completed (preprocwf.selectanat).
# 180811-12:37:40,282 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 115 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:37:40,669 nipype.workflow INFO:
# 	 [Job 3] Cached (preprocwf.reg_temp).
# 180811-12:37:40,780 nipype.workflow INFO:
# 	 [Job 24] Cached (preprocwf.reorientstruct).
# 180811-12:37:42,626 nipype.workflow INFO:
# 	 [Job 4] Cached (preprocwf.segment).
# 180811-12:37:42,842 nipype.workflow INFO:
# 	 [Job 25] Cached (preprocwf.reslice_struct).
# 180811-12:37:44,287 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 114 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:37:44,699 nipype.workflow INFO:
# 	 [Job 26] Cached (preprocwf.reg_temp).
# 180811-12:37:44,775 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:37:44,780 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.select_func" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1057-L-T3/select_func".
# 180811-12:37:44,801 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:37:46,280 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 113 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.select_func
# 180811-12:37:46,633 nipype.workflow INFO:
# 	 [Job 27] Cached (preprocwf.segment).
# 180811-12:37:46,651 nipype.workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
# 180811-12:37:47,391 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.select_func".
# 180811-12:37:48,274 nipype.workflow INFO:
# 	 [Job 28] Completed (preprocwf.select_func).
# 180811-12:37:48,283 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 113 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:37:48,717 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.selectanat" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/selectanat".
# 180811-12:37:48,789 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:37:48,796 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.select_func" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/select_func".
# 180811-12:37:48,816 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:37:50,283 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 112 jobs ready. Free memory (GB): 6.80/7.20, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.select_func
#                        * preprocwf.selectanat
# 180811-12:37:51,42 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 180811-12:37:51,194 nipype.workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
# 180811-12:37:51,734 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.selectanat".
# 180811-12:37:51,980 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.select_func".
# 180811-12:37:52,288 nipype.workflow INFO:
# 	 [Job 46] Completed (preprocwf.selectanat).
# 180811-12:37:52,297 nipype.workflow INFO:
# 	 [Job 51] Completed (preprocwf.select_func).
# 180811-12:37:52,314 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 114 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:37:52,591 nipype.workflow INFO:
# 	 [Job 47] Cached (preprocwf.reorientstruct).
# 180811-12:37:52,683 nipype.workflow INFO:
# 	 [Job 52] Cached (preprocwf.reorientfunc).
# 180811-12:37:54,556 nipype.workflow INFO:
# 	 [Job 48] Cached (preprocwf.reslice_struct).
# 180811-12:37:54,839 nipype.workflow INFO:
# 	 [Job 53] Cached (preprocwf.trimvols).
# 180811-12:37:56,293 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 115 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:37:56,619 nipype.workflow INFO:
# 	 [Job 49] Cached (preprocwf.reg_temp).
# 180811-12:37:56,933 nipype.workflow INFO:
# 	 [Job 54] Cached (preprocwf.get_FD).
# 180811-12:37:58,701 nipype.workflow INFO:
# 	 [Job 50] Cached (preprocwf.segment).
# 180811-12:37:59,31 nipype.workflow INFO:
# 	 [Job 55] Cached (preprocwf.comb_fd).
# 180811-12:38:00,297 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 113 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:38:00,452 nipype.workflow INFO:
# 	 [Job 56] Cached (preprocwf.motion_correct).
# 180811-12:38:00,541 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.selectanat" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/selectanat".
# 180811-12:38:02,304 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 113 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.selectanat
# 180811-12:38:02,664 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 180811-12:38:02,827 nipype.workflow INFO:
# 	 [Job 57] Cached (preprocwf.comb_par).
# 180811-12:38:03,395 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.selectanat".
# 180811-12:38:04,296 nipype.workflow INFO:
# 	 [Job 69] Completed (preprocwf.selectanat).
# 180811-12:38:04,306 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 113 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:38:04,621 nipype.workflow INFO:
# 	 [Job 58] Cached (preprocwf.merge).
# 180811-12:38:04,752 nipype.workflow INFO:
# 	 [Job 70] Cached (preprocwf.reorientstruct).
# 180811-12:38:06,846 nipype.workflow INFO:
# 	 [Job 59] Cached (preprocwf.realignment).
# 180811-12:38:07,71 nipype.workflow INFO:
# 	 [Job 71] Cached (preprocwf.reslice_struct).
# 180811-12:38:08,685 nipype.workflow INFO:
# 	 [Job 60] Cached (preprocwf.slicetime_correct).
# 180811-12:38:08,914 nipype.workflow INFO:
# 	 [Job 72] Cached (preprocwf.reg_temp).
# 180811-12:38:10,613 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.coregT2" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/coregT2".
# 180811-12:38:10,914 nipype.workflow INFO:
# 	 [Job 73] Cached (preprocwf.segment).
# 180811-12:38:11,874 nipype.workflow INFO:
# 	 [Node] Running "coregT2" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/slicetime_correct/st_func.nii.gz -ref /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz -out st_func_flirt.nii.gz -omat xform.mat
# 180811-12:38:12,316 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 111 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.coregT2
# 180811-12:38:12,544 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:38:12,550 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.select_func" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/select_func".
# 180811-12:38:12,573 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.select_func".
# 180811-12:38:14,316 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 110 jobs ready. Free memory (GB): 6.80/7.20, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.select_func
#                        * preprocwf.coregT2
# 180811-12:38:15,75 nipype.workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
# 180811-12:38:15,911 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.select_func".
# 180811-12:38:16,314 nipype.workflow INFO:
# 	 [Job 74] Completed (preprocwf.select_func).
# 180811-12:38:16,330 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 111 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.coregT2
# 180811-12:38:16,580 nipype.workflow INFO:
# 	 [Job 75] Cached (preprocwf.reorientfunc).
# 180811-12:38:18,731 nipype.workflow INFO:
# 	 [Job 76] Cached (preprocwf.trimvols).
# 180811-12:38:20,327 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 112 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.coregT2
# 180811-12:38:20,809 nipype.workflow INFO:
# 	 [Job 77] Cached (preprocwf.get_FD).
# 180811-12:38:24,185 nipype.workflow INFO:
# 	 [Job 78] Cached (preprocwf.comb_fd).
# 180811-12:38:24,330 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 111 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.coregT2
# 180811-12:38:24,496 nipype.workflow INFO:
# 	 [Job 79] Cached (preprocwf.motion_correct).
# 180811-12:38:25,369 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.coregT2".
# 180811-12:38:26,330 nipype.workflow INFO:
# 	 [Job 61] Completed (preprocwf.coregT2).
# 180811-12:38:26,339 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 114 jobs ready. Free memory (GB): 7.20/7.20, Free processors: 2/2.
# 180811-12:38:26,582 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.make_coreg_img".
# 180811-12:38:26,585 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.make_coreg_img" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/make_coreg_img".
# 180811-12:38:26,608 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.make_coreg_img".
# 180811-12:38:26,830 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.applyT2xform".
# 180811-12:38:26,836 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.applyT2xform" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/applyT2xform".
# 180811-12:38:26,856 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.applyT2xform".
# 180811-12:38:28,338 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 112 jobs ready. Free memory (GB): 6.80/7.20, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.applyT2xform
#                        * preprocwf.make_coreg_img
# 180811-12:38:29,661 nipype.workflow INFO:
# 	 [Node] Running "make_coreg_img" ("nipype.interfaces.utility.wrappers.Function")
# 180811-12:38:30,20 nipype.workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/make_coreg_img/result_make_coreg_img.pklz
# 180811-12:38:30,26 nipype.workflow WARNING:
# 	 [Node] Error on "preprocwf.make_coreg_img" (/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/make_coreg_img)
# 180811-12:38:30,332 nipype.workflow DEBUG:
# 	 Aggregate: False
# 180811-12:38:30,393 nipype.workflow INFO:
# 	 [Node] Running "applyT2xform" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/slicetime_correct/st_func.nii.gz -ref /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz -out st_func_flirt.nii.gz -omat st_func_flirt.mat -applyxfm -init /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1037-L-T3/coregT2/xform.mat
# 180811-12:38:32,994 nipype.workflow ERROR:
# 	 Node make_coreg_img.a54 failed to run on host Lucindas-MacBook-Pro.local.
# 180811-12:38:32,996 nipype.workflow ERROR:
# 	 Saving crash info to /Users/lucindasisk/Dropbox/Github/infant_rest/crash-20180811-123832-lucindasisk-make_coreg_img.a54-cffa0083-c1a5-4116-91de-063a39c6c58c.pklz
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/multiproc.py", line 69, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 480, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 564, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 644, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 521, in run
#     runtime = self._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/utility/wrappers.py", line 144, in _run_interface
#     out = function_handle(**args)
#   File "<string>", line 6, in create_coreg_plot
# ModuleNotFoundError: No module named 'nilearn'
#
# 180811-12:38:33,8 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 112 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.applyT2xform
# 180811-12:38:34,919 nipype.workflow INFO:
# 	 [Job 80] Cached (preprocwf.comb_par).
# 180811-12:38:34,938 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 111 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.applyT2xform
# 180811-12:38:35,596 nipype.workflow INFO:
# 	 [Job 81] Cached (preprocwf.merge).
# 180811-12:38:37,819 nipype.workflow INFO:
# 	 [Job 82] Cached (preprocwf.realignment).
# 180811-12:38:39,547 nipype.workflow INFO:
# 	 [Job 83] Cached (preprocwf.slicetime_correct).
# 180811-12:38:41,645 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.coregT2" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2".
# 180811-12:38:41,689 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2".
# 180811-12:38:41,694 nipype.utils DEBUG:
# 	 Removing contents of /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2
# 180811-12:38:41,699 nipype.utils DEBUG:
# 	 Creating directory /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2
# 180811-12:38:42,382 nipype.utils DEBUG:
# 	 Creating directory /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/_report
# 180811-12:38:42,588 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/_report/report.rst"
# 180811-12:38:42,939 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 110 jobs ready. Free memory (GB): 6.80/7.20, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.coregT2
#                        * preprocwf.applyT2xform
# 180811-12:38:45,112 nipype.workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180811-12:38:45,119 nipype.interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/slicetime_correct/st_func.nii.gz
# 180811-12:38:45,126 nipype.interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 180811-12:38:45,132 nipype.interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180811-12:38:45,147 nipype.interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz
# 180811-12:38:46,13 nipype.workflow INFO:
# 	 [Node] Running "coregT2" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/slicetime_correct/st_func.nii.gz -ref /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz -out st_func_flirt.nii.gz -omat xform.mat
# 180811-12:38:46,20 nipype.interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/slicetime_correct/st_func.nii.gz
# 180811-12:38:46,27 nipype.interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 180811-12:38:46,35 nipype.interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180811-12:38:46,42 nipype.interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz
# 180811-12:39:08,976 nipype.workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/st_func_flirt.nii.gz;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.hdr;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.img;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.mat;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.nii;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.mat;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/_0x515b3ee6efd6a259ffbdfbdca63685e1_unfinished.json;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/command.txt;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/_node.pklz
# 180811-12:39:08,981 nipype.workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/_report
# 180811-12:39:09,105 nipype.workflow DEBUG:
# 	 Removing files:
# 180811-12:39:09,486 nipype.workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/result_coregT2.pklz
# 180811-12:39:09,891 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/_report/report.rst"
# 180811-12:39:10,73 nipype.workflow DEBUG:
# 	 Aggregate: False
# 180811-12:39:10,386 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.coregT2".
# 180811-12:39:10,959 nipype.workflow INFO:
# 	 [Job 84] Completed (preprocwf.coregT2).
# 180811-12:39:10,969 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 112 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.applyT2xform
# 180811-12:39:11,771 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.make_coreg_img".
# 180811-12:39:11,775 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.make_coreg_img" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img".
# 180811-12:39:11,817 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('anat', ('/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz', '3ce89060f85628b0d4e581a9706272c2')), ('epi', ('/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/st_func_flirt.nii.gz', '68609ba5f17ed6315ab7cc2a1b0a89ec')), ('function_str', "def create_coreg_plot(epi,anat):\n    import os\n    from nipype import config, logging\n    config.enable_debug_mode()\n    logging.update_logging(config)\n    from nilearn import plotting\n\n    coreg_filename='coregistration.png'\n    display = plotting.plot_anat(epi, display_mode='ortho',\n                                 draw_cross=False,\n                                 title = 'coregistration to anatomy')\n    display.add_edges(anat)\n    display.savefig(coreg_filename) \n    display.close()\n    coreg_file = os.path.abspath(coreg_filename)\n\n    return(coreg_file)\n"), ('needed_outputs', ['coreg_file'])], b7f76bc3201fa39ed96e12604feb471f, /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img/_0xb7f76bc3201fa39ed96e12604feb471f.json, ['/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img/_0x0693ea729bfae5e6daf3ba267d3498fc.json']
# 180811-12:39:11,822 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.make_coreg_img".
# 180811-12:39:11,828 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = 0693ea729bfae5e6daf3ba267d3498fc/b7f76bc3201fa39ed96e12604feb471f
# 180811-12:39:12,304 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * epi: ('/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/st_func_flirt.nii.gz', '68609ba5f17ed6315ab7cc2a1b0a89ec') != ['/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT1/st_func_flirt.nii.gz', '0ad5abfcadc44c0e27dab9b60a7f57ba']
#             * function_str: "def create_coreg_plot(epi,anat):\n    import os\n    from nipype import config, logging\n    config.enable_debug_mode()\n    logging.update_logging(config)\n    from nilearn import plotting\n\n    coreg_filename='coregistration.png'\n    display = plotting.plot_anat(epi, display_mode='ortho',\n                                 draw_cross=False,\n                                 title = 'coregistration to anatomy')\n    display.add_edges(anat)\n    display.savefig(coreg_filename) \n    display.close()\n    coreg_file = os.path.abspath(coreg_filename)\n\n    return(coreg_file)\n" != "def create_coreg_plot(epi,anat):\n    import os\n    from nipype import config, logging\n    config.enable_debug_mode()\n    logging.update_logging(config)\n    from nilearn import plotting\n\n    coreg_filename='coregistration.png'\n    display = plotting.plot_anat(epi, display_mode='ortho',\n                                 draw_cross=False,\n                                 title = 'coregistration to anatomy')\n    display.add_edges(anat)\n    display.savefig(coreg_filename)\n    display.close()\n    coreg_file = os.path.abspath(coreg_filename)\n\n    return(coreg_file)\n"
# 180811-12:39:12,472 nipype.utils DEBUG:
# 	 Removing contents of /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img
# 180811-12:39:12,974 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 111 jobs ready. Free memory (GB): 6.80/7.20, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.make_coreg_img
#                        * preprocwf.applyT2xform
# 180811-12:39:17,65 nipype.utils DEBUG:
# 	 Creating directory /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img/_report
# 180811-12:39:17,430 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img/_report/report.rst"
# 180811-12:39:19,582 nipype.workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180811-12:39:19,586 nipype.workflow INFO:
# 	 [Node] Running "make_coreg_img" ("nipype.interfaces.utility.wrappers.Function")
# 180811-12:39:20,109 nipype.workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img/result_make_coreg_img.pklz
# 180811-12:39:20,114 nipype.workflow WARNING:
# 	 [Node] Error on "preprocwf.make_coreg_img" (/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/make_coreg_img)
# 180811-12:39:20,390 nipype.workflow DEBUG:
# 	 Aggregate: False
# 180811-12:39:21,710 nipype.workflow ERROR:
# 	 Node make_coreg_img.a53 failed to run on host Lucindas-MacBook-Pro.local.
# 180811-12:39:21,713 nipype.workflow ERROR:
# 	 Saving crash info to /Users/lucindasisk/Dropbox/Github/infant_rest/crash-20180811-123921-lucindasisk-make_coreg_img.a53-53e04542-4c4c-4d88-a270-24b58a584719.pklz
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/multiproc.py", line 69, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 480, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 564, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 644, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 521, in run
#     runtime = self._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/utility/wrappers.py", line 144, in _run_interface
#     out = function_handle(**args)
#   File "<string>", line 6, in create_coreg_plot
# ModuleNotFoundError: No module named 'nilearn'
#
# 180811-12:39:21,722 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 111 jobs ready. Free memory (GB): 7.00/7.20, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.applyT2xform
# 180811-12:39:22,803 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.applyT2xform".
# 180811-12:39:22,810 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.applyT2xform" in "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/applyT2xform".
# 180811-12:39:22,877 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('apply_xfm', True), ('in_file', ('/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/slicetime_correct/st_func.nii.gz', '6adbea0eedfd5dd78c04c934b16c93e7')), ('in_matrix_file', ('/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.mat', 'd269d3b1d1e598c6e393bd383a9200f7')), ('output_type', 'NIFTI_GZ'), ('reference', ('/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz', '3ce89060f85628b0d4e581a9706272c2')), ('needed_outputs', ['out_file'])], 3271277d0a895954931f93ee9c25c1cf, /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/applyT2xform/_0x3271277d0a895954931f93ee9c25c1cf.json, ['/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/applyT2xform/_0x044966da37ebb9533777225b69599dbe.json']
# 180811-12:39:22,884 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preprocwf.applyT2xform".
# 180811-12:39:22,890 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = 044966da37ebb9533777225b69599dbe/3271277d0a895954931f93ee9c25c1cf
# 180811-12:39:22,997 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 110 jobs ready. Free memory (GB): 6.80/7.20, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.applyT2xform
#                        * preprocwf.applyT2xform
# 180811-12:39:23,209 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * in_matrix_file: ('/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.mat', 'd269d3b1d1e598c6e393bd383a9200f7') != ['/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT1/xform.mat', 'd905cca20efc8368233027b3b7b9cd39']
# 180811-12:39:23,364 nipype.utils DEBUG:
# 	 Removing contents of /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/applyT2xform
# 180811-12:39:27,278 nipype.utils DEBUG:
# 	 Creating directory /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/applyT2xform/_report
# 180811-12:39:27,506 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/applyT2xform/_report/report.rst"
# 180811-12:39:30,148 nipype.workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180811-12:39:30,168 nipype.interface DEBUG:
# 	 apply_xfm_True
# 180811-12:39:30,178 nipype.interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/slicetime_correct/st_func.nii.gz
# 180811-12:39:30,188 nipype.interface DEBUG:
# 	 in_matrix_file_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.mat
# 180811-12:39:30,194 nipype.interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 180811-12:39:30,198 nipype.interface DEBUG:
# 	 out_matrix_file_st_func_flirt.mat
# 180811-12:39:30,205 nipype.interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz
# 180811-12:39:30,512 nipype.workflow INFO:
# 	 [Node] Running "applyT2xform" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/slicetime_correct/st_func.nii.gz -ref /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz -out st_func_flirt.nii.gz -omat st_func_flirt.mat -applyxfm -init /Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.mat
# 180811-12:39:30,521 nipype.interface DEBUG:
# 	 apply_xfm_True
# 180811-12:39:30,526 nipype.interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/slicetime_correct/st_func.nii.gz
# 180811-12:39:30,531 nipype.interface DEBUG:
# 	 in_matrix_file_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/coregT2/xform.mat
# 180811-12:39:30,537 nipype.interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 180811-12:39:30,541 nipype.interface DEBUG:
# 	 out_matrix_file_st_func_flirt.mat
# 180811-12:39:30,548 nipype.interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_1036-L-T3/reslice_struct/skulstripped_anat_reoriented_out.nii.gz

# %%
# Resting state preprocessing
# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)


# Data grabber- select fMRI and sMRI
templates = {'func': output_dir + '/preproc_func/{subject_id}/preproc_func.nii.gz',
             'csf': output_dir + '/tissue_class_files/{subject_id}/preproc_anat_seg_0.nii.gz', 
             'vols_to_censor':output_dir + '/vols_to_censor/{subject_id}/art.preproc_func_outliers.txt', 
             'motion_params':output_dir + '/FD_out_metric_values/{subject_id}/FD_full.txt',
             'wm':template_wm}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# %%
## Pull motion info for all subjects

motion_df_file = output_dir + '/motion_summary/motionSummary.csv'

if isdir(output_dir + '/motion_summary')==False:
    makedirs(output_dir + '/motion_summary')
    motion_df = DataFrame(columns=['meanFD','maxFD','NumCensoredVols','totalVolumes','secondsNotCensored','lengthsNotCensored_descendingSeconds'])
    motion_df.to_csv(motion_df_file)
    
def summarize_motion(motion_df_file, motion_file, vols_to_censor, TR):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import dirname, basename
    from numpy import asarray, mean, insert, zeros, sort
    from pandas import DataFrame, Series, read_csv
    
    motion_df = read_csv(motion_df_file, index_col=0)
    
    motion = asarray(open(motion_file).read().splitlines()).astype(float)
    censvols = asarray(open(vols_to_censor).read().splitlines()).astype(int)
    sec_not_censored = (len(motion)-len(censvols))*TR
    
    if censvols[0]>0:
        periods_not_censored = insert(censvols,0,0)
    else:
        periods_not_censored = censvols
    
    if periods_not_censored[-1]<len(motion):
        periods_not_censored = insert(periods_not_censored,len(periods_not_censored),len(motion))
    
    lengths = zeros(len(periods_not_censored)-1)
    for a in range(0,len(lengths)):
        lengths[a] = periods_not_censored[a+1] - periods_not_censored[a] - 1
    
    lengths = lengths*TR
    
    # sort lengths in descending order
    lengths = sort(lengths)[::-1]

    fp = dirname(motion_file)
    subject = basename(fp)

    motion_df.loc[subject] = [mean(motion),max(motion),len(censvols),len(motion),sec_not_censored,lengths]
    motion_df.to_csv(motion_df_file)

    return()

# Make a list of tissues for component noise removal
def combine_masks(mask1,mask2):
    from nipype.interfaces.fsl.utils import Merge
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    vols = []
    vols.append(mask1)
    vols.append(mask2)
    
    return(vols)
    
# Remove all noise (GLM with noise params)
def create_noise_matrix(vols_to_censor,motion_params,comp_noise):
    from numpy import genfromtxt, zeros,concatenate, savetxt
    from os import path

    motion = genfromtxt(motion_params, delimiter=' ', dtype=None, skip_header=0)
    comp_noise = genfromtxt(comp_noise, delimiter='\t', dtype=None, skip_header=1)
    censor_vol_list = genfromtxt(vols_to_censor, delimiter='\t', dtype=None, skip_header=0)

    c = len(censor_vol_list)
    d = len(comp_noise)
    if c > 0:
        scrubbing = zeros((d,c),dtype=int)
        for t in range(0,c):
            scrubbing[censor_vol_list[t]][t] = 1    
        noise_matrix = concatenate([motion[:,None],comp_noise,scrubbing],axis=1)
    else:
        noise_matrix = concatenate((motion[:,None],comp_noise),axis=1)

    noise_file = 'noise_matrix.txt'
    savetxt(noise_file, noise_matrix, delimiter='\t')
    noise_filepath = path.abspath(noise_file)
    
    return(noise_filepath)

def convertafni(in_file):
    from nipype.interfaces.afni.utils import AFNItoNIFTI
    from os import path
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    cvt = AFNItoNIFTI()
    cvt.inputs.in_file = in_file
    cvt.inputs.out_file = 'func_filtered.nii.gz'
    cvt.run()
    
    out_file = path.abspath('func_filtered.nii.gz')
    return(out_file)

# Brightness threshold should be 0.75 * the contrast between the median brain intensity and the background
def brightthresh(func):
    import nibabel as nib
    from numpy import median, where
    
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    func_nifti1 = nib.load(func)
    func_data = func_nifti1.get_data()
    func_data = func_data.astype(float)
    
    brain_values = where(func_data > 0)
    median_thresh = median(brain_values)
    bright_thresh = 0.75 * median_thresh
    
    return(bright_thresh)

# %%
# Denoising
merge_confs = Node(Function(input_names=['mask1','mask2'],
                            output_names=['vols'], 
                            function=combine_masks), 
                   name='merge_confs')

compcor = Node(CompCor(merge_method='none'), 
               name='compcor')

noise_mat = Node(Function(input_names=['vols_to_censor','motion_params','comp_noise'],
                          output_names=['noise_filepath'], 
                          function=create_noise_matrix), 
                 name='noise_mat')

denoise = Node(GLM(out_res_name='denoised_residuals.nii.gz', 
                   out_data_name='denoised_func.nii.gz'), 
               name='denoise')

# band pass filtering- all rates are in Hz (1/TR or samples/second)
bandpass = Node(Bandpass(highpass=highpass_freq,
                         lowpass=lowpass_freq), 
                name='bandpass')

afni_convert = Node(Function(input_names=['in_file'],
                             output_names=['out_file'],
                             function=convertafni), 
                    name='afni_convert')

# Spatial smoothing 
brightthresh_filt = Node(Function(input_names=['func'], 
                                  output_names=['bright_thresh'], 
                                  function=brightthresh), 
                         name='brightthresh_filt')    
    
smooth_filt = Node(SUSAN(fwhm=fwhm), name='smooth_filt')

motion_summary = Node(Function(input_names=['motion_df_file','motion_file','vols_to_censor'], 
                               output_names=[], 
                               function=summarize_motion), 
                      name='motion_summary')
motion_summary.inputs.motion_df_file = motion_df_file

# %%
# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                       (node2,node3,[('node2output','node3input')])
#                     ])

rs_procwf = Workflow(name='rs_procwf')
rs_procwf.connect([(infosource,selectfiles,[('subject_id','subject_id')]),
                   (selectfiles,compcor,[('func','realigned_file')]),
                   (selectfiles,merge_confs,[('csf','mask1')]),
                   (selectfiles,merge_confs,[('wm','mask2')]),
                   (merge_confs,compcor,[('vols','mask_files')]),
                   (compcor,noise_mat,[('components_file','comp_noise')]),
                   (selectfiles,noise_mat,[('vols_to_censor','vols_to_censor'),
                                           ('motion_params','motion_params')]),
                   (noise_mat,denoise,[('noise_filepath','design')]),
                   (selectfiles,denoise,[('func','in_file')]),
                   (denoise,bandpass,[('out_data','in_file')]),
                   (bandpass,afni_convert,[('out_file','in_file')]),
                   (afni_convert,brightthresh_filt,[('out_file','func')]),
                   (brightthresh_filt,smooth_filt,[('bright_thresh','brightness_threshold')]),
                   (afni_convert,smooth_filt,[('out_file','in_file')]),  
                   (selectfiles, motion_summary, [('motion_params','motion_file'),
                                                  ('vols_to_censor','vols_to_censor')]),
                   
                   (smooth_filt,datasink,[('smoothed_file','proc_func')])
                   ])

rs_procwf.base_dir = workflow_dir
rs_procwf.write_graph(graph2use='flat')
rs_procwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
