# %% [markdown]
# # Infant resting state fMRI preprocessing
# This notebook contains preprocessing tailored to infant resting state fMRI collected in 5-8 month olds.
#
# The processing steps for the fMRI broadly include:
# * Slice-time correction
# * Rigid realignment
# * Co-registration to the sMRI (T2-weighted structural MRI)
# * Artifact detection:
#     - Motion
#     - Global intensity outliers
# * De-noising to remove:
#     - Component noise associated with white matter and CSF
#     - component noise associated with motion
#     - Censoring/scrubbing of individual volumes detected as artifacts in the previous step
#     - Frame-wise displacement
# * Bandpass filtering
# * Spatial smoothing
# * Registration to infant sample template

# %%
#import packages
from os import listdir, makedirs
from os.path import isdir
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, MapNode        # pypeline engine
from nipype.interfaces.nipy.preprocess import Trim

from nipype.algorithms.rapidart import ArtifactDetect
from nipype.interfaces.fsl.preprocess import SliceTimer, MCFLIRT, FLIRT, FAST, SUSAN
from nipype.interfaces.fsl.utils import Reorient2Std, MotionOutliers, Merge, ExtractROI
from nipype.interfaces.fsl.model import GLM, MELODIC
from nipype.interfaces.fsl.maths import ApplyMask, TemporalFilter
from nipype.interfaces.fsl.epi import ApplyTOPUP, TOPUP
from nipype.interfaces.freesurfer import Resample, Binarize, MRIConvert
from nipype.algorithms.confounds import CompCor
from nipype.interfaces.afni.preprocess import Bandpass
from nipype.interfaces.afni.utils import AFNItoNIFTI
from nipype.interfaces.ants import ApplyTransforms, Registration
from nipype.algorithms.misc import Gunzip
from pandas import DataFrame, Series

#set output file type for FSL to NIFTI
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# Set study variables
setup='Cat'
sample='newborn' #6mo or newborn
sequence='mux6'#spiral or mux6

if setup=='Lucinda':
    studyhome = '/Volumes/iang/BABIES_data/BABIES_rest'
    raw_data = studyhome + '/subjDir/all/'
    output_dir = studyhome + '/processed/preproc'
    workflow_dir = studyhome + '/workflows' 
if setup=='sherlock':
    studyhome = '/oak/stanford/groups/iang/BABIES_data/BABIES_rest'
    raw_data = studyhome + '/subjDir/all/'
    output_dir = studyhome + '/processed/preproc'
    workflow_dir = studyhome + '/workflows' 
elif setup=='Cat':
    studyhome = '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest'
    raw_data = studyhome + '/SEA_mux_raw'
    output_dir = studyhome + '/SEA_proc'
    workflow_dir = studyhome + '/workflows'

if sample =='6mo':
    template_brain = '/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii.gz'
    template_wm = studyhome + '/templates/BABIES_wm_mask_2mm.nii.gz'
    template_mask = studyhome + '/templates/T2w_BABIES_template_2mm_mask.nii.gz'
elif sample=='newborn':
    template_brain = '/Users/catcamacho/Box/SNAP/BABIES/templates/neonate_T2w_template_2mm.nii.gz'
    template_wm = '/Users/catcamacho/Box/SNAP/BABIES/templates/neonate_T2w_template_2mm_wm.nii.gz'
    template_mask = '/Users/catcamacho/Box/SNAP/BABIES/templates/neonate_T2w_template_2mm_gm.nii.gz'

if sequence=='spiral':
    vols_to_trim = 4
    interleave = False
    TR = 2.5 # in seconds
elif sequence=='mux6':
    custom_timings = studyhome + '/misc/SEA_slicetime_trfraction.txt'
    vols_to_trim = 6
    TR = 0.820 # in seconds

#subjects_list = open(studyhome + '/misc/all_subjects.txt').read().splitlines()
subjects_list = ['SEA-999-NB']

proc_cores = 2 # number of cores of processing for the workflows
resampled_voxel_size = (2,2,2)
fwhm = 4 #fwhm for smoothing with SUSAN
slice_dir = 3 # 1=x, 2=y, 3=z
phase_encoding_file = studyhome + '/misc/SEA_rest_encoding.txt'

#changed to match Pendl et al 2017 (HBM)
highpass_freq = 0.005 #in Hz
lowpass_freq = 0.1 #in Hz

mask_erosion = 1
mask_dilation = 1

# %%
## File handling Nodes

# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)

# Datasink- where our select outputs will go
substitutions = [('_subject_id_', '')]
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
datasink.inputs.substitutions = substitutions

# Data grabber- select fMRI and sMRI
anat_template = {'struct': raw_data + '/{subject_id}_skullstripped_anat.nii.gz'}
select_anat = Node(SelectFiles(anat_template), name='selectanat')

# %% [markdown]
# ### Unwarping workflow

# %%
def sort_pes(pes):
    from nipype import config, logging
    from nipype.interfaces.fsl import Merge
    from os.path import abspath
    config.enable_debug_mode()
    logging.update_logging(config)
    
    print(pes)
    pe1s = []
    pe0s = []
    for file in pes:
        if 'pe0' in file:
            pe0s.append(file)
        elif 'pe1' in file:
            pe1s.append(file)
    
    pe1s = sorted(pe1s)
    pe0s = sorted(pe0s)
    
    me = Merge()
    merged_pes = []
    
    for i in range(0,len(pe1s)):
        num=pe1s[i][-12:-11]
        me.inputs.in_files = [pe1s[i],pe0s[i]]
        me.inputs.dimension='t'
        me.inputs.merged_file = 'merged_pes%s.nii.gz' % num
        me.run()
        file = abspath('merged_pes%s.nii.gz' % num)
        merged_pes.append(file)
        
    return(merged_pes)

# %%
if sequence=='mux6':
    pes_template = {'pes': raw_data + '/%s_mux_rest*.nii.gz'}
    select_pes = Node(DataGrabber(sort_filelist=True,
                                  template = raw_data + '/%s_mux_rest*.nii.gz',
                                  field_template = pes_template,
                                  base_directory=raw_data,
                                  infields=['subject_id'], 
                                  template_args={'pes':[['subject_id']]}), 
                      name='select_pes')

    func_template = {'func': raw_data + '/%s_mux_rest_pe0*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s_mux_rest_pe0*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')

    # include only the first volume of each PE volume
    trim_PEs = MapNode(ExtractROI(t_min=0, t_size=5),name='trim_PEs', 
                       iterfield=['in_file'])

    sort_pe_list = Node(Function(input_names=['pes'],
                                 output_names=['merged_pes'],
                                 function=sort_pes), 
                        name='sort_pe_list')

    topup = MapNode(TOPUP(encoding_file=phase_encoding_file), name='topup',iterfield=['in_file'])

    apply_topup = MapNode(ApplyTOPUP(in_index=[2], encoding_file=phase_encoding_file,
                                     method='jac', out_corrected='func_unwarped.nii.gz'),
                          name='apply_topup',iterfield=['in_topup_fieldcoef','in_topup_movpar','in_files'])

# %%
if sequence=='mux6':
    prepreprocflow = Workflow(name='prepreprocflow')
    prepreprocflow.connect([(infosource,select_pes, [('subject_id','subject_id')]),
                            (infosource,select_func, [('subject_id','subject_id')]),
                            (select_pes,trim_PEs, [('pes','in_file')]), 
                            (trim_PEs,sort_pe_list, [('roi_file','pes')]),
                            (sort_pe_list,topup, [('merged_pes','in_file')]),
                            (topup, apply_topup, [('out_fieldcoef','in_topup_fieldcoef'), 
                                                  ('out_movpar','in_topup_movpar')]),
                            (select_func, apply_topup, [('func','in_files')]),
                            (apply_topup, datasink, [('out_corrected','unwarped_funcs')])
                           ])

    prepreprocflow.base_dir = workflow_dir
    #prepreprocflow.write_graph(graph2use='flat')
    prepreprocflow.run('MultiProc', plugin_args={'n_procs': proc_cores, 'memory_gb':10})
# Out:
# 190326-18:45:26,141 workflow INFO:
# 	 Workflow prepreprocflow settings: ['check', 'execution', 'logging', 'monitoring']
# 190326-18:45:26,201 workflow INFO:
# 	 Running in parallel.
# 190326-18:45:26,206 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-18:45:26,287 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.select_pes" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/select_pes".190326-18:45:26,288 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.select_func" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/select_func".
#
# 190326-18:45:26,300 workflow INFO:
# 	 [Node] Running "select_pes" ("nipype.interfaces.io.DataGrabber")190326-18:45:26,300 workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
#
# 190326-18:45:26,313 workflow INFO:
# 	 [Node] Finished "prepreprocflow.select_func".190326-18:45:26,312 workflow INFO:
# 	 [Node] Finished "prepreprocflow.select_pes".
#
# 190326-18:45:28,205 workflow INFO:
# 	 [Job 0] Completed (prepreprocflow.select_pes).
# 190326-18:45:28,207 workflow INFO:
# 	 [Job 4] Completed (prepreprocflow.select_func).
# 190326-18:45:28,210 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-18:45:30,210 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-18:45:30,254 workflow INFO:
# 	 [Job 7] Cached (_trim_PEs0).
# 190326-18:45:30,256 workflow INFO:
# 	 [Job 8] Cached (_trim_PEs1).
# 190326-18:45:32,212 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-18:45:32,263 workflow INFO:
# 	 [Job 9] Cached (_trim_PEs2).
# 190326-18:45:32,265 workflow INFO:
# 	 [Job 10] Cached (_trim_PEs3).
# 190326-18:45:34,214 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-18:45:34,258 workflow INFO:
# 	 [Job 1] Cached (prepreprocflow.trim_PEs).
# 190326-18:45:36,254 workflow INFO:
# 	 [Job 2] Cached (prepreprocflow.sort_pe_list).
# 190326-18:45:40,219 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-18:45:40,269 workflow INFO:
# 	 [Node] Outdated cache found for "_topup0".
# 190326-18:45:40,272 workflow INFO:
# 	 [Node] Outdated cache found for "_topup1".
# 190326-18:45:40,272 workflow INFO:
# 	 [Node] Setting-up "_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0".
# 190326-18:45:40,275 workflow INFO:
# 	 [Node] Setting-up "_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1".190326-18:45:40,276 workflow INFO:
# 	 [Node] Outdated cache found for "_topup0".
#
# 190326-18:45:40,279 workflow INFO:
# 	 [Node] Outdated cache found for "_topup1".
# 190326-18:45:40,285 workflow INFO:
# 	 [Node] Running "_topup0" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --fwhm=8.000000 --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes1.nii.gz --miter=5 --out=merged_pes1_base --iout=merged_pes1_corrected.nii.gz --fout=merged_pes1_field.nii.gz --jacout=jac --logout=merged_pes1_topup.log --rbmout=xfm --dfout=warpfield --miter=1 --splineorder=3 --subsamp=1 --warpres=10.000000
# 190326-18:45:40,289 workflow INFO:
# 	 [Node] Running "_topup1" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --fwhm=8.000000 --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes2.nii.gz --miter=5 --out=merged_pes2_base --iout=merged_pes2_corrected.nii.gz --fout=merged_pes2_field.nii.gz --jacout=jac --logout=merged_pes2_topup.log --rbmout=xfm --dfout=warpfield --miter=1 --splineorder=3 --subsamp=1 --warpres=10.000000
# 190326-18:45:42,219 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 0/2.
#                      Currently running:
#                        * _topup1
#                        * _topup0
# 190326-19:10:02,34 workflow INFO:
# 	 [Node] Finished "_topup0".
# 190326-19:10:03,720 workflow INFO:
# 	 [Job 11] Completed (_topup0).
# 190326-19:10:03,722 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 1/2.
#                      Currently running:
#                        * _topup1
# 190326-19:10:09,522 workflow INFO:
# 	 [Node] Finished "_topup1".
# 190326-19:10:09,721 workflow INFO:
# 	 [Job 12] Completed (_topup1).
# 190326-19:10:09,723 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-19:10:09,776 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.topup".
# 190326-19:10:09,779 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.topup" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup".
# 190326-19:10:09,783 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.topup".
# 190326-19:10:09,789 workflow INFO:
# 	 [Node] Setting-up "_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0".
# 190326-19:10:09,793 workflow INFO:
# 	 [Node] Cached "_topup0" - collecting precomputed outputs
# 190326-19:10:09,795 workflow INFO:
# 	 [Node] "_topup0" found cached.
# 190326-19:10:09,800 workflow INFO:
# 	 [Node] Setting-up "_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1".
# 190326-19:10:09,805 workflow INFO:
# 	 [Node] Cached "_topup1" - collecting precomputed outputs
# 190326-19:10:09,807 workflow INFO:
# 	 [Node] "_topup1" found cached.
# 190326-19:10:09,813 workflow INFO:
# 	 [Node] Finished "prepreprocflow.topup".
# 190326-19:10:11,722 workflow INFO:
# 	 [Job 3] Completed (prepreprocflow.topup).
# 190326-19:10:11,725 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-19:10:13,730 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-19:10:13,783 workflow INFO:
# 	 [Node] Outdated cache found for "_apply_topup0".
# 190326-19:10:13,785 workflow INFO:
# 	 [Node] Outdated cache found for "_apply_topup1".
# 190326-19:10:13,785 workflow INFO:
# 	 [Node] Setting-up "_apply_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0".
# 190326-19:10:13,788 workflow INFO:
# 	 [Node] Setting-up "_apply_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1".190326-19:10:13,788 workflow INFO:
# 	 [Node] Outdated cache found for "_apply_topup0".
#
# 190326-19:10:13,791 workflow INFO:
# 	 [Node] Outdated cache found for "_apply_topup1".
# 190326-19:10:13,815 workflow INFO:
# 	 [Node] Running "_apply_topup1" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_2.nii.gz --inindex=2 --topup=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1/merged_pes2_base --method=jac --out=func_unwarped.nii.gz190326-19:10:13,815 workflow INFO:
# 	 [Node] Running "_apply_topup0" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz --inindex=2 --topup=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base --method=jac --out=func_unwarped.nii.gz
#
# 190326-19:10:15,739 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 0/2.
#                      Currently running:
#                        * _apply_topup1
#                        * _apply_topup0
# 190326-19:11:36,14 workflow INFO:
# 	 [Node] Finished "_apply_topup0".
# 190326-19:11:36,129 workflow INFO:
# 	 [Node] Finished "_apply_topup1".
# 190326-19:11:37,952 workflow INFO:
# 	 [Job 13] Completed (_apply_topup0).
# 190326-19:11:37,954 workflow INFO:
# 	 [Job 14] Completed (_apply_topup1).
# 190326-19:11:37,955 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-19:11:37,997 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190326-19:11:38,0 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup".
# 190326-19:11:38,4 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190326-19:11:38,11 workflow INFO:
# 	 [Node] Setting-up "_apply_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0".
# 190326-19:11:38,15 workflow INFO:
# 	 [Node] Cached "_apply_topup0" - collecting precomputed outputs
# 190326-19:11:38,18 workflow INFO:
# 	 [Node] "_apply_topup0" found cached.
# 190326-19:11:38,22 workflow INFO:
# 	 [Node] Setting-up "_apply_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1".
# 190326-19:11:38,26 workflow INFO:
# 	 [Node] Cached "_apply_topup1" - collecting precomputed outputs
# 190326-19:11:38,28 workflow INFO:
# 	 [Node] "_apply_topup1" found cached.
# 190326-19:11:38,34 workflow INFO:
# 	 [Node] Finished "prepreprocflow.apply_topup".
# 190326-19:11:39,958 workflow INFO:
# 	 [Job 5] Completed (prepreprocflow.apply_topup).
# 190326-19:11:39,961 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-19:11:40,8 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190326-19:11:40,12 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink".
# 190326-19:11:40,14 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190326-19:11:40,22 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190326-19:11:40,25 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/unwarped_funcs/_subject_id_SEA-999-NB/_apply_topup0/func_unwarped.nii.gz -> /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/unwarped_funcs/SEA-999-NB/_apply_topup0/func_unwarped.nii.gz
# 190326-19:11:40,29 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/unwarped_funcs/_subject_id_SEA-999-NB/_apply_topup1/func_unwarped.nii.gz -> /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/unwarped_funcs/SEA-999-NB/_apply_topup1/func_unwarped.nii.gz
# 190326-19:11:40,37 workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 190326-19:11:41,958 workflow INFO:
# 	 [Job 6] Completed (prepreprocflow.datasink).
# 190326-19:11:41,960 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.

# %% [markdown]
# ### Basic Preprocessing

# %%
if sequence=='spiral': 
    func_template = {'func': raw_data + '/%s/rest*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s/rest*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')
    #Slice timing correction based on interleaved acquisition using FSL
    slicetime_correct = Node(SliceTimer(interleaved=interleave,
                                        slice_direction=slice_dir,
                                        time_repetition=TR,
                                        out_file='st_func.nii.gz'),
                             name='slicetime_correct')
    
elif sequence=='mux6':
    func_template = {'func':'/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/%s_mux_rest_pe1_1.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/%s_mux_rest_pe1_1.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')
    #Slice timing correction 
    slicetime_correct = Node(SliceTimer(time_repetition=TR,
                                        custom_timings=custom_timings,
                                        interleaved=True,
                                        out_file='st_func.nii.gz'),
                             name='slicetime_correct')

# %%
## struct processing
# reorient to standard
reorientstruct = Node(Reorient2Std(), name='reorientstruct')

# convert files to nifti
reslice_struct = Node(MRIConvert(out_type='niigz',
                                 conform_size=2,
                                 crop_size=(128, 128, 128),
                                ),
                   name='reslice_struct')
# Segment structural scan
segment = Node(FAST(no_bias=True, 
                    segments=True, 
                    number_classes=3), 
               name='segment')

# register BOLD to anat
coregT2 = Node(FLIRT(out_matrix_file='xform.mat'),
           name='coregT2')

# apply transform to func
applyT2xform = Node(FLIRT(apply_xfm=True),
                    name='applyT2xform')

# register anat to template
reg_temp = Node(FLIRT(reference=template_brain, 
                      out_matrix_file='xform.mat',
                      out_file='preproc_anat.nii.gz'),
                name='reg_temp')

# apply transform to func
applyxform = Node(FLIRT(reference=template_brain,
                        apply_xfm=True, 
                        out_file='preproc_func.nii.gz'),
                  name='applyxform')


# register BOLD to anat
#coregT2 = Node(Registration(args='--float',
#                            collapse_output_transforms=True,
#                            initial_moving_transform_com=True,
#                            num_threads=1,
#                            output_inverse_warped_image=True,
#                            output_warped_image=True,
#                            sigma_units=['vox']*2,
#                            transforms=['Affine', 'Affine'],
#                            terminal_output='file',
#                            winsorize_lower_quantile=0.005,
#                            winsorize_upper_quantile=0.995,
#                            convergence_threshold=[1e-06],
#                            convergence_window_size=[10],
#                           metric=['Mattes', 'CC'],
#                            metric_weight=[1.0]*2,
#                            number_of_iterations=[[100, 75, 50],
#                                                  [70, 50, 20]],
#                            radius_or_number_of_bins=[32, 4],
#                            sampling_percentage=[0.25, 1],
#                            sampling_strategy=['Regular',
#                                               'None'],
#                            shrink_factors=[[4, 2, 1]]*2,
#                            smoothing_sigmas=[[2, 1, 0]]*2,
#                            transform_parameters=[(0.1,),
#                                                  (0.1,)],
#                            use_histogram_matching=False,
#                            write_composite_transform=True,
#                            dimension=3),
#               name='coregT2')

# apply transform to func
#applyT2xform = Node(ApplyTransforms(reference_image=template_brain, 
#                                    dimension=4, input_image_type=3), 
#                    name = 'applyT2xform')

# register anat to template
#reg_temp = Node(Registration(args='--float',
#                             collapse_output_transforms=True,
#                             initial_moving_transform_com=True,
#                             num_threads=1,
#                             output_inverse_warped_image=True,
#                             output_warped_image=True,
#                             sigma_units=['vox']*2,
#                             transforms=['Affine', 'SyN'],
#                             terminal_output='file',
#                             winsorize_lower_quantile=0.005,
#                             winsorize_upper_quantile=0.995,
#                             convergence_threshold=[1e-06],
#                             convergence_window_size=[10],
#                             metric=['Mattes', 'CC'],
#                             metric_weight=[1.0]*2,
#                             number_of_iterations=[[100, 75, 50],
#                                                   [70, 50, 20]],
#                             radius_or_number_of_bins=[32, 4],
#                             sampling_percentage=[0.25, 1],
#                             sampling_strategy=['Regular',
#                                                'None'],
#                             shrink_factors=[[4, 2, 1]]*2,
#                             smoothing_sigmas=[[2, 1, 0]]*2,
#                             transform_parameters=[(0.1,),
#                                                   (0.1, 3.0, 0.0)],
#                             use_histogram_matching=False,
#                             write_composite_transform=True, 
#                             fixed_image=template_brain),
#                name='reg_temp')

# apply transform to func
#applyxform = Node(ApplyTransforms(reference_image=template_brain, 
#                                  dimension=4, input_image_type=3), 
#                  name = 'applyxform')

# %%
def combine_fd(fd_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import asarray, savetxt
    
    motion = open(fd_list[0]).read().splitlines()

    if len(fd_list)>1:
        for file in fd_list[1:]:
            temp = open(file).read().splitlines()
            motion = motion+temp

    motion = asarray(motion).astype(float)
    filename = 'FD_full.txt'
    savetxt(filename,motion)
    combined_fd = abspath(filename)
    return(combined_fd)


def combine_par(par_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import vstack, savetxt, genfromtxt
    
    motion = genfromtxt(par_list[0], dtype=float)
    if len(par_list)>1:
        for file in par_list[1:]:
            temp = genfromtxt(par_list[0], dtype=float)
            motion=vstack((motion,temp))
    
    filename = 'motion.par'
    savetxt(filename, motion, delimiter=' ')
    combined_par = abspath(filename)
    return(combined_par)

# %%
# Data QC nodes
def create_coreg_plot(epi,anat):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    coreg_filename='coregistration.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'coregistration to anatomy')
    display.add_edges(anat)
    display.savefig(coreg_filename) 
    display.close()
    coreg_file = os.path.abspath(coreg_filename)
    
    return(coreg_file)

def check_mask_coverage(epi,brainmask):
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    from nipype.interfaces.nipy.preprocess import Trim
    
    trim = Trim()
    trim.inputs.in_file = epi
    trim.inputs.end_index = 1
    trim.inputs.out_file = 'epi_vol1.nii.gz'
    trim.run()
    epi_vol = abspath('epi_vol1.nii.gz')
    
    maskcheck_filename='maskcheck.png'
    display = plotting.plot_anat(epi_vol, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'brainmask coverage')
    display.add_contours(brainmask,levels=[.5], colors='r')
    display.savefig(maskcheck_filename)
    display.close()
    maskcheck_file = abspath(maskcheck_filename)

    return(maskcheck_file)

make_coreg_img = Node(Function(input_names=['epi','anat'],
                               output_names=['coreg_file'],
                               function=create_coreg_plot), name='make_coreg_img')

make_checkmask_img = Node(
    Function(input_names=['epi','brainmask'],
             output_names=['maskcheck_file'],
             function=check_mask_coverage), name='make_checkmask_img')
make_checkmask_img.inputs.brainmask = template_mask

# %%
## Nodes for func preprocessing
# Reorient to standard space using FSL
reorientfunc = MapNode(Reorient2Std(), name='reorientfunc', iterfield=['in_file'])

# Trim first 4 volumes
trimvols = MapNode(Trim(begin_index=vols_to_trim), name='trimvols', iterfield=['in_file'])

# Motion correction
motion_correct = MapNode(MCFLIRT(save_plots=True), name='motion_correct', iterfield=['in_file'])

# Get frame-wise displacement for each run: in_file; out_file, out_metric_plot, out_metric_values
get_FD = MapNode(MotionOutliers(metric = 'fd',
                                out_metric_values = 'FD.txt',
                                out_metric_plot = 'motionplot.png',
                                threshold=0.001,
                                no_motion_correction=False),
                    name='get_FD', iterfield=['in_file'])

# Merge rest
merge = Node(Merge(dimension='t'), name='merge')

# Merge motion (6 params)
comb_par = Node(Function(input_names=['par_list'],
                         output_names=['combined_par'],
                         function=combine_par), name='comb_par')

# Merge FD
comb_fd = Node(Function(input_names=['fd_list'],
                         output_names=['combined_fd'],
                         function=combine_fd), name='comb_fd')

# Rigid body realignment
realignment = Node(MCFLIRT(), name='realignment')

# unzip the nifti for ART
gunzip = Node(Gunzip(), name='gunzip')

# Artifact detection for scrubbing/motion assessment
art = Node(ArtifactDetect(mask_type='file',
                          parameter_source='FSL',
                          norm_threshold=0.25, #mutually exclusive with rotation and translation thresh
                          zintensity_threshold=2,
                          use_differences=[True, False], 
                          mask_file=template_mask),
           name='art')

# %%
## Preprocessing Workflow

# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                    (node2,node3,[('node2output','node3input')])
#                    ])

preprocwf = Workflow(name='preprocwf')
preprocwf.connect([(infosource,select_func,[('subject_id','subject_id')]), 
                   (select_func,reorientfunc,[('func','in_file')]),
                   (reorientfunc,trimvols,[('out_file','in_file')]),
                   (trimvols,motion_correct,[('out_file','in_file')]),
                   (trimvols,get_FD,[('out_file','in_file')]),
                   (motion_correct,merge,[('out_file','in_files')]),
                   (merge,realignment,[('merged_file','in_file')]),
                   (realignment,slicetime_correct,[('out_file','in_file')]),
                   (get_FD,comb_fd,[('out_metric_values','fd_list')]),
                   (motion_correct,comb_par,[('par_file','par_list')]),
                   (comb_par,art,[('combined_par','realignment_parameters')]),
                   (gunzip,art,[('out_file','realigned_files')]),
                   
                   (infosource,select_anat,[('subject_id','subject_id')]),
                   (select_anat,reslice_struct,[('struct','in_file')]),
                   (reslice_struct,reorientstruct,[('out_file','in_file')]),
                   (reorientstruct,make_coreg_img,[('out_file','anat')]),
                   
                   (reorientstruct,coregT2,[('out_file','reference')]),
                   (reorientstruct,applyT2xform,[('out_file','reference')]),
                   (reorientstruct,reg_temp,[('out_file','in_file')]),
                   (reg_temp,applyxform,[('out_matrix_file','in_matrix_file')]),
                   (slicetime_correct,coregT2,[('slice_time_corrected_file','in_file')]),
                   (slicetime_correct,applyT2xform,[('slice_time_corrected_file','in_file')]),
                   (coregT2,applyT2xform,[('out_matrix_file','in_matrix_file')]),
                   (applyT2xform, applyxform,[('out_file','in_file')]),
                   (applyxform,gunzip,[('out_file','in_file')]),
                   (reg_temp,segment,[('out_file','in_files')]),
                   (coregT2,make_coreg_img,[('out_file','epi')]),
                   (applyxform,make_checkmask_img,[('out_file','epi')]),
                   (applyxform, datasink, [('out_file','preproc_func')]),
                   (reg_temp, datasink,[('out_file','preproc_anat')]),
                   
                   #(reslice_struct,coregT2,[('out_file','fixed_image')]),
                   #(reslice_struct, applyT2xform,[('out_file','reference_image')]),
                   #(reslice_struct,reg_temp,[('out_file','moving_image')]),
                   #(reg_temp,applyxform,[('composite_transform','transforms')]),
                   #(slicetime_correct,coregT2,[('slice_time_corrected_file','moving_image')]),
                   #(slicetime_correct,applyT2xform,[('slice_time_corrected_file','input_image')]),
                   #(coregT2,applyT2xform,[('composite_transform','transforms')]),
                   #(applyT2xform, applyxform,[('output_image','input_image')]),
                   #(applyxform,gunzip,[('output_image','in_file')]),
                   #(reg_temp,segment,[('warped_image','in_files')]),
                   #(coregT2,make_coreg_img,[('warped_image','epi')]),
                   #(applyxform,make_checkmask_img,[('output_image','epi')]),
                   #(applyxform, datasink, [('output_image','preproc_func')]),
                   #(reg_temp, datasink,[('warped_image','preproc_anat')]),

                   (comb_fd, datasink, [('combined_fd','FD_out_metric_values')]),
                   (comb_par,datasink,[('combined_par','motion_params')]),
                   (segment,datasink,[('tissue_class_files','tissue_class_files')]),
                   (art,datasink, [('plot_files','art_plot_files')]),
                   (art,datasink, [('outlier_files','vols_to_censor')]),
                   (make_checkmask_img,datasink,[('maskcheck_file','maskcheck_image')]),
                   (make_coreg_img,datasink,[('coreg_file','coreg_image')])                   
                  ])
preprocwf.base_dir = workflow_dir
#preprocwf.write_graph(graph2use='flat')
preprocwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 190911-09:35:59,603 nipype.workflow INFO:
# 	 Workflow preprocwf settings: ['check', 'execution', 'logging', 'monitoring']
# 190911-09:35:59,661 nipype.workflow INFO:
# 	 Running in parallel.
# 190911-09:35:59,666 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190911-09:35:59,728 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.selectanat" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/selectanat".
# 190911-09:35:59,735 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.select_func" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/select_func".
# 190911-09:35:59,761 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 190911-09:35:59,771 nipype.workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
# 190911-09:35:59,795 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.selectanat".
# 190911-09:35:59,807 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.select_func".
# 190911-09:36:01,669 nipype.workflow INFO:
# 	 [Job 0] Completed (preprocwf.selectanat).
# 190911-09:36:01,674 nipype.workflow INFO:
# 	 [Job 5] Completed (preprocwf.select_func).
# 190911-09:36:01,677 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190911-09:36:01,754 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.reslice_struct" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reslice_struct".
# 190911-09:36:01,762 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.reorientfunc" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientfunc".
# 190911-09:36:01,806 nipype.workflow INFO:
# 	 [Node] Running "reslice_struct" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --conform_size 2.0 --cropsize 128 128 128 --out_type nii --input_volume /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_skullstripped_anat.nii.gz --output_volume /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reslice_struct/SEA-999-NB_skullstripped_anat_out.nii.gz
# 190911-09:36:01,814 nipype.workflow INFO:
# 	 [Node] Setting-up "_reorientfunc0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientfunc/mapflow/_reorientfunc0".
# 190911-09:36:01,850 nipype.workflow INFO:
# 	 [Node] Running "_reorientfunc0" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe1_1.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientfunc/mapflow/_reorientfunc0/SEA-999-NB_mux_rest_pe1_1_reoriented.nii.gz
# 190911-09:36:02,684 nipype.workflow INFO:
# 	 [Node] Finished "_reorientfunc0".
# 190911-09:36:02,704 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.reorientfunc".
# 190911-09:36:03,668 nipype.workflow INFO:
# 	 [Job 6] Completed (preprocwf.reorientfunc).
# 190911-09:36:03,671 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reslice_struct
# 190911-09:36:03,729 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.trimvols" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/trimvols".
# 190911-09:36:03,770 nipype.workflow INFO:
# 	 [Node] Setting-up "_trimvols0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/trimvols/mapflow/_trimvols0".
# 190911-09:36:03,812 nipype.workflow INFO:
# 	 [Node] Running "_trimvols0" ("nipype.interfaces.nipy.preprocess.Trim")
# 190911-09:36:03,988 nipype.workflow INFO:
# 	 [Node] Finished "_trimvols0".
# 190911-09:36:04,13 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.trimvols".
# 190911-09:36:05,178 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.reslice_struct".
# 190911-09:36:05,670 nipype.workflow INFO:
# 	 [Job 1] Completed (preprocwf.reslice_struct).
# 190911-09:36:05,674 nipype.workflow INFO:
# 	 [Job 7] Completed (preprocwf.trimvols).
# 190911-09:36:05,678 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190911-09:36:05,725 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.reorientstruct" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientstruct".
# 190911-09:36:05,737 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.get_FD" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/get_FD".
# 190911-09:36:05,770 nipype.workflow INFO:
# 	 [Node] Running "reorientstruct" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reslice_struct/SEA-999-NB_skullstripped_anat_out.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientstruct/SEA-999-NB_skullstripped_anat_out_reoriented.nii.gz
# 190911-09:36:05,776 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_FD0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/get_FD/mapflow/_get_FD0".
# 190911-09:36:05,815 nipype.workflow INFO:
# 	 [Node] Running "_get_FD0" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/trimvols/mapflow/_trimvols0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim.nii.gz --fd -o SEA-999-NB_mux_rest_pe1_1_reoriented_trim_outliers.txt -p motionplot.png -s FD.txt --thresh=0.001
# 190911-09:36:06,165 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.reorientstruct".
# 190911-09:36:07,122 nipype.workflow INFO:
# 	 [Node] Finished "_get_FD0".
# 190911-09:36:07,139 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.get_FD".
# 190911-09:36:07,671 nipype.workflow INFO:
# 	 [Job 2] Completed (preprocwf.reorientstruct).
# 190911-09:36:07,673 nipype.workflow INFO:
# 	 [Job 8] Completed (preprocwf.get_FD).
# 190911-09:36:07,676 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190911-09:36:07,722 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.reg_temp" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reg_temp".
# 190911-09:36:07,728 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.comb_fd" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd".
# 190911-09:36:07,765 nipype.workflow INFO:
# 	 [Node] Running "comb_fd" ("nipype.interfaces.utility.wrappers.Function")
# 190911-09:36:07,775 nipype.workflow INFO:
# 	 [Node] Running "reg_temp" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientstruct/SEA-999-NB_skullstripped_anat_out_reoriented.nii.gz -ref /Users/catcamacho/Box/SNAP/BABIES/templates/neonate_T2w_template_2mm.nii.gz -out preproc_anat.nii.gz -omat xform.mat
# 190911-09:36:07,790 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/FD_full.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/_0xf00a10380629d54cf9de9e3e317a3dd0_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/_node.pklz
# 190911-09:36:07,793 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/_report
# 190911-09:36:07,799 nipype.workflow DEBUG:
# 	 Removing files:
# 190911-09:36:07,805 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/result_comb_fd.pklz
# 190911-09:36:07,816 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/_report/report.rst"
# 190911-09:36:07,821 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:07,827 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.comb_fd".
# 190911-09:36:09,672 nipype.workflow INFO:
# 	 [Job 9] Completed (preprocwf.comb_fd).
# 190911-09:36:09,674 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190911-09:36:09,721 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.motion_correct" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct".
# 190911-09:36:09,724 nipype.workflow DEBUG:
# 	 adding multipath trait: in_file
# 190911-09:36:09,727 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct".
# 190911-09:36:09,729 nipype.workflow DEBUG:
# 	 [MapNode] Resume - hashfile=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/_0x28767470d673c4a9f644e85198e2b17b_unfinished.json
# 190911-09:36:09,732 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct
# 190911-09:36:09,741 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/_report
# 190911-09:36:09,745 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/_report/report.rst"
# 190911-09:36:09,763 nipype.workflow DEBUG:
# 	 setting input 0 in_file /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/trimvols/mapflow/_trimvols0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim.nii.gz
# 190911-09:36:09,768 nipype.workflow INFO:
# 	 [Node] Setting-up "_motion_correct0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0".
# 190911-09:36:09,770 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190911-09:36:09,775 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0".
# 190911-09:36:09,777 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0
# 190911-09:36:09,780 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0
# 190911-09:36:09,790 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/_report
# 190911-09:36:09,794 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/_report/report.rst"
# 190911-09:36:09,812 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/trimvols/mapflow/_trimvols0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim.nii.gz
# 190911-09:36:09,817 nipype.interface DEBUG:
# 	 out_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz
# 190911-09:36:09,819 nipype.interface DEBUG:
# 	 save_plots_True
# 190911-09:36:09,827 nipype.workflow INFO:
# 	 [Node] Running "_motion_correct0" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/trimvols/mapflow/_trimvols0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim.nii.gz -out /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz -plots
# 190911-09:36:09,831 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/trimvols/mapflow/_trimvols0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim.nii.gz
# 190911-09:36:09,834 nipype.interface DEBUG:
# 	 out_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz
# 190911-09:36:09,837 nipype.interface DEBUG:
# 	 save_plots_True
# 190911-09:36:10,208 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz.par;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/_0x68a2ff97a88f98881d08625ec2817626_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/_node.pklz
# 190911-09:36:10,210 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/_report
# 190911-09:36:10,216 nipype.workflow DEBUG:
# 	 Removing files:
# 190911-09:36:10,224 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/result__motion_correct0.pklz
# 190911-09:36:10,230 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/_report/report.rst"
# 190911-09:36:10,241 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:10,250 nipype.workflow INFO:
# 	 [Node] Finished "_motion_correct0".
# 190911-09:36:10,263 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/result_motion_correct.pklz
# 190911-09:36:10,270 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/_report/report.rst"
# 190911-09:36:10,276 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:10,282 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.motion_correct".
# 190911-09:36:11,674 nipype.workflow INFO:
# 	 [Job 10] Completed (preprocwf.motion_correct).
# 190911-09:36:11,677 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190911-09:36:11,719 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.comb_par" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par".
# 190911-09:36:11,721 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par".
# 190911-09:36:11,723 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par
# 190911-09:36:11,726 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par
# 190911-09:36:11,733 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/_report
# 190911-09:36:11,737 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/_report/report.rst"
# 190911-09:36:11,755 nipype.workflow INFO:
# 	 [Node] Running "comb_par" ("nipype.interfaces.utility.wrappers.Function")
# 190911-09:36:11,781 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/motion.par;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/_0x00448b8720668f5ca2b30a423d606682_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/_node.pklz
# 190911-09:36:11,784 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/_report
# 190911-09:36:11,789 nipype.workflow DEBUG:
# 	 Removing files:
# 190911-09:36:11,796 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/result_comb_par.pklz
# 190911-09:36:11,800 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/_report/report.rst"
# 190911-09:36:11,806 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:11,812 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.comb_par".
# 190911-09:36:13,675 nipype.workflow INFO:
# 	 [Job 11] Completed (preprocwf.comb_par).
# 190911-09:36:13,677 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190911-09:36:13,719 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.merge" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge".
# 190911-09:36:13,722 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge".
# 190911-09:36:13,724 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge
# 190911-09:36:13,726 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge
# 190911-09:36:13,733 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/_report
# 190911-09:36:13,737 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/_report/report.rst"
# 190911-09:36:13,755 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz']
# 190911-09:36:13,757 nipype.interface DEBUG:
# 	 merged_file_SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged.nii.gz
# 190911-09:36:13,764 nipype.workflow INFO:
# 	 [Node] Running "merge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz
# 190911-09:36:13,767 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/motion_correct/mapflow/_motion_correct0/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf.nii.gz']
# 190911-09:36:13,770 nipype.interface DEBUG:
# 	 merged_file_SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged.nii.gz
# 190911-09:36:14,30 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/_0x5e920a133ee4bdf8d768e8b294536bf1_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/_node.pklz
# 190911-09:36:14,33 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/_report
# 190911-09:36:14,39 nipype.workflow DEBUG:
# 	 Removing files:
# 190911-09:36:14,47 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/result_merge.pklz
# 190911-09:36:14,52 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/_report/report.rst"
# 190911-09:36:14,60 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:14,65 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.merge".
# 190911-09:36:15,676 nipype.workflow INFO:
# 	 [Job 12] Completed (preprocwf.merge).
# 190911-09:36:15,678 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190911-09:36:15,725 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.realignment" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment".
# 190911-09:36:15,728 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment".
# 190911-09:36:15,730 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment
# 190911-09:36:15,732 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment
# 190911-09:36:15,741 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/_report
# 190911-09:36:15,744 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/_report/report.rst"
# 190911-09:36:15,762 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged.nii.gz
# 190911-09:36:15,765 nipype.interface DEBUG:
# 	 out_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged_mcf.nii.gz
# 190911-09:36:15,771 nipype.workflow INFO:
# 	 [Node] Running "realignment" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged.nii.gz -out /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged_mcf.nii.gz
# 190911-09:36:15,775 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/merge/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged.nii.gz
# 190911-09:36:15,778 nipype.interface DEBUG:
# 	 out_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged_mcf.nii.gz
# 190911-09:36:16,155 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged_mcf.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/_0x72c1704bb0a7b549268324c264a390cd_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/_node.pklz
# 190911-09:36:16,158 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/_report
# 190911-09:36:16,164 nipype.workflow DEBUG:
# 	 Removing files:
# 190911-09:36:16,171 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/result_realignment.pklz
# 190911-09:36:16,176 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/_report/report.rst"
# 190911-09:36:16,184 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:16,189 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.realignment".
# 190911-09:36:17,680 nipype.workflow INFO:
# 	 [Job 13] Completed (preprocwf.realignment).
# 190911-09:36:17,683 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190911-09:36:17,727 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.slicetime_correct" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct".
# 190911-09:36:17,729 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct".
# 190911-09:36:17,731 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct
# 190911-09:36:17,733 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct
# 190911-09:36:17,740 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/_report
# 190911-09:36:17,744 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/_report/report.rst"
# 190911-09:36:17,760 nipype.interface DEBUG:
# 	 custom_timings_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_slicetime_trfraction.txt
# 190911-09:36:17,762 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged_mcf.nii.gz
# 190911-09:36:17,764 nipype.interface DEBUG:
# 	 interleaved_True
# 190911-09:36:17,767 nipype.interface DEBUG:
# 	 out_file_st_func.nii.gz
# 190911-09:36:17,770 nipype.interface DEBUG:
# 	 time_repetition_0.82
# 190911-09:36:17,777 nipype.workflow INFO:
# 	 [Node] Running "slicetime_correct" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged_mcf.nii.gz --tcustom=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_slicetime_trfraction.txt --odd --out=st_func.nii.gz --repeat=0.820000
# 190911-09:36:17,781 nipype.interface DEBUG:
# 	 custom_timings_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_slicetime_trfraction.txt
# 190911-09:36:17,783 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/realignment/SEA-999-NB_mux_rest_pe1_1_reoriented_trim_mcf_merged_mcf.nii.gz
# 190911-09:36:17,786 nipype.interface DEBUG:
# 	 interleaved_True
# 190911-09:36:17,789 nipype.interface DEBUG:
# 	 out_file_st_func.nii.gz
# 190911-09:36:17,791 nipype.interface DEBUG:
# 	 time_repetition_0.82
# 190911-09:36:18,376 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/st_func.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/_0xe73b2483119b27d58d8d134c4113d80c_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/_node.pklz
# 190911-09:36:18,378 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/_report
# 190911-09:36:18,383 nipype.workflow DEBUG:
# 	 Removing files:
# 190911-09:36:18,390 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/result_slicetime_correct.pklz
# 190911-09:36:18,395 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/_report/report.rst"
# 190911-09:36:18,402 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:18,409 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.slicetime_correct".
# 190911-09:36:19,683 nipype.workflow INFO:
# 	 [Job 14] Completed (preprocwf.slicetime_correct).
# 190911-09:36:19,685 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190911-09:36:19,732 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.coregT2" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2".
# 190911-09:36:19,735 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2".
# 190911-09:36:19,737 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2
# 190911-09:36:19,739 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2
# 190911-09:36:19,746 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2/_report
# 190911-09:36:19,750 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2/_report/report.rst"
# 190911-09:36:19,770 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/st_func.nii.gz
# 190911-09:36:19,773 nipype.interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 190911-09:36:19,776 nipype.interface DEBUG:
# 	 out_matrix_file_xform.mat
# 190911-09:36:19,778 nipype.interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientstruct/SEA-999-NB_skullstripped_anat_out_reoriented.nii.gz
# 190911-09:36:19,785 nipype.workflow INFO:
# 	 [Node] Running "coregT2" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/st_func.nii.gz -ref /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientstruct/SEA-999-NB_skullstripped_anat_out_reoriented.nii.gz -out st_func_flirt.nii.gz -omat xform.mat
# 190911-09:36:19,789 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/st_func.nii.gz
# 190911-09:36:19,792 nipype.interface DEBUG:
# 	 out_file_st_func_flirt.nii.gz
# 190911-09:36:19,794 nipype.interface DEBUG:
# 	 out_matrix_file_xform.mat
# 190911-09:36:19,797 nipype.interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientstruct/SEA-999-NB_skullstripped_anat_out_reoriented.nii.gz
# 190911-09:36:21,686 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 0/2.
#                      Currently running:
#                        * preprocwf.coregT2
#                        * preprocwf.reg_temp
# 190911-09:36:28,848 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2/result_coregT2.pklz
# 190911-09:36:28,850 nipype.workflow WARNING:
# 	 [Node] Error on "preprocwf.coregT2" (/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2)
# 190911-09:36:28,855 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:29,704 nipype.workflow ERROR:
# 	 Node coregT2.a0 failed to run on host cats-mbp.wusm-wifi.wucon.wustl.edu.
# 190911-09:36:29,706 nipype.workflow ERROR:
# 	 Saving crash info to /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/infant_rest/crash-20190911-093629-catcamacho-coregT2.a0-515bdbbd-f9d7-46b2-995c-3f5251310ac0.pklz
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 69, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 473, in run
#     result = self._run_interface(execute=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 557, in _run_interface
#     return self._run_command(execute)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 637, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 371, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/fsl/preprocess.py", line 666, in aggregate_outputs
#     runtime=runtime, needed_outputs=needed_outputs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 472, in aggregate_outputs
#     raise error
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 465, in aggregate_outputs
#     setattr(outputs, key, val)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/traits_extension.py", line 112, in validate
#     self.info_text, value))
# traits.trait_errors.TraitError: The trait 'out_file' of a FLIRTOutputSpec instance is an existing file name, but the path  '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2/st_func_flirt.nii.gz' does not exist.
#
# 190911-09:36:29,712 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.reg_temp
# 190911-09:36:33,661 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.reg_temp".
# 190911-09:36:33,700 nipype.workflow INFO:
# 	 [Job 3] Completed (preprocwf.reg_temp).
# 190911-09:36:33,703 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190911-09:36:33,744 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.segment" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment".
# 190911-09:36:33,746 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment".
# 190911-09:36:33,748 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment
# 190911-09:36:33,750 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment
# 190911-09:36:33,757 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/_report
# 190911-09:36:33,760 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/_report/report.rst"
# 190911-09:36:33,776 nipype.workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190911-09:36:33,778 nipype.utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz
# 190911-09:36:33,781 nipype.utils DEBUG:
# 	 Symlinking File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reg_temp/preproc_anat.nii.gz
# 190911-09:36:33,783 nipype.utils DEBUG:
# 	 Copying File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reg_temp/preproc_anat.nii.gz
# 190911-09:36:33,793 nipype.utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz
# 190911-09:36:33,796 nipype.utils DEBUG:
# 	 File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz already exists,b1f5ed8c74922cb58bf341aea1b7ba27, copy:1
# 190911-09:36:33,798 nipype.utils DEBUG:
# 	 File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz already exists, not overwriting, copy:1
# 190911-09:36:33,802 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz']
# 190911-09:36:33,804 nipype.interface DEBUG:
# 	 no_bias_True
# 190911-09:36:33,806 nipype.interface DEBUG:
# 	 number_classes_3
# 190911-09:36:33,808 nipype.interface DEBUG:
# 	 segments_True
# 190911-09:36:33,814 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -N -n 3 -g -S 1 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz
# 190911-09:36:33,818 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz']
# 190911-09:36:33,821 nipype.interface DEBUG:
# 	 no_bias_True
# 190911-09:36:33,823 nipype.interface DEBUG:
# 	 number_classes_3
# 190911-09:36:33,826 nipype.interface DEBUG:
# 	 segments_True
# 190911-09:36:35,702 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.segment
# 190911-09:36:41,136 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_seg_0.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_seg_1.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_seg_2.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/_0xc5b1b1a6775d266db1916c5e4023214d_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/_node.pklz
# 190911-09:36:41,139 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/_report
# 190911-09:36:41,145 nipype.workflow DEBUG:
# 	 Removing files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_mixeltype.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_pve_0.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_pve_1.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_pve_2.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_pveseg.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_seg.nii.gz
# 190911-09:36:41,164 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/result_segment.pklz
# 190911-09:36:41,168 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/_report/report.rst"
# 190911-09:36:41,176 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190911-09:36:41,183 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.segment".
# 190911-09:36:41,711 nipype.workflow INFO:
# 	 [Job 4] Completed (preprocwf.segment).
# 190911-09:36:41,715 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190911-09:36:43,710 nipype.workflow INFO:
# 	 ***********************************
# 190911-09:36:43,711 nipype.workflow ERROR:
# 	 could not run node: preprocwf.coregT2.a0
# 190911-09:36:43,711 nipype.workflow INFO:
# 	 crashfile: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/infant_rest/crash-20190911-093629-catcamacho-coregT2.a0-515bdbbd-f9d7-46b2-995c-3f5251310ac0.pklz
# 190911-09:36:43,712 nipype.workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-832f138e0ba2> in <module>
#      64 preprocwf.base_dir = workflow_dir
#      65 #preprocwf.write_graph(graph2use='flat')
# ---> 66 preprocwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     597         if str2bool(self.config['execution']['create_report']):
#     598             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 599         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     600         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     601         if str2bool(self.config['execution']['write_provenance']):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     189
#     190         self._remove_node_dirs()
# --> 191         report_nodes_not_run(notrun)
#     192
#     193         # close any open resources
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/plugins/tools.py in report_nodes_not_run(notrun)
#      80                 logger.debug(subnode._id)
#      81         logger.info("***********************************")
# ---> 82         raise RuntimeError(('Workflow did not execute cleanly. '
#      83                             'Check log for details'))
#      84
#
# RuntimeError: Workflow did not execute cleanly. Check log for details

# %%
# Resting state preprocessing
# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)


# Data grabber- select fMRI and sMRI
templates = {'func': output_dir + '/preproc_func/{subject_id}/preproc_func.nii.gz',
             'csf': output_dir + '/tissue_class_files/{subject_id}/preproc_anat_seg_0.nii.gz', 
             'vols_to_censor':output_dir + '/vols_to_censor/{subject_id}/art.preproc_func_outliers.txt', 
             'motion_params':output_dir + '/FD_out_metric_values/{subject_id}/FD_full.txt',
             'wm':template_wm}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# %%
## Pull motion info for all subjects

motion_df_file = output_dir + '/motion_summary/motionSummary.csv'

if isdir(output_dir + '/motion_summary')==False:
    makedirs(output_dir + '/motion_summary')
    motion_df = DataFrame(columns=['meanFD','maxFD','NumCensoredVols','totalVolumes','secondsNotCensored','lengthsNotCensored_descendingSeconds'])
    motion_df.to_csv(motion_df_file)
    
def summarize_motion(motion_df_file, motion_file, vols_to_censor, TR):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import dirname, basename
    from numpy import asarray, mean, insert, zeros, sort
    from pandas import DataFrame, Series, read_csv
    
    motion_df = read_csv(motion_df_file, index_col=0)
    
    motion = asarray(open(motion_file).read().splitlines()).astype(float)
    censvols = asarray(open(vols_to_censor).read().splitlines()).astype(int)
    sec_not_censored = (len(motion)-len(censvols))*TR
    
    if censvols[0]>0:
        periods_not_censored = insert(censvols,0,0)
    else:
        periods_not_censored = censvols
    
    if periods_not_censored[-1]<len(motion):
        periods_not_censored = insert(periods_not_censored,len(periods_not_censored),len(motion))
    
    lengths = zeros(len(periods_not_censored)-1)
    for a in range(0,len(lengths)):
        lengths[a] = periods_not_censored[a+1] - periods_not_censored[a] - 1
    
    lengths = lengths*TR
    
    # sort lengths in descending order
    lengths = sort(lengths)[::-1]

    fp = dirname(motion_file)
    subject = basename(fp)

    motion_df.loc[subject] = [mean(motion),max(motion),len(censvols),len(motion),sec_not_censored,lengths]
    motion_df.to_csv(motion_df_file)

    return()

# Make a list of tissues for component noise removal
def combine_masks(mask1,mask2):
    from nipype.interfaces.fsl.utils import Merge
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    vols = []
    vols.append(mask1)
    vols.append(mask2)
    
    return(vols)
    
# Remove all noise (GLM with noise params)
def create_noise_matrix(vols_to_censor,motion_params,comp_noise):
    from numpy import genfromtxt, zeros,concatenate, savetxt
    from os import path

    motion = genfromtxt(motion_params, delimiter=' ', dtype=None, skip_header=0)
    comp_noise = genfromtxt(comp_noise, delimiter='\t', dtype=None, skip_header=1)
    censor_vol_list = genfromtxt(vols_to_censor, delimiter='\t', dtype=None, skip_header=0)

    c = len(censor_vol_list)
    d = len(comp_noise)
    if c > 0:
        scrubbing = zeros((d,c),dtype=int)
        for t in range(0,c):
            scrubbing[censor_vol_list[t]][t] = 1    
        noise_matrix = concatenate([motion[:,None],comp_noise,scrubbing],axis=1)
    else:
        noise_matrix = concatenate((motion[:,None],comp_noise),axis=1)

    noise_file = 'noise_matrix.txt'
    savetxt(noise_file, noise_matrix, delimiter='\t')
    noise_filepath = path.abspath(noise_file)
    
    return(noise_filepath)

def convertafni(in_file):
    from nipype.interfaces.afni.utils import AFNItoNIFTI
    from os import path
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    cvt = AFNItoNIFTI()
    cvt.inputs.in_file = in_file
    cvt.inputs.out_file = 'func_filtered.nii.gz'
    cvt.run()
    
    out_file = path.abspath('func_filtered.nii.gz')
    return(out_file)

# Brightness threshold should be 0.75 * the contrast between the median brain intensity and the background
def brightthresh(func):
    import nibabel as nib
    from numpy import median, where
    
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    func_nifti1 = nib.load(func)
    func_data = func_nifti1.get_data()
    func_data = func_data.astype(float)
    
    brain_values = where(func_data > 0)
    median_thresh = median(brain_values)
    bright_thresh = 0.75 * median_thresh
    
    return(bright_thresh)

# %%
# Denoising
merge_confs = Node(Function(input_names=['mask1','mask2'],
                            output_names=['vols'], 
                            function=combine_masks), 
                   name='merge_confs')

compcor = Node(CompCor(merge_method='none'), 
               name='compcor')

noise_mat = Node(Function(input_names=['vols_to_censor','motion_params','comp_noise'],
                          output_names=['noise_filepath'], 
                          function=create_noise_matrix), 
                 name='noise_mat')

denoise = Node(GLM(out_res_name='denoised_residuals.nii.gz', 
                   out_data_name='denoised_func.nii.gz'), 
               name='denoise')

# band pass filtering- all rates are in Hz (1/TR or samples/second)
bandpass = Node(Bandpass(highpass=highpass_freq,
                         lowpass=lowpass_freq), 
                name='bandpass')

afni_convert = Node(Function(input_names=['in_file'],
                             output_names=['out_file'],
                             function=convertafni), 
                    name='afni_convert')

# Spatial smoothing 
brightthresh_filt = Node(Function(input_names=['func'], 
                                  output_names=['bright_thresh'], 
                                  function=brightthresh), 
                         name='brightthresh_filt')    
    
smooth_filt = Node(SUSAN(fwhm=fwhm), name='smooth_filt')

motion_summary = Node(Function(input_names=['motion_df_file','motion_file','vols_to_censor','TR'], 
                               output_names=[], 
                               function=summarize_motion), 
                      name='motion_summary')
motion_summary.inputs.motion_df_file = motion_df_file
motion_summary.inputs.TR = TR

# %%
# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                       (node2,node3,[('node2output','node3input')])
#                     ])

rs_procwf = Workflow(name='rs_procwf')
rs_procwf.connect([(infosource,selectfiles,[('subject_id','subject_id')]),
                   (selectfiles,compcor,[('func','realigned_file')]),
                   (selectfiles,merge_confs,[('csf','mask1')]),
                   (selectfiles,merge_confs,[('wm','mask2')]),
                   (merge_confs,compcor,[('vols','mask_files')]),
                   (compcor,noise_mat,[('components_file','comp_noise')]),
                   (selectfiles,noise_mat,[('vols_to_censor','vols_to_censor'),
                                           ('motion_params','motion_params')]),
                   (noise_mat,denoise,[('noise_filepath','design')]),
                   (selectfiles,denoise,[('func','in_file')]),
                   (denoise,bandpass,[('out_data','in_file')]),
                   (bandpass,afni_convert,[('out_file','in_file')]),
                   (afni_convert,brightthresh_filt,[('out_file','func')]),
                   (brightthresh_filt,smooth_filt,[('bright_thresh','brightness_threshold')]),
                   (afni_convert,smooth_filt,[('out_file','in_file')]),  
                   (selectfiles, motion_summary, [('motion_params','motion_file'),
                                                  ('vols_to_censor','vols_to_censor')]),
                   
                   (smooth_filt,datasink,[('smoothed_file','proc_func')])
                   ])

rs_procwf.base_dir = workflow_dir
rs_procwf.write_graph(graph2use='flat')
rs_procwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 190326-19:26:23,450 workflow INFO:
# 	 Generated workflow graph: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/graph.png (graph2use=flat, simple_form=True).
# 190326-19:26:23,475 workflow INFO:
# 	 Workflow rs_procwf settings: ['check', 'execution', 'logging', 'monitoring']
# 190326-19:26:23,497 workflow INFO:
# 	 Running in parallel.
# 190326-19:26:23,501 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:26:23,579 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.selectfiles" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/selectfiles".
# 190326-19:26:23,589 workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 190326-19:26:23,600 workflow INFO:
# 	 [Node] Finished "rs_procwf.selectfiles".
# 190326-19:26:25,508 workflow INFO:
# 	 [Job 0] Completed (rs_procwf.selectfiles).
# 190326-19:26:25,512 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:26:25,566 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.merge_confs" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/merge_confs".
# 190326-19:26:25,566 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.motion_summary" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/motion_summary".
# 190326-19:26:25,572 workflow INFO:
# 	 [Node] Running "merge_confs" ("nipype.interfaces.utility.wrappers.Function")
# 190326-19:26:25,577 workflow INFO:
# 	 [Node] Running "motion_summary" ("nipype.interfaces.utility.wrappers.Function")
# 190326-19:26:25,582 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/tissue_class_files/SEA-999-NB/preproc_anat_seg_0.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/templates/neonate_T2w_template_2mm_wm.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/merge_confs/_0x29a58f168427a56e8c96b70cb907dfc9_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/merge_confs/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/merge_confs/_node.pklz
# 190326-19:26:25,585 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/merge_confs/_report
# 190326-19:26:25,588 workflow DEBUG:
# 	 Removing files:
# 190326-19:26:25,592 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/merge_confs/result_merge_confs.pklz
# 190326-19:26:25,595 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/merge_confs/_report/report.rst"
# 190326-19:26:25,599 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:26:25,604 workflow INFO:
# 	 [Node] Finished "rs_procwf.merge_confs".
# 190326-19:26:25,615 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/motion_summary/_0x473a3d93956cb0a0708c181f0b32d629_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/motion_summary/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/motion_summary/_node.pklz
# 190326-19:26:25,618 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/motion_summary/_report
# 190326-19:26:25,620 workflow DEBUG:
# 	 Removing files:
# 190326-19:26:25,624 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/motion_summary/result_motion_summary.pklz
# 190326-19:26:25,627 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/motion_summary/_report/report.rst"
# 190326-19:26:25,630 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:26:25,635 workflow INFO:
# 	 [Node] Finished "rs_procwf.motion_summary".
# 190326-19:26:27,511 workflow INFO:
# 	 [Job 1] Completed (rs_procwf.motion_summary).
# 190326-19:26:27,513 workflow INFO:
# 	 [Job 2] Completed (rs_procwf.merge_confs).
# 190326-19:26:27,515 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:26:27,572 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.compcor" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor".
# 190326-19:26:27,575 workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor".
# 190326-19:26:27,577 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor
# 190326-19:26:27,580 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor
# 190326-19:26:27,583 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/_report
# 190326-19:26:27,586 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/_report/report.rst"
# 190326-19:26:27,590 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:26:27,593 workflow INFO:
# 	 [Node] Running "compcor" ("nipype.algorithms.confounds.CompCor")
# 190326-19:26:29,512 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * rs_procwf.compcor
# 190326-19:26:40,920 interface DEBUG:
# 	 Performing polynomial regression on data of shape (18797, 528)
# 190326-19:26:43,146 interface DEBUG:
# 	 Performing polynomial regression on data of shape (11106, 528)
# 190326-19:26:44,622 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/components_file.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/_0xca5ab904ccc17749bfd21948624aec73_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/_node.pklz
# 190326-19:26:44,625 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/_report
# 190326-19:26:44,628 workflow DEBUG:
# 	 Removing files:
# 190326-19:26:44,631 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/result_compcor.pklz
# 190326-19:26:44,635 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/compcor/_report/report.rst"
# 190326-19:26:44,638 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:26:44,640 workflow INFO:
# 	 [Node] Finished "rs_procwf.compcor".
# 190326-19:26:45,545 workflow INFO:
# 	 [Job 3] Completed (rs_procwf.compcor).
# 190326-19:26:45,548 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:26:45,601 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.noise_mat" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat".
# 190326-19:26:45,603 workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat".
# 190326-19:26:45,606 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat
# 190326-19:26:45,608 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat
# 190326-19:26:45,611 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/_report
# 190326-19:26:45,614 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/_report/report.rst"
# 190326-19:26:45,618 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:26:45,621 workflow INFO:
# 	 [Node] Running "noise_mat" ("nipype.interfaces.utility.wrappers.Function")
# 190326-19:26:45,657 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/noise_matrix.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/_0x016ca5816770f7fb1ada27579af17082_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/_node.pklz
# 190326-19:26:45,660 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/_report
# 190326-19:26:45,663 workflow DEBUG:
# 	 Removing files:
# 190326-19:26:45,667 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/result_noise_mat.pklz
# 190326-19:26:45,670 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/_report/report.rst"
# 190326-19:26:45,675 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:26:45,678 workflow INFO:
# 	 [Node] Finished "rs_procwf.noise_mat".
# 190326-19:26:47,550 workflow INFO:
# 	 [Job 4] Completed (rs_procwf.noise_mat).
# 190326-19:26:47,552 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:26:47,609 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.denoise" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise".
# 190326-19:26:47,612 workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise".
# 190326-19:26:47,615 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise
# 190326-19:26:47,617 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise
# 190326-19:26:47,621 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/_report
# 190326-19:26:47,624 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/_report/report.rst"
# 190326-19:26:47,629 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:26:47,633 interface DEBUG:
# 	 design_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/noise_matrix.txt
# 190326-19:26:47,635 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/preproc_func/SEA-999-NB/preproc_func.nii.gz
# 190326-19:26:47,638 interface DEBUG:
# 	 out_data_name_denoised_func.nii.gz
# 190326-19:26:47,641 interface DEBUG:
# 	 out_file_preproc_func_glm.nii.gz
# 190326-19:26:47,643 interface DEBUG:
# 	 out_res_name_denoised_residuals.nii.gz
# 190326-19:26:47,646 workflow INFO:
# 	 [Node] Running "denoise" ("nipype.interfaces.fsl.model.GLM"), a CommandLine Interface with command:
# fsl_glm -i /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/preproc_func/SEA-999-NB/preproc_func.nii.gz -d /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/noise_matrix.txt -o preproc_func_glm.nii.gz --out_data=denoised_func.nii.gz --out_res=denoised_residuals.nii.gz
# 190326-19:26:47,650 interface DEBUG:
# 	 design_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/noise_mat/noise_matrix.txt
# 190326-19:26:47,653 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/preproc_func/SEA-999-NB/preproc_func.nii.gz
# 190326-19:26:47,655 interface DEBUG:
# 	 out_data_name_denoised_func.nii.gz
# 190326-19:26:47,658 interface DEBUG:
# 	 out_file_preproc_func_glm.nii.gz
# 190326-19:26:47,661 interface DEBUG:
# 	 out_res_name_denoised_residuals.nii.gz
# 190326-19:26:49,557 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * rs_procwf.denoise
# 190326-19:33:40,151 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/denoised_func.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/_0xa4a08f9ef4056121e73886530b63b321_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/_node.pklz
# 190326-19:33:40,155 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/_report
# 190326-19:33:40,158 workflow DEBUG:
# 	 Removing files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/denoised_residuals.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/preproc_func_glm.nii.gz
# 190326-19:33:40,165 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/result_denoise.pklz
# 190326-19:33:40,168 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/_report/report.rst"
# 190326-19:33:40,185 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:33:40,190 workflow INFO:
# 	 [Node] Finished "rs_procwf.denoise".
# 190326-19:33:40,361 workflow INFO:
# 	 [Job 5] Completed (rs_procwf.denoise).
# 190326-19:33:40,367 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:33:40,423 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.bandpass" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass".
# 190326-19:33:40,430 workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass".
# 190326-19:33:40,434 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass
# 190326-19:33:40,437 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass
# 190326-19:33:40,442 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/_report
# 190326-19:33:40,444 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/_report/report.rst"
# 190326-19:33:40,450 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:33:40,454 utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz
# 190326-19:33:40,457 utils DEBUG:
# 	 Symlinking File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/denoise/denoised_func.nii.gz
# 190326-19:33:40,460 utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz
# 190326-19:33:40,462 utils DEBUG:
# 	 File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz already exists, not overwriting, copy:0
# 190326-19:33:40,465 interface DEBUG:
# 	 highpass_0.005
# 190326-19:33:40,469 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz
# 190326-19:33:40,472 interface DEBUG:
# 	 lowpass_0.1
# 190326-19:33:40,475 interface DEBUG:
# 	 out_file_denoised_func_bp
# 190326-19:33:40,478 workflow INFO:
# 	 [Node] Running "bandpass" ("nipype.interfaces.afni.preprocess.Bandpass"), a CommandLine Interface with command:
# 3dBandpass -prefix denoised_func_bp 0.005000 0.100000 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz
# 190326-19:33:40,482 interface DEBUG:
# 	 highpass_0.005
# 190326-19:33:40,485 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz
# 190326-19:33:40,488 interface DEBUG:
# 	 lowpass_0.1
# 190326-19:33:40,491 interface DEBUG:
# 	 out_file_denoised_func_bp
# 190326-19:33:42,364 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * rs_procwf.bandpass
# 190326-19:35:10,399 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func_bp+orig.BRIK;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func_bp+orig.HEAD;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/_0x6134e88a112f7cac8cbf0e3554c9d4ee_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/_node.pklz
# 190326-19:35:10,402 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/_report
# 190326-19:35:10,406 workflow DEBUG:
# 	 Removing files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func.nii.gz
# 190326-19:35:10,410 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/result_bandpass.pklz
# 190326-19:35:10,413 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/_report/report.rst"
# 190326-19:35:10,417 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:35:10,420 workflow INFO:
# 	 [Node] Finished "rs_procwf.bandpass".
# 190326-19:35:10,557 workflow INFO:
# 	 [Job 6] Completed (rs_procwf.bandpass).
# 190326-19:35:10,560 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:35:10,608 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.afni_convert" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert".
# 190326-19:35:10,611 workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert".
# 190326-19:35:10,614 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert
# 190326-19:35:10,617 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert
# 190326-19:35:10,620 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/_report
# 190326-19:35:10,623 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/_report/report.rst"
# 190326-19:35:10,627 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:35:10,630 workflow INFO:
# 	 [Node] Running "afni_convert" ("nipype.interfaces.utility.wrappers.Function")
# 190326-19:35:10,635 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/bandpass/denoised_func_bp+orig.BRIK
# 190326-19:35:10,638 interface DEBUG:
# 	 out_file_func_filtered.nii.gz
# 190326-19:35:10,767 interface INFO:
# 	 stderr 2019-03-26T19:35:10.767048:++ 3dAFNItoNIFTI: AFNI version=AFNI_17.1.01 (Apr 12 2017) [64-bit]
# 190326-19:35:12,559 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * rs_procwf.afni_convert
# 190326-19:36:02,679 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/func_filtered.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/_0x582619b0797e0296d39405db80742445_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/_node.pklz
# 190326-19:36:02,682 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/_report
# 190326-19:36:02,685 workflow DEBUG:
# 	 Removing files:
# 190326-19:36:02,688 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/result_afni_convert.pklz
# 190326-19:36:02,691 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/_report/report.rst"
# 190326-19:36:02,695 workflow DEBUG:
# 	 Aggregate: False
#
# 190326-19:36:02,698 workflow INFO:
# 	 [Node] Finished "rs_procwf.afni_convert".190326-19:36:04,704 workflow INFO:
# 	 [Job 7] Completed (rs_procwf.afni_convert).
# 190326-19:36:04,706 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:36:04,759 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.brightthresh_filt" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt".
# 190326-19:36:04,762 workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt".
# 190326-19:36:04,765 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt
# 190326-19:36:04,768 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt
# 190326-19:36:04,771 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/_report
# 190326-19:36:04,774 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/_report/report.rst"
# 190326-19:36:04,778 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:36:04,781 workflow INFO:
# 	 [Node] Running "brightthresh_filt" ("nipype.interfaces.utility.wrappers.Function")
# 190326-19:36:06,707 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * rs_procwf.brightthresh_filt
# 190326-19:37:11,323 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/_0xae71838a7c0a9f3eb3f608c8182f7b1f_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/_node.pklz
# 190326-19:37:11,345 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/_report
# 190326-19:37:11,350 workflow DEBUG:
# 	 Removing files:
# 190326-19:37:11,360 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/result_brightthresh_filt.pklz
# 190326-19:37:11,364 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/brightthresh_filt/_report/report.rst"
# 190326-19:37:11,391 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:37:11,396 workflow INFO:
# 	 [Node] Finished "rs_procwf.brightthresh_filt".
# 190326-19:37:12,810 workflow INFO:
# 	 [Job 8] Completed (rs_procwf.brightthresh_filt).
# 190326-19:37:12,813 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:37:12,918 workflow INFO:
# 	 [Node] Setting-up "rs_procwf.smooth_filt" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt".
# 190326-19:37:12,935 workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt".
# 190326-19:37:12,940 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt
# 190326-19:37:12,943 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt
# 190326-19:37:12,947 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/_report
# 190326-19:37:12,951 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/_report/report.rst"
# 190326-19:37:12,965 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:37:12,971 interface DEBUG:
# 	 brightness_threshold_48.75
# 190326-19:37:12,975 interface DEBUG:
# 	 dimension_3
# 190326-19:37:12,979 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/func_filtered.nii.gz
# 190326-19:37:12,983 interface DEBUG:
# 	 out_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz
# 190326-19:37:12,987 interface DEBUG:
# 	 use_median_1
# 190326-19:37:12,991 workflow INFO:
# 	 [Node] Running "smooth_filt" ("nipype.interfaces.fsl.preprocess.SUSAN"), a CommandLine Interface with command:
# susan /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/func_filtered.nii.gz 48.7500000000 1.6986436006 3 1 0 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz
# 190326-19:37:12,996 interface DEBUG:
# 	 brightness_threshold_48.75
# 190326-19:37:13,0 interface DEBUG:
# 	 dimension_3
# 190326-19:37:13,3 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/afni_convert/func_filtered.nii.gz
# 190326-19:37:13,7 interface DEBUG:
# 	 out_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz
# 190326-19:37:13,10 interface DEBUG:
# 	 use_median_1
# 190326-19:37:14,812 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * rs_procwf.smooth_filt
# 190326-19:46:00,109 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/_0xfe369aca427a4bb9a07451b7c3699546_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/_node.pklz
# 190326-19:46:00,113 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/_report
# 190326-19:46:00,116 workflow DEBUG:
# 	 Removing files:
# 190326-19:46:00,122 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/result_smooth_filt.pklz
# 190326-19:46:00,127 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/_report/report.rst"
# 190326-19:46:00,133 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:46:00,138 workflow INFO:
# 	 [Node] Finished "rs_procwf.smooth_filt".
# 190326-19:46:01,943 workflow INFO:
# 	 [Job 9] Completed (rs_procwf.smooth_filt).
# 190326-19:46:01,945 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-19:46:01,985 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190326-19:46:01,992 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink".
# 190326-19:46:01,995 workflow DEBUG:
# 	 [Node] Hashes: [('_outputs', [('proc_func', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz', '8b89e891349d68edcba88900c3fee754'))]), ('base_directory', '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc'), ('container', '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc'), ('parameterization', True), ('remove_dest_dir', False), ('substitutions', [('_subject_id_', '')])], 3abda85c970c7ac9af6c3785513b01be, /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_0x3abda85c970c7ac9af6c3785513b01be.json, ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_0x68f30970d362baa6c297abf8df6a8cae.json']
# 190326-19:46:01,998 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.datasink".
# 190326-19:46:02,1 workflow DEBUG:
# 	 [Node] Old/new hashes = 68f30970d362baa6c297abf8df6a8cae/3abda85c970c7ac9af6c3785513b01be
# 190326-19:46:02,10 workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * _outputs: [('proc_func', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz', '8b89e891349d68edcba88900c3fee754'))] != [['FD_out_metric_values', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_fd/FD_full.txt', 'fedda338c5baa23100b59f189d05b4ff']], ['art_plot_files', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/art/plot.preproc_func.png', '0e77e89cb59040f1057e50223a0a4a33']], ['coreg_image', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/make_coreg_img/coregistration.png', 'f89ffc0f5f4f72a05de2d4f53605386a']], ['maskcheck_image', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/make_checkmask_img/maskcheck.png', '2aa63cc04a2cdeafc26909d7323b0502']], ['motion_params', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/comb_par/motion.par', '136c5e60692a6d8cff6cd2aad290868d']], ['preproc_anat', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reg_temp/preproc_anat.nii.gz', '34baa58dc571470a70eccf5e0c7267b5']], ['preproc_func', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/applyxform/preproc_func.nii.gz', 'c0db3d9424aee6f1c4e3855b51bd8d7c']], ['tissue_class_files', [['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_seg_0.nii.gz', '853c1431cd87ccd986f1b97d87c41c02'], ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_seg_1.nii.gz', '2e8830b95c27c3d98c95405bcfd92140'], ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/segment/preproc_anat_seg_2.nii.gz', 'c9595a70c41090f59131843521aab70b']]], ['vols_to_censor', ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/art/art.preproc_func_outliers.txt', '55223cdaad9ad2b53536a90877d73149']]]
#             * substitutions: [('_subject_id_', '')] != [['_subject_id_', '']]
# 190326-19:46:02,14 utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink
# 190326-19:46:02,19 utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_report
# 190326-19:46:02,22 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_report/report.rst"
# 190326-19:46:02,29 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-19:46:02,32 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190326-19:46:02,36 interface DEBUG:
# 	 key: proc_func files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz
# 190326-19:46:02,39 interface DEBUG:
# 	 sub.str: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/_subject_id_SEA-999-NB/func_filtered_smooth.nii.gz -> /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz using '_subject_id_' -> ''
# 190326-19:46:02,42 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/_subject_id_SEA-999-NB/func_filtered_smooth.nii.gz -> /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz
# 190326-19:46:02,45 interface DEBUG:
# 	 copyfile: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz
# 190326-19:46:02,48 utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz
# 190326-19:46:02,51 utils DEBUG:
# 	 Linking File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/rs_procwf/_subject_id_SEA-999-NB/smooth_filt/func_filtered_smooth.nii.gz
# 190326-19:46:02,56 utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz
# 190326-19:46:02,59 utils DEBUG:
# 	 File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz already exists, not overwriting, copy:1
# 190326-19:46:02,63 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_proc/proc_func/SEA-999-NB/func_filtered_smooth.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_0x3abda85c970c7ac9af6c3785513b01be_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_node.pklz
# 190326-19:46:02,66 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_report
# 190326-19:46:02,69 workflow DEBUG:
# 	 Removing files:
# 190326-19:46:02,73 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/result_datasink.pklz
# 190326-19:46:02,76 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink/_report/report.rst"
# 190326-19:46:02,80 workflow DEBUG:
# 	 Aggregate: False
# 190326-19:46:02,83 workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 190326-19:46:03,943 workflow INFO:
# 	 [Job 10] Completed (prepreprocflow.datasink).
# 190326-19:46:03,945 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
