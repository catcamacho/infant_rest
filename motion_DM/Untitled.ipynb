# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import read_csv
data = read_csv('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocflow/_subject_id_0033x/realign/mapflow/_realign0/rest_reoriented_st_mcf.nii.gz.par',
                sep='  ',names=['pitch','roll','yaw','x','y','z'],engine='python')
ax = plt.gca()
data.plot(kind='line',y='pitch', ax=ax)
data.plot(kind='line',y='roll',ax=ax)
data.plot(kind='line',y='yaw',ax=ax)
data.plot(kind='line',y='x',ax=ax)
data.plot(kind='line',y='y',ax=ax)
data.plot(kind='line',y='z',ax=ax)
plt.show()
