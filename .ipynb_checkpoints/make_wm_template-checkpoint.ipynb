# %%
#import packages
from os import listdir
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, MapNode
from nipype.interfaces.fsl.preprocess import FLIRT
from nipype.interfaces.fsl.maths import MeanImage
from nipype.interfaces.fsl.utils import Merge

#set output file type for FSL to NIFTI
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI')

# Set study variables
studyhome = '/Users/catcamacho/Box/SNAP/BABIES'
#studyhome = '/share/iang/active/BABIES/BABIES_rest'
raw_data = '/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C'
output_dir = studyhome + '/processed/template'
workflow_dir = studyhome + '/workflows'
subjects_list = open(studyhome + '/misc/templatesubjects.txt').read().splitlines()

template_brain = studyhome + '/templates/T2w_BABIES_template_2mm.nii'

proc_cores = 2 # number of cores of processing for the workflows

tissue_list=['wm','gm']

# %%
# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subj']),
                     name="infosource")
infosource.iterables = ('subj', subjects_list)

# Data grabber- select gm/wm
templates = {'struct': raw_data + '/T1{subj}/T1{subj}-5/skullstripped_anat.nii',
             'seg': raw_data + '/T1{subj}/T1{subj}-5/seg.nii'}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# Datasink- where our select outputs will go
substitutions = [('_subj_', '')]
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
datasink.inputs.substitutions = substitutions

# %%
def split_tissues(in_tissues):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from nibabel import load, save, Nifti1Image
    
    segmentation_nifti = load(in_tissues)
    segmentation_data = segmentation_nifti.get_data()

    gm_data = segmentation_data
    gm_data[gm_data==150] = 1
    gm_data[gm_data==10] = 0
    gm_data[gm_data==250] = 0
    gm_nifti = Nifti1Image(gm_data, segmentation_nifti.affine)
    save(gm_nifti, 'gm.nii')
    gm_file = abspath('gm.nii')
    
    wm_data = segmentation_nifti.get_data()
    wm_data[wm_data==150] = 0
    wm_data[wm_data==10] = 0
    wm_data[wm_data==250] = 1
    wm_nifti = Nifti1Image(wm_data, segmentation_nifti.affine)
    save(wm_nifti, 'wm.nii')
    wm_file = abspath('wm.nii')

    out_tissues=[wm_file, gm_file]
    
    return(out_tissues)

split_tissues = Node(Function(input_names=['in_tissues'], 
                              output_names=['out_tissues'], 
                              function=split_tissues), 
                     name='split_tissues')

register_anat = Node(FLIRT(reference=template_brain, 
                           out_matrix_file='xform.mat'), 
                     name='register_anat')

register_seg = MapNode(FLIRT(reference=template_brain,
                             apply_xfm=True),
                       name='register_seg', 
                       iterfield=['in_file'])

# %%
templatetissue = Workflow(name='templatetissue')
templatetissue.connect([(infosource, selectfiles,[('subj','subj')]),
                        (selectfiles, register_anat,[('struct','in_file')]),
                        (selectfiles, split_tissues,[('seg','in_tissues')]),
                        (register_anat, register_seg, [('out_matrix_file','in_matrix_file')]),
                        (split_tissues, register_seg, [('out_tissues','in_file')]),
                        (register_anat, datasink, [('out_file','reg_anat')]),
                        (register_seg, datasink, [('out_file','reg_tissues')])
                       ])
templatetissue.base_dir = workflow_dir
templatetissue.write_graph(graph2use='flat')
templatetissue.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 180116-07:18:32,248 workflow INFO:
# 	 Generated workflow graph: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/graph.dot.png (graph2use=flat, simple_form=True).
# 180116-07:18:32,275 workflow INFO:
# 	 Workflow templatetissue settings: ['check', 'execution', 'logging', 'monitoring']
# 180116-07:18:32,383 workflow INFO:
# 	 Running in parallel.
# 180116-07:18:32,390 workflow INFO:
# 	 Currently running 0 tasks, and 16 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:18:32,396 workflow INFO:
# 	 Executing node templatetissue.selectfiles in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_045/selectfiles180116-07:18:32,396 workflow INFO:
# 	 Executing node templatetissue.selectfiles in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/selectfiles
#
# 180116-07:18:32,412 workflow INFO:
# 	 Running node "selectfiles" ("nipype.interfaces.io.SelectFiles").180116-07:18:32,412 workflow INFO:
# 	 Running node "selectfiles" ("nipype.interfaces.io.SelectFiles").
#
# 180116-07:18:34,397 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a15 jobid: 0
# 180116-07:18:34,399 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a14 jobid: 5
# 180116-07:18:34,402 workflow INFO:
# 	 Currently running 0 tasks, and 18 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:18:34,406 workflow INFO:
# 	 [Job finished] jobname: split_tissues.a15 jobid: 1
# 180116-07:18:34,412 workflow INFO:
# 	 Executing node templatetissue.register_anat in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_045/register_anat
# 180116-07:18:34,423 workflow INFO:
# 	 Running node "register_anat" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1045/T1045-5/skullstripped_anat.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out skullstripped_anat_flirt.nii -omat xform.mat.
# 180116-07:18:36,415 workflow INFO:
# 	 Currently running 1 tasks, and 16 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:18:36,419 workflow INFO:
# 	 Executing node templatetissue.split_tissues in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues
# 180116-07:18:36,426 workflow INFO:
# 	 Running node "split_tissues" ("nipype.interfaces.utility.wrappers.Function").
# 180116-07:18:36,896 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/wm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/wm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/gm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/gm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/_0x4723fc91848ab4a281c019aa07f5a835_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/_node.pklz
# 180116-07:18:36,899 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/_report
# 180116-07:18:36,902 workflow DEBUG:
# 	 Removing files:
# 180116-07:18:36,905 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/result_split_tissues.pklz
# 180116-07:18:36,910 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues/_report/report.rst
# 180116-07:18:36,916 workflow DEBUG:
# 	 Finished running split_tissues.a14 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/split_tissues
#
# 180116-07:18:38,421 workflow INFO:
# 	 [Job finished] jobname: split_tissues.a14 jobid: 6
# 180116-07:18:38,423 workflow INFO:
# 	 Currently running 1 tasks, and 15 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:18:38,428 workflow INFO:
# 	 Executing node templatetissue.register_anat in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat
# 180116-07:18:38,432 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:18:38,435 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_0x414446a77aafd98faea897011d4d5ec5.json
# 180116-07:18:38,438 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:18:38,441 workflow DEBUG:
# 	 Node hash: 414446a77aafd98faea897011d4d5ec5
# 180116-07:18:38,444 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_0x414446a77aafd98faea897011d4d5ec5_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:18:38,447 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat
# 180116-07:18:38,451 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_report/report.rst
# 180116-07:18:38,456 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:18:38,460 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1040/T1040-5/skullstripped_anat.nii
# 180116-07:18:38,464 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:18:38,466 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:18:38,469 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:18:38,473 workflow INFO:
# 	 Running node "register_anat" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1040/T1040-5/skullstripped_anat.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out skullstripped_anat_flirt.nii -omat xform.mat.
# 180116-07:18:38,479 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1040/T1040-5/skullstripped_anat.nii
# 180116-07:18:38,482 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:18:38,484 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:18:38,487 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:18:40,431 workflow INFO:
# 	 Currently running 2 tasks, and 14 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 0/2
# 180116-07:19:26,528 workflow INFO:
# 	 [Job finished] jobname: register_anat.a15 jobid: 2
# 180116-07:19:26,531 workflow INFO:
# 	 Currently running 1 tasks, and 15 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:19:26,543 workflow INFO:
# 	 Executing node templatetissue.selectfiles in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/selectfiles
# 180116-07:19:26,549 workflow INFO:
# 	 Running node "selectfiles" ("nipype.interfaces.io.SelectFiles").
# 180116-07:19:28,49 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/skullstripped_anat_flirt.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/skullstripped_anat_flirt.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/xform.hdr;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/xform.img;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/xform.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_0x414446a77aafd98faea897011d4d5ec5_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/command.txt;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_node.pklz
# 180116-07:19:28,52 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_report
# 180116-07:19:28,56 workflow DEBUG:
# 	 Removing files:
# 180116-07:19:28,61 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/result_register_anat.pklz
# 180116-07:19:28,64 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat/_report/report.rst
# 180116-07:19:28,70 workflow DEBUG:
# 	 Finished running register_anat.a14 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_040/register_anat
#
# 180116-07:19:28,548 workflow INFO:
# 	 [Job finished] jobname: register_anat.a14 jobid: 7
# 180116-07:19:28,550 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a13 jobid: 10
# 180116-07:19:28,553 workflow INFO:
# 	 Currently running 0 tasks, and 18 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:19:28,565 workflow INFO:
# 	 Executing node templatetissue.split_tissues in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues
# 180116-07:19:28,567 workflow INFO:
# 	 Executing node templatetissue.register_anat in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat
# 180116-07:19:28,571 workflow DEBUG:
# 	 Found hashfiles: []180116-07:19:28,572 workflow INFO:
# 	 Running node "split_tissues" ("nipype.interfaces.utility.wrappers.Function").
#
# 180116-07:19:28,574 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_0x9b5c1fa75de5aac809c6495d05072b74.json
# 180116-07:19:28,577 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:19:28,580 workflow DEBUG:
# 	 Node hash: 9b5c1fa75de5aac809c6495d05072b74
# 180116-07:19:28,582 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_0x9b5c1fa75de5aac809c6495d05072b74_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:19:28,585 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat
# 180116-07:19:28,590 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_report/report.rst
# 180116-07:19:28,597 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:19:28,603 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1039/T1039-5/skullstripped_anat.nii
# 180116-07:19:28,606 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:19:28,610 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:19:28,613 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:19:28,617 workflow INFO:
# 	 Running node "register_anat" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1039/T1039-5/skullstripped_anat.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out skullstripped_anat_flirt.nii -omat xform.mat.
# 180116-07:19:28,622 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1039/T1039-5/skullstripped_anat.nii
# 180116-07:19:28,626 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:19:28,633 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:19:28,637 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:19:29,175 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/wm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/wm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/gm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/gm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/_0x73141bcb061a6f978373f6c8f584d8a2_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/_node.pklz
# 180116-07:19:29,179 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/_report
# 180116-07:19:29,182 workflow DEBUG:
# 	 Removing files:
# 180116-07:19:29,186 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/result_split_tissues.pklz
# 180116-07:19:29,190 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues/_report/report.rst
# 180116-07:19:29,195 workflow DEBUG:
# 	 Finished running split_tissues.a13 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/split_tissues
#
# 180116-07:19:30,571 workflow INFO:
# 	 [Job finished] jobname: split_tissues.a13 jobid: 11
# 180116-07:19:30,574 workflow INFO:
# 	 Currently running 1 tasks, and 17 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:19:30,577 workflow INFO:
# 	 Executing node templatetissue.selectfiles in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles
# 180116-07:19:30,580 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:19:30,584 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_0xf1e215eab3dca14e3dd926dff6c9694c.json
# 180116-07:19:30,587 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 180116-07:19:30,590 workflow DEBUG:
# 	 Node hash: f1e215eab3dca14e3dd926dff6c9694c
# 180116-07:19:30,594 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_0xf1e215eab3dca14e3dd926dff6c9694c_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:19:30,598 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles
# 180116-07:19:30,603 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_report/report.rst
# 180116-07:19:30,608 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:19:30,612 workflow INFO:
# 	 Running node "selectfiles" ("nipype.interfaces.io.SelectFiles").
# 180116-07:19:30,619 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1036/T1036-5/seg.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1036/T1036-5/seg.mat;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1036/T1036-5/skullstripped_anat.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1036/T1036-5/skullstripped_anat.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_0xf1e215eab3dca14e3dd926dff6c9694c_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_node.pklz
# 180116-07:19:30,622 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_report
# 180116-07:19:30,626 workflow DEBUG:
# 	 Removing files:
# 180116-07:19:30,632 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/result_selectfiles.pklz
# 180116-07:19:30,641 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles/_report/report.rst
# 180116-07:19:30,646 workflow DEBUG:
# 	 Finished running selectfiles.a12 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/selectfiles
#
# 180116-07:19:32,578 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a12 jobid: 15
# 180116-07:19:32,580 workflow INFO:
# 	 Currently running 1 tasks, and 18 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:19:32,583 workflow INFO:
# 	 Executing node templatetissue.split_tissues in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues
# 180116-07:19:32,587 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:19:32,590 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_0xac4782764246651a5df36b2dced6d49e.json
# 180116-07:19:32,594 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:19:32,597 workflow DEBUG:
# 	 Node hash: ac4782764246651a5df36b2dced6d49e
# 180116-07:19:32,601 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_0xac4782764246651a5df36b2dced6d49e_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:19:32,605 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues
# 180116-07:19:32,609 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_report/report.rst
# 180116-07:19:32,614 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:19:32,618 workflow INFO:
# 	 Running node "split_tissues" ("nipype.interfaces.utility.wrappers.Function").
# 180116-07:19:33,100 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/wm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/wm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/gm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/gm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_0xac4782764246651a5df36b2dced6d49e_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_node.pklz
# 180116-07:19:33,103 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_report
# 180116-07:19:33,106 workflow DEBUG:
# 	 Removing files:
# 180116-07:19:33,111 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/result_split_tissues.pklz
# 180116-07:19:33,115 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues/_report/report.rst
# 180116-07:19:33,121 workflow DEBUG:
# 	 Finished running split_tissues.a12 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/split_tissues
#
# 180116-07:19:34,586 workflow INFO:
# 	 [Job finished] jobname: split_tissues.a12 jobid: 16
# 180116-07:19:34,589 workflow INFO:
# 	 Currently running 1 tasks, and 17 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:19:34,593 workflow INFO:
# 	 Executing node templatetissue.register_anat in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat
# 180116-07:19:34,598 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:19:34,601 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_0x28599a95ca161d31da6d45e6e9d1c8fc.json
# 180116-07:19:34,605 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:19:34,609 workflow DEBUG:
# 	 Node hash: 28599a95ca161d31da6d45e6e9d1c8fc
# 180116-07:19:34,613 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_0x28599a95ca161d31da6d45e6e9d1c8fc_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:19:34,616 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat
# 180116-07:19:34,620 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_report/report.rst
# 180116-07:19:34,626 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:19:34,630 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1036/T1036-5/skullstripped_anat.nii
# 180116-07:19:34,633 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:19:34,637 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:19:34,641 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:19:34,645 workflow INFO:
# 	 Running node "register_anat" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1036/T1036-5/skullstripped_anat.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out skullstripped_anat_flirt.nii -omat xform.mat.
# 180116-07:19:34,650 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1036/T1036-5/skullstripped_anat.nii
# 180116-07:19:34,653 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:19:34,657 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:19:34,660 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:19:36,599 workflow INFO:
# 	 Currently running 2 tasks, and 16 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 0/2
# 180116-07:20:18,489 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/skullstripped_anat_flirt.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/skullstripped_anat_flirt.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/xform.hdr;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/xform.img;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/xform.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_0x9b5c1fa75de5aac809c6495d05072b74_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/command.txt;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_node.pklz
# 180116-07:20:18,492 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_report
# 180116-07:20:18,496 workflow DEBUG:
# 	 Removing files:
# 180116-07:20:18,502 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/result_register_anat.pklz
# 180116-07:20:18,506 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat/_report/report.rst
# 180116-07:20:18,511 workflow DEBUG:
# 	 Finished running register_anat.a13 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_039/register_anat
#
# 180116-07:20:18,691 workflow INFO:
# 	 [Job finished] jobname: register_anat.a13 jobid: 12
# 180116-07:20:18,693 workflow INFO:
# 	 Currently running 1 tasks, and 17 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:20:18,705 workflow INFO:
# 	 Executing node templatetissue.selectfiles in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles
# 180116-07:20:18,710 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:20:18,713 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_0x536474fcc9c2e2141a9a133ad1331858.json
# 180116-07:20:18,718 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 180116-07:20:18,721 workflow DEBUG:
# 	 Node hash: 536474fcc9c2e2141a9a133ad1331858
# 180116-07:20:18,725 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_0x536474fcc9c2e2141a9a133ad1331858_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:20:18,729 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles
# 180116-07:20:18,734 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_report/report.rst
# 180116-07:20:18,740 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:20:18,744 workflow INFO:
# 	 Running node "selectfiles" ("nipype.interfaces.io.SelectFiles").
# 180116-07:20:18,752 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1035/T1035-5/seg.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1035/T1035-5/seg.mat;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1035/T1035-5/skullstripped_anat.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1035/T1035-5/skullstripped_anat.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_0x536474fcc9c2e2141a9a133ad1331858_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_node.pklz
# 180116-07:20:18,755 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_report
# 180116-07:20:18,759 workflow DEBUG:
# 	 Removing files:
# 180116-07:20:18,763 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/result_selectfiles.pklz
# 180116-07:20:18,766 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles/_report/report.rst
# 180116-07:20:18,771 workflow DEBUG:
# 	 Finished running selectfiles.a11 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/selectfiles
#
# 180116-07:20:20,706 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a11 jobid: 20
# 180116-07:20:20,708 workflow INFO:
# 	 Currently running 1 tasks, and 19 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:20:20,712 workflow INFO:
# 	 Executing node templatetissue.split_tissues in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues
# 180116-07:20:20,716 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:20:20,719 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_0x85945b0fcaafa52cb6aebe0469ae42d9.json
# 180116-07:20:20,721 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:20:20,724 workflow DEBUG:
# 	 Node hash: 85945b0fcaafa52cb6aebe0469ae42d9
# 180116-07:20:20,728 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_0x85945b0fcaafa52cb6aebe0469ae42d9_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:20:20,731 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues
# 180116-07:20:20,735 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_report/report.rst
# 180116-07:20:20,741 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:20:20,744 workflow INFO:
# 	 Running node "split_tissues" ("nipype.interfaces.utility.wrappers.Function").
# 180116-07:20:21,235 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/wm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/wm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/gm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/gm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_0x85945b0fcaafa52cb6aebe0469ae42d9_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_node.pklz
# 180116-07:20:21,239 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_report
# 180116-07:20:21,243 workflow DEBUG:
# 	 Removing files:
# 180116-07:20:21,248 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/result_split_tissues.pklz
# 180116-07:20:21,251 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues/_report/report.rst
# 180116-07:20:21,256 workflow DEBUG:
# 	 Finished running split_tissues.a11 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/split_tissues
#
# 180116-07:20:22,716 workflow INFO:
# 	 [Job finished] jobname: split_tissues.a11 jobid: 21
# 180116-07:20:22,718 workflow INFO:
# 	 Currently running 1 tasks, and 18 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:20:22,721 workflow INFO:
# 	 Executing node templatetissue.register_anat in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat
# 180116-07:20:22,726 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:20:22,730 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_0x8e545c1a87a9d3727e8a918eaf21b596.json
# 180116-07:20:22,733 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:20:22,736 workflow DEBUG:
# 	 Node hash: 8e545c1a87a9d3727e8a918eaf21b596
# 180116-07:20:22,740 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_0x8e545c1a87a9d3727e8a918eaf21b596_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:20:22,743 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat
# 180116-07:20:22,747 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_report/report.rst
# 180116-07:20:22,758 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:20:22,762 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1035/T1035-5/skullstripped_anat.nii
# 180116-07:20:22,766 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:20:22,769 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:20:22,772 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:20:22,780 workflow INFO:
# 	 Running node "register_anat" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1035/T1035-5/skullstripped_anat.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out skullstripped_anat_flirt.nii -omat xform.mat.
# 180116-07:20:22,787 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1035/T1035-5/skullstripped_anat.nii
# 180116-07:20:22,792 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:20:22,795 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:20:22,800 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:20:24,725 workflow INFO:
# 	 Currently running 2 tasks, and 17 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 0/2
# 180116-07:20:25,428 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/skullstripped_anat_flirt.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/skullstripped_anat_flirt.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/xform.hdr;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/xform.img;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/xform.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_0x28599a95ca161d31da6d45e6e9d1c8fc_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/command.txt;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_node.pklz
# 180116-07:20:25,433 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_report
# 180116-07:20:25,436 workflow DEBUG:
# 	 Removing files:
# 180116-07:20:25,442 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/result_register_anat.pklz
# 180116-07:20:25,447 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat/_report/report.rst
# 180116-07:20:25,454 workflow DEBUG:
# 	 Finished running register_anat.a12 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_036/register_anat
#
# 180116-07:20:26,729 workflow INFO:
# 	 [Job finished] jobname: register_anat.a12 jobid: 17
# 180116-07:20:26,732 workflow INFO:
# 	 Currently running 1 tasks, and 18 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:20:26,743 workflow INFO:
# 	 Executing node templatetissue.selectfiles in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles
# 180116-07:20:26,748 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:20:26,751 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_0x744be7ca2e7ce9a804590a4d293b88ac.json
# 180116-07:20:26,754 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 180116-07:20:26,757 workflow DEBUG:
# 	 Node hash: 744be7ca2e7ce9a804590a4d293b88ac
# 180116-07:20:26,760 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_0x744be7ca2e7ce9a804590a4d293b88ac_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:20:26,766 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles
# 180116-07:20:26,771 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_report/report.rst
# 180116-07:20:26,778 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:20:26,785 workflow INFO:
# 	 Running node "selectfiles" ("nipype.interfaces.io.SelectFiles").
# 180116-07:20:26,793 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1033x/T1033x-5/seg.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1033x/T1033x-5/seg.mat;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1033x/T1033x-5/skullstripped_anat.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1033x/T1033x-5/skullstripped_anat.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_0x744be7ca2e7ce9a804590a4d293b88ac_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_node.pklz
# 180116-07:20:26,798 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_report
# 180116-07:20:26,802 workflow DEBUG:
# 	 Removing files:
# 180116-07:20:26,807 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/result_selectfiles.pklz
# 180116-07:20:26,810 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles/_report/report.rst
# 180116-07:20:26,815 workflow DEBUG:
# 	 Finished running selectfiles.a10 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/selectfiles
#
# 180116-07:20:28,748 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a10 jobid: 25
# 180116-07:20:28,752 workflow INFO:
# 	 Currently running 1 tasks, and 20 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:20:28,756 workflow INFO:
# 	 Executing node templatetissue.split_tissues in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues
# 180116-07:20:28,760 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:20:28,763 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_0x627e0e14d8ebee6624834d6a21ba9bbd.json
# 180116-07:20:28,767 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:20:28,770 workflow DEBUG:
# 	 Node hash: 627e0e14d8ebee6624834d6a21ba9bbd
# 180116-07:20:28,774 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_0x627e0e14d8ebee6624834d6a21ba9bbd_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:20:28,777 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues
# 180116-07:20:28,781 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_report/report.rst
# 180116-07:20:28,787 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:20:28,791 workflow INFO:
# 	 Running node "split_tissues" ("nipype.interfaces.utility.wrappers.Function").
# 180116-07:20:29,307 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/wm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/wm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/gm.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/gm.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_0x627e0e14d8ebee6624834d6a21ba9bbd_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_node.pklz
# 180116-07:20:29,310 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_report
# 180116-07:20:29,313 workflow DEBUG:
# 	 Removing files:
# 180116-07:20:29,318 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/result_split_tissues.pklz
# 180116-07:20:29,321 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues/_report/report.rst
# 180116-07:20:29,326 workflow DEBUG:
# 	 Finished running split_tissues.a10 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/split_tissues
#
# 180116-07:20:30,757 workflow INFO:
# 	 [Job finished] jobname: split_tissues.a10 jobid: 26
# 180116-07:20:30,759 workflow INFO:
# 	 Currently running 1 tasks, and 19 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:20:30,762 workflow INFO:
# 	 Executing node templatetissue.register_anat in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/register_anat
# 180116-07:20:30,766 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:20:30,769 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/register_anat/_0x535b54b8042cf554f93f225962f0887f.json
# 180116-07:20:30,773 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 180116-07:20:30,776 workflow DEBUG:
# 	 Node hash: 535b54b8042cf554f93f225962f0887f
# 180116-07:20:30,779 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/register_anat/_0x535b54b8042cf554f93f225962f0887f_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:20:30,783 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/register_anat
# 180116-07:20:30,787 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_033x/register_anat/_report/report.rst
# 180116-07:20:30,793 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:20:30,797 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1033x/T1033x-5/skullstripped_anat.nii
# 180116-07:20:30,801 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:20:30,803 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:20:30,807 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:20:30,810 workflow INFO:
# 	 Running node "register_anat" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1033x/T1033x-5/skullstripped_anat.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out skullstripped_anat_flirt.nii -omat xform.mat.
# 180116-07:20:30,816 interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1033x/T1033x-5/skullstripped_anat.nii
# 180116-07:20:30,819 interface DEBUG:
# 	 out_file_skullstripped_anat_flirt.nii
# 180116-07:20:30,823 interface DEBUG:
# 	 out_matrix_file_xform.mat
# 180116-07:20:30,827 interface DEBUG:
# 	 reference_/Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii
# 180116-07:20:32,766 workflow INFO:
# 	 Currently running 2 tasks, and 18 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 0/2
# 180116-07:21:16,968 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/skullstripped_anat_flirt.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/skullstripped_anat_flirt.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/xform.hdr;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/xform.img;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/xform.nii;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/xform.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_0x8e545c1a87a9d3727e8a918eaf21b596_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/command.txt;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_node.pklz
# 180116-07:21:16,971 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_report
# 180116-07:21:16,974 workflow DEBUG:
# 	 Removing files:
# 180116-07:21:16,979 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/result_register_anat.pklz
# 180116-07:21:16,983 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat/_report/report.rst
# 180116-07:21:16,987 workflow DEBUG:
# 	 Finished running register_anat.a11 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_035/register_anat
#
# 180116-07:21:18,857 workflow INFO:
# 	 [Job finished] jobname: register_anat.a11 jobid: 22
# 180116-07:21:18,860 workflow INFO:
# 	 Currently running 1 tasks, and 19 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:21:18,871 workflow INFO:
# 	 Executing node templatetissue.selectfiles in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles
# 180116-07:21:18,875 workflow DEBUG:
# 	 Found hashfiles: []
# 180116-07:21:18,878 workflow DEBUG:
# 	 Final hashfile: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_0xf852574e040eda77189e4e9b6682bea2.json
# 180116-07:21:18,882 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 180116-07:21:18,885 workflow DEBUG:
# 	 Node hash: f852574e040eda77189e4e9b6682bea2
# 180116-07:21:18,889 workflow DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_0xf852574e040eda77189e4e9b6682bea2_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 180116-07:21:18,892 workflow DEBUG:
# 	 Creating /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles
# 180116-07:21:18,897 workflow DEBUG:
# 	 writing pre-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_report/report.rst
# 180116-07:21:18,904 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180116-07:21:18,908 workflow INFO:
# 	 Running node "selectfiles" ("nipype.interfaces.io.SelectFiles").
# 180116-07:21:18,915 workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1032/T1032-5/seg.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1032/T1032-5/seg.mat;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1032/T1032-5/skullstripped_anat.nii;/Users/catcamacho/Box/SNAP/BABIES/seg_temp/BABIES_C/T1032/T1032-5/skullstripped_anat.mat;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_0xf852574e040eda77189e4e9b6682bea2_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_node.pklz
# 180116-07:21:18,918 workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_report
# 180116-07:21:18,922 workflow DEBUG:
# 	 Removing files:
# 180116-07:21:18,927 workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/result_selectfiles.pklz
# 180116-07:21:18,931 workflow DEBUG:
# 	 writing post-exec report to /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles/_report/report.rst
# 180116-07:21:18,937 workflow DEBUG:
# 	 Finished running selectfiles.a09 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_032/selectfiles
#
# 180116-07:21:20,875 workflow INFO:
# ...
# 180116-07:28:24,608 workflow INFO:
# 	 Currently running 0 tasks, and 8 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:24,621 workflow INFO:
# 	 Executing node templatetissue.register_seg in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_023/register_seg
# 180116-07:28:24,626 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_012/register_seg/mapflow/_register_seg1
# 180116-07:28:24,631 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_023/register_seg/mapflow/_register_seg0
# 180116-07:28:24,636 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:24,644 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_023/register_seg/mapflow/_register_seg1180116-07:28:24,644 workflow INFO:
# 	 Running node "_register_seg1" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_012/split_tissues/gm.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out gm_flirt.nii -omat gm_flirt.mat -applyxfm -init /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_012/register_anat/xform.mat.
#
# 180116-07:28:24,648 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:26,624 workflow INFO:
# 	 [Job finished] jobname: register_seg.a05 jobid: 53
# 180116-07:28:26,627 workflow INFO:
# 	 Currently running 1 tasks, and 7 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:28:26,634 workflow INFO:
# 	 Executing node templatetissue.datasink in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_023/datasink
# 180116-07:28:26,643 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").
# 180116-07:28:26,648 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/_subj_023/skullstripped_anat_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/023/skullstripped_anat_flirt.nii
# 180116-07:28:26,652 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_023/_register_seg0/wm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/023/_register_seg0/wm_flirt.nii
# 180116-07:28:26,658 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_023/_register_seg1/gm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/023/_register_seg1/gm_flirt.nii
# 180116-07:28:28,635 workflow INFO:
# 	 [Job finished] jobname: _register_seg1 jobid: 105
# 180116-07:28:28,637 workflow INFO:
# 	 [Job finished] jobname: datasink.a05 jobid: 54
# 180116-07:28:28,640 workflow INFO:
# 	 Currently running 0 tasks, and 7 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:28,646 workflow INFO:
# 	 Executing node templatetissue.register_seg in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_012/register_seg180116-07:28:28,647 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/register_seg/mapflow/_register_seg0
#
# 180116-07:28:28,656 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_012/register_seg/mapflow/_register_seg0
# 180116-07:28:28,659 workflow INFO:
# 	 Running node "_register_seg0" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/split_tissues/wm.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out wm_flirt.nii -omat wm_flirt.mat -applyxfm -init /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/register_anat/xform.mat.
# 180116-07:28:28,661 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:28,667 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_012/register_seg/mapflow/_register_seg1
# 180116-07:28:28,671 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:30,651 workflow INFO:
# 	 [Job finished] jobname: register_seg.a02 jobid: 68
# 180116-07:28:30,654 workflow INFO:
# 	 [Job finished] jobname: _register_seg0 jobid: 106
# 180116-07:28:30,657 workflow INFO:
# 	 Currently running 0 tasks, and 6 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:30,663 workflow INFO:
# 	 Executing node templatetissue.datasink in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_012/datasink
# 180116-07:28:30,664 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/register_seg/mapflow/_register_seg1
# 180116-07:28:30,674 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").180116-07:28:30,675 workflow INFO:
# 	 Running node "_register_seg1" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/split_tissues/gm.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out gm_flirt.nii -omat gm_flirt.mat -applyxfm -init /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/register_anat/xform.mat.
#
# 180116-07:28:30,679 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/_subj_012/skullstripped_anat_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/012/skullstripped_anat_flirt.nii
# 180116-07:28:30,684 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_012/_register_seg0/wm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/012/_register_seg0/wm_flirt.nii
# 180116-07:28:30,691 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_012/_register_seg1/gm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/012/_register_seg1/gm_flirt.nii
# 180116-07:28:32,665 workflow INFO:
# 	 [Job finished] jobname: datasink.a02 jobid: 69
# 180116-07:28:32,666 workflow INFO:
# 	 [Job finished] jobname: _register_seg1 jobid: 107
# 180116-07:28:32,669 workflow INFO:
# 	 Currently running 0 tasks, and 5 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:32,677 workflow INFO:
# 	 Executing node templatetissue.register_seg in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/register_seg
# 180116-07:28:32,680 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/register_seg/mapflow/_register_seg0
# 180116-07:28:32,691 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/register_seg/mapflow/_register_seg0180116-07:28:32,694 workflow INFO:
# 	 Running node "_register_seg0" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/split_tissues/wm.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out wm_flirt.nii -omat wm_flirt.mat -applyxfm -init /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/register_anat/xform.mat.
#
# 180116-07:28:32,699 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:32,707 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/register_seg/mapflow/_register_seg1
# 180116-07:28:32,714 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:34,683 workflow INFO:
# 	 [Job finished] jobname: register_seg.a03 jobid: 63
# 180116-07:28:34,685 workflow INFO:
# 	 [Job finished] jobname: _register_seg0 jobid: 108
# 180116-07:28:34,687 workflow INFO:
# 	 Currently running 0 tasks, and 4 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:34,695 workflow INFO:
# 	 Executing node templatetissue.datasink in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_020/datasink180116-07:28:34,696 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/register_seg/mapflow/_register_seg1
#
# 180116-07:28:34,708 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").180116-07:28:34,709 workflow INFO:
# 	 Running node "_register_seg1" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/split_tissues/gm.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out gm_flirt.nii -omat gm_flirt.mat -applyxfm -init /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/register_anat/xform.mat.
#
# 180116-07:28:34,713 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/_subj_020/skullstripped_anat_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/020/skullstripped_anat_flirt.nii
# 180116-07:28:34,717 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_020/_register_seg0/wm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/020/_register_seg0/wm_flirt.nii
# 180116-07:28:34,723 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_020/_register_seg1/gm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/020/_register_seg1/gm_flirt.nii
# 180116-07:28:36,702 workflow INFO:
# 	 [Job finished] jobname: datasink.a03 jobid: 64
# 180116-07:28:36,708 workflow INFO:
# 	 Currently running 1 tasks, and 2 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:28:36,718 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/register_seg/mapflow/_register_seg0
# 180116-07:28:36,733 workflow INFO:
# 	 Running node "_register_seg0" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/split_tissues/wm.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out wm_flirt.nii -omat wm_flirt.mat -applyxfm -init /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/register_anat/xform.mat.
# 180116-07:28:38,715 workflow INFO:
# 	 [Job finished] jobname: _register_seg1 jobid: 109
# 180116-07:28:38,717 workflow INFO:
# 	 Currently running 1 tasks, and 2 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2
# 180116-07:28:38,724 workflow INFO:
# 	 Executing node templatetissue.register_seg in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/register_seg
# 180116-07:28:38,734 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/register_seg/mapflow/_register_seg0
# 180116-07:28:38,738 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:38,744 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/register_seg/mapflow/_register_seg1
# 180116-07:28:38,748 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:40,725 workflow INFO:
# 	 [Job finished] jobname: _register_seg0 jobid: 110
# 180116-07:28:40,726 workflow INFO:
# 	 [Job finished] jobname: register_seg.a00 jobid: 78
# 180116-07:28:40,729 workflow INFO:
# 	 Currently running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:40,736 workflow INFO:
# 	 Executing node templatetissue.datasink in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_002x/datasink180116-07:28:40,737 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/register_seg/mapflow/_register_seg1
#
# 180116-07:28:40,748 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").180116-07:28:40,748 workflow INFO:
# 	 Running node "_register_seg1" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/split_tissues/gm.nii -ref /Users/catcamacho/Box/SNAP/BABIES/templates/T2w_BABIES_template_2mm.nii -out gm_flirt.nii -omat gm_flirt.mat -applyxfm -init /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/register_anat/xform.mat.
#
# 180116-07:28:40,753 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/_subj_002x/skullstripped_anat_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/002x/skullstripped_anat_flirt.nii
# 180116-07:28:40,757 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_002x/_register_seg0/wm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/002x/_register_seg0/wm_flirt.nii
# 180116-07:28:40,762 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_002x/_register_seg1/gm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/002x/_register_seg1/gm_flirt.nii
# 180116-07:28:42,742 workflow INFO:
# 	 [Job finished] jobname: datasink.a00 jobid: 79
# 180116-07:28:42,744 workflow INFO:
# 	 [Job finished] jobname: _register_seg1 jobid: 111
# 180116-07:28:42,747 workflow INFO:
# 	 Currently running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:42,755 workflow INFO:
# 	 Executing node templatetissue.register_seg in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/register_seg
# 180116-07:28:42,766 workflow INFO:
# 	 Executing node _register_seg0 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/register_seg/mapflow/_register_seg0
# 180116-07:28:42,771 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:42,777 workflow INFO:
# 	 Executing node _register_seg1 in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/register_seg/mapflow/_register_seg1
# 180116-07:28:42,782 workflow INFO:
# 	 Collecting precomputed outputs
# 180116-07:28:44,754 workflow INFO:
# 	 [Job finished] jobname: register_seg.a01 jobid: 73
# 180116-07:28:44,757 workflow INFO:
# 	 Currently running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:44,767 workflow INFO:
# 	 Executing node templatetissue.datasink in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_subj_010/datasink
# 180116-07:28:44,781 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").
# 180116-07:28:44,787 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/_subj_010/skullstripped_anat_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_anat/010/skullstripped_anat_flirt.nii
# 180116-07:28:44,794 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_010/_register_seg0/wm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/010/_register_seg0/wm_flirt.nii
# 180116-07:28:44,802 interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/_subj_010/_register_seg1/gm_flirt.nii -> /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/010/_register_seg1/gm_flirt.nii
# 180116-07:28:46,766 workflow INFO:
# 	 [Job finished] jobname: datasink.a01 jobid: 74
# 180116-07:28:46,769 workflow INFO:
# 	 Currently running 0 tasks, and 0 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2

# %%
tissueinfo = Node(IdentityInterface(fields=['tissue']),
                     name='tissueinfo')
tissueinfo.iterables = ('tissue', tissue_list)

select_tissue = Node(DataGrabber(infields=['tissue'], 
                                 base_directory=output_dir, 
                                 sort_filelist=True,
                                 template=output_dir+'/*/*/*/%s*.nii',
                                 field_template={'tissue_data':output_dir +'/*/*/*/%s*.nii'},
                                 template_args = dict(tissue_data=[['tissue']])),
                     name='select_tissue')

# %%
merge_image = Node(Merge(dimension='t'), 
                   name='merge_image')

average_image = Node(MeanImage(), 
                     name='average_image')

# %%
group_tissue = Workflow(name='group_tissue')
group_tissue.connect([(tissueinfo, select_tissue, [('tissue','tissue')]),
                      (select_tissue, merge_image, [('tissue_data','in_files')]),
                      (merge_image, average_image, [('merged_file','in_file')]),
                      (average_image, datasink, [('out_file','average_tissue')])
                     ])
group_tissue.base_dir = workflow_dir
group_tissue.write_graph(graph2use='flat')
group_tissue.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 180116-07:28:49,173 workflow INFO:
# 	 Generated workflow graph: /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/graph.dot.png (graph2use=flat, simple_form=True).
# 180116-07:28:49,202 workflow INFO:
# 	 Workflow group_tissue settings: ['check', 'execution', 'logging', 'monitoring']
# 180116-07:28:49,227 workflow INFO:
# 	 Running in parallel.
# 180116-07:28:49,232 workflow INFO:
# 	 Currently running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:49,240 workflow INFO:
# 	 Executing node group_tissue.select_tissue in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_gm/select_tissue180116-07:28:49,242 workflow INFO:
# 	 Executing node group_tissue.select_tissue in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_wm/select_tissue
#
# 180116-07:28:49,262 workflow INFO:
# 	 Running node "select_tissue" ("nipype.interfaces.io.DataGrabber").180116-07:28:49,261 workflow INFO:
# 	 Running node "select_tissue" ("nipype.interfaces.io.DataGrabber").
#
# 180116-07:28:51,242 workflow INFO:
# 	 [Job finished] jobname: select_tissue.a1 jobid: 0
# 180116-07:28:51,245 workflow INFO:
# 	 [Job finished] jobname: select_tissue.a0 jobid: 4
# 180116-07:28:51,248 workflow INFO:
# 	 Currently running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:51,257 workflow INFO:
# 	 Executing node group_tissue.merge_image in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_gm/merge_image
# 180116-07:28:51,264 workflow INFO:
# 	 Executing node group_tissue.merge_image in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_wm/merge_image
# 180116-07:28:51,276 workflow INFO:
# 	 Running node "merge_image" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t gm_flirt_merged.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/002x/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/010/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/012/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/020/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/021/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/023/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/025/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/027/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/031/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/032/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/033x/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/035/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/036/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/039/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/040/_register_seg1/gm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/045/_register_seg1/gm_flirt.nii.
# 180116-07:28:51,282 workflow INFO:
# 	 Running node "merge_image" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t wm_flirt_merged.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/002x/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/010/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/012/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/020/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/021/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/023/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/025/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/027/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/031/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/032/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/033x/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/035/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/036/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/039/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/040/_register_seg0/wm_flirt.nii /Users/catcamacho/Box/SNAP/BABIES/processed/template/reg_tissues/045/_register_seg0/wm_flirt.nii.
# 180116-07:28:53,267 workflow INFO:
# 	 [Job finished] jobname: merge_image.a1 jobid: 1
# 180116-07:28:53,268 workflow INFO:
# 	 [Job finished] jobname: merge_image.a0 jobid: 5
# 180116-07:28:53,271 workflow INFO:
# 	 Currently running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:53,276 workflow INFO:
# 	 Executing node group_tissue.average_image in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_gm/average_image
# 180116-07:28:53,279 workflow INFO:
# 	 Executing node group_tissue.average_image in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_wm/average_image
# 180116-07:28:53,288 workflow INFO:
# 	 Running node "average_image" ("nipype.interfaces.fsl.maths.MeanImage"), a CommandLine Interface with command:
# fslmaths /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_gm/merge_image/gm_flirt_merged.nii -Tmean /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_gm/average_image/gm_flirt_merged_mean.nii.
# 180116-07:28:53,291 workflow INFO:
# 	 Running node "average_image" ("nipype.interfaces.fsl.maths.MeanImage"), a CommandLine Interface with command:
# fslmaths /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_wm/merge_image/wm_flirt_merged.nii -Tmean /Users/catcamacho/Box/SNAP/BABIES/workflows/group_tissue/_tissue_wm/average_image/wm_flirt_merged_mean.nii.
# 180116-07:28:55,281 workflow INFO:
# 	 [Job finished] jobname: average_image.a1 jobid: 2
# 180116-07:28:55,283 workflow INFO:
# 	 [Job finished] jobname: average_image.a0 jobid: 6
# 180116-07:28:55,285 workflow INFO:
# 	 Currently running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
# 180116-07:28:55,294 workflow INFO:
# 	 Executing node templatetissue.datasink in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_tissue_gm/datasink
# 180116-07:28:55,299 workflow INFO:
# 	 Executing node templatetissue.datasink in dir: /Users/catcamacho/Box/SNAP/BABIES/workflows/templatetissue/_tissue_wm/datasink
# 180116-07:28:55,306 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").
# 180116-07:28:55,312 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").
# 180116-07:28:57,299 workflow INFO:
# 	 [Job finished] jobname: datasink.a1 jobid: 3
# 180116-07:28:57,300 workflow INFO:
# 	 [Job finished] jobname: datasink.a0 jobid: 7
# 180116-07:28:57,302 workflow INFO:
# 	 Currently running 0 tasks, and 0 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2
