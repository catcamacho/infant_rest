# %% [markdown]
# # Infant resting state fMRI preprocessing
# This notebook contains preprocessing tailored to infant resting state fMRI collected in 5-8 month olds.
#
# The processing steps for the fMRI broadly include:
# * Slice-time correction
# * Rigid realignment
# * Co-registration to the sMRI (T2-weighted structural MRI)
# * Artifact detection:
#     - Motion
#     - Global intensity outliers
# * De-noising to remove:
#     - Component noise associated with white matter and CSF
#     - component noise associated with motion
#     - Censoring/scrubbing of individual volumes detected as artifacts in the previous step
#     - Frame-wise displacement
# * Bandpass filtering
# * Spatial smoothing
# * Registration to infant sample template

# %%
#import packages
from os import listdir, makedirs
from os.path import isdir
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, MapNode        # pypeline engine
from nipype.interfaces.nipy.preprocess import Trim

from nipype.algorithms.rapidart import ArtifactDetect
from nipype.interfaces.fsl.preprocess import SliceTimer, MCFLIRT, FLIRT, FAST, SUSAN
from nipype.interfaces.fsl.utils import Reorient2Std, MotionOutliers, Merge, ExtractROI
from nipype.interfaces.fsl.model import GLM, MELODIC
from nipype.interfaces.fsl.maths import ApplyMask, TemporalFilter
from nipype.interfaces.fsl.epi import ApplyTOPUP, TOPUP
from nipype.interfaces.freesurfer import Resample, Binarize, MRIConvert
from nipype.algorithms.confounds import CompCor
from nipype.interfaces.afni.preprocess import Bandpass
from nipype.interfaces.afni.utils import AFNItoNIFTI
from nipype.interfaces.ants import ApplyTransforms, Registration
from nipype.algorithms.misc import Gunzip
from pandas import DataFrame, Series

#set output file type for FSL to NIFTI
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# Set study variables
setup='Cat'
sample='newborn' #6mo or newborn
sequence='mux6'#spiral or mux6

if setup=='Lucinda':
    studyhome = '/Volumes/iang/BABIES_data/BABIES_rest'
    raw_data = studyhome + '/subjDir/all/'
    output_dir = studyhome + '/processed/preproc'
    workflow_dir = studyhome + '/workflows' 
if setup=='sherlock':
    studyhome = '/oak/stanford/groups/iang/BABIES_data/BABIES_rest'
    raw_data = studyhome + '/subjDir/all/'
    output_dir = studyhome + '/processed/preproc'
    workflow_dir = studyhome + '/workflows' 
elif setup=='Cat':
    studyhome = '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest'
    raw_data = studyhome + '/SEA_mux_raw'
    output_dir = studyhome + '/processed/SEA_proc'
    workflow_dir = studyhome + '/workflows'

if sample =='6mo':
    template_brain = studyhome + '/templates/T2w_BABIES_template_2mm.nii.gz'
    template_wm = studyhome + '/templates/BABIES_wm_mask_2mm.nii.gz'
    template_mask = studyhome + '/templates/T2w_BABIES_template_2mm_mask.nii.gz'
elif sample=='newborn':
    template_brain = studyhome + '/templates/neonate_T2w_template_2mm.nii.gz'
    template_wm = studyhome + '/templates/neonate_T2w_template_2mm_wm.nii.gz'
    template_mask = studyhome + '/templates/neonate_T2w_template_2mm_gm.nii.gz'

if sequence=='spiral':
    vols_to_trim = 4
    interleave = False
    TR = 2.5 # in seconds
elif sequence=='mux6':
    custom_timings = studyhome + '/misc/slice_timing.txt'
    vols_to_trim = 6
    TR = 0.820 # in seconds

#subjects_list = open(studyhome + '/misc/all_subjects.txt').read().splitlines()
subjects_list = ['SEA-999-NB']

proc_cores = 2 # number of cores of processing for the workflows
resampled_voxel_size = (2,2,2)
fwhm = 4 #fwhm for smoothing with SUSAN
slice_dir = 3 # 1=x, 2=y, 3=z
phase_encoding_file = studyhome + '/misc/SEA_rest_encoding.txt'

#changed to match Pendl et al 2017 (HBM)
highpass_freq = 0.005 #in Hz
lowpass_freq = 0.1 #in Hz

mask_erosion = 1
mask_dilation = 1

# %%
## File handling Nodes

# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)

# Datasink- where our select outputs will go
substitutions = [('_subject_id_', '')]
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
datasink.inputs.substitutions = substitutions

# Data grabber- select fMRI and sMRI
anat_template = {'struct': raw_data + '/{subject_id}_skullstripped_anat.nii.gz'}
select_anat = Node(SelectFiles(anat_template), name='selectanat')

# %% [markdown]
# ### Unwarping workflow

# %%
def sort_pes(pes):
    from nipype import config, logging
    from nipype.interfaces.fsl import Merge
    from os.path import abspath
    config.enable_debug_mode()
    logging.update_logging(config)
    
    print(pes)
    pe1s = []
    pe0s = []
    for file in pes:
        if 'pe0' in file:
            pe0s.append(file)
        elif 'pe1' in file:
            pe1s.append(file)
    
    pe1s = sorted(pe1s)
    pe0s = sorted(pe0s)
    
    me = Merge()
    merged_pes = []
    
    for i in range(0,len(pe1s)):
        num=pe1s[i][-12:-11]
        me.inputs.in_files = [pe1s[i],pe0s[i]]
        me.inputs.dimension='t'
        me.inputs.merged_file = 'merged_pes%s.nii.gz' % num
        me.run()
        file = abspath('merged_pes%s.nii.gz' % num)
        merged_pes.append(file)
        
    return(merged_pes)

# %%
if sequence=='mux6':
    pes_template = {'pes': raw_data + '/%s_mux_rest*.nii.gz'}
    select_pes = Node(DataGrabber(sort_filelist=True,
                                  template = raw_data + '/%s_mux_rest*.nii.gz',
                                  field_template = pes_template,
                                  base_directory=raw_data,
                                  infields=['subject_id'], 
                                  template_args={'pes':[['subject_id']]}), 
                      name='select_pes')

    func_template = {'func': raw_data + '/%s_mux_rest_pe0*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s_mux_rest_pe0*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')

    # include only the first volume of each PE volume
    trim_PEs = MapNode(ExtractROI(t_min=0, t_size=5),name='trim_PEs', 
                       iterfield=['in_file'])

    sort_pe_list = Node(Function(input_names=['pes'],
                                 output_names=['merged_pes'],
                                 function=sort_pes), 
                        name='sort_pe_list')

    topup = MapNode(TOPUP(encoding_file=phase_encoding_file), name='topup',iterfield=['in_file'])

    apply_topup = MapNode(ApplyTOPUP(in_index=[2], encoding_file=phase_encoding_file,
                                     method='jac', out_corrected='func_unwarped.nii.gz'),
                          name='apply_topup',iterfield=['in_topup_fieldcoef','in_topup_movpar','in_files'])

# %%
if sequence=='mux6':
    prepreprocflow = Workflow(name='prepreprocflow')
    prepreprocflow.connect([(infosource,select_pes, [('subject_id','subject_id')]),
                            (infosource,select_func, [('subject_id','subject_id')]),
                            (select_pes,trim_PEs, [('pes','in_file')]), 
                            (trim_PEs,sort_pe_list, [('roi_file','pes')]),
                            (sort_pe_list,topup, [('merged_pes','in_file')]),
                            (topup, apply_topup, [('out_fieldcoef','in_topup_fieldcoef'), 
                                                  ('out_movpar','in_topup_movpar')]),
                            (select_func, apply_topup, [('func','in_files')]),
                            (apply_topup, datasink, [('out_corrected','unwarped_funcs')])
                           ])

    prepreprocflow.base_dir = workflow_dir
    #prepreprocflow.write_graph(graph2use='flat')
    prepreprocflow.run('MultiProc', plugin_args={'n_procs': proc_cores, 'memory_gb':10})
# Out:
# 190326-12:02:19,119 nipype.workflow INFO:
# 	 Workflow prepreprocflow settings: ['check', 'execution', 'logging', 'monitoring']
# 190326-12:02:19,173 nipype.workflow INFO:
# 	 Running in parallel.
# 190326-12:02:19,176 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:19,260 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.select_func" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/select_func".
# 190326-12:02:19,267 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.select_pes" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/select_pes".
# 190326-12:02:19,319 nipype.workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
# 190326-12:02:19,329 nipype.workflow INFO:
# 	 [Node] Running "select_pes" ("nipype.interfaces.io.DataGrabber")
# 190326-12:02:19,364 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.select_func".
# 190326-12:02:19,377 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.select_pes".
# 190326-12:02:21,181 nipype.workflow INFO:
# 	 [Job 0] Completed (prepreprocflow.select_func).
# 190326-12:02:21,187 nipype.workflow INFO:
# 	 [Job 1] Completed (prepreprocflow.select_pes).
# 190326-12:02:21,191 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:23,182 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:23,235 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs0".
# 190326-12:02:23,242 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs1".
# 190326-12:02:23,291 nipype.workflow INFO:
# 	 [Node] Running "_trim_PEs0" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs0/SEA-999-NB_mux_rest_pe0_1_roi.nii.gz 0 5
# 190326-12:02:23,298 nipype.workflow INFO:
# 	 [Node] Running "_trim_PEs1" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_2.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs1/SEA-999-NB_mux_rest_pe0_2_roi.nii.gz 0 5
# 190326-12:02:25,185 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 0/2.
#                      Currently running:
#                        * _trim_PEs1
#                        * _trim_PEs0
# 190326-12:02:26,27 nipype.workflow INFO:
# 	 [Node] Finished "_trim_PEs0".
# 190326-12:02:26,47 nipype.workflow INFO:
# 	 [Node] Finished "_trim_PEs1".
# 190326-12:02:27,186 nipype.workflow INFO:
# 	 [Job 7] Completed (_trim_PEs0).
# 190326-12:02:27,189 nipype.workflow INFO:
# 	 [Job 8] Completed (_trim_PEs1).
# 190326-12:02:27,192 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:27,253 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs2" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs2".
# 190326-12:02:27,261 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs3" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs3".
# 190326-12:02:27,304 nipype.workflow INFO:
# 	 [Node] Running "_trim_PEs2" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe1_1.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs2/SEA-999-NB_mux_rest_pe1_1_roi.nii.gz 0 5
# 190326-12:02:27,310 nipype.workflow INFO:
# 	 [Node] Running "_trim_PEs3" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe1_2.nii.gz /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs3/SEA-999-NB_mux_rest_pe1_2_roi.nii.gz 0 5
# 190326-12:02:27,837 nipype.workflow INFO:
# 	 [Node] Finished "_trim_PEs2".
# 190326-12:02:27,842 nipype.workflow INFO:
# 	 [Node] Finished "_trim_PEs3".
# 190326-12:02:29,186 nipype.workflow INFO:
# 	 [Job 9] Completed (_trim_PEs2).
# 190326-12:02:29,187 nipype.workflow INFO:
# 	 [Job 10] Completed (_trim_PEs3).
# 190326-12:02:29,189 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:29,250 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.trim_PEs" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs".
# 190326-12:02:29,275 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs0".
# 190326-12:02:29,283 nipype.workflow INFO:
# 	 [Node] Cached "_trim_PEs0" - collecting precomputed outputs
# 190326-12:02:29,285 nipype.workflow INFO:
# 	 [Node] "_trim_PEs0" found cached.
# 190326-12:02:29,289 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs1".
# 190326-12:02:29,296 nipype.workflow INFO:
# 	 [Node] Cached "_trim_PEs1" - collecting precomputed outputs
# 190326-12:02:29,298 nipype.workflow INFO:
# 	 [Node] "_trim_PEs1" found cached.
# 190326-12:02:29,302 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs2" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs2".
# 190326-12:02:29,311 nipype.workflow INFO:
# 	 [Node] Cached "_trim_PEs2" - collecting precomputed outputs
# 190326-12:02:29,312 nipype.workflow INFO:
# 	 [Node] "_trim_PEs2" found cached.
# 190326-12:02:29,317 nipype.workflow INFO:
# 	 [Node] Setting-up "_trim_PEs3" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs3".
# 190326-12:02:29,326 nipype.workflow INFO:
# 	 [Node] Cached "_trim_PEs3" - collecting precomputed outputs
# 190326-12:02:29,328 nipype.workflow INFO:
# 	 [Node] "_trim_PEs3" found cached.
# 190326-12:02:29,347 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.trim_PEs".
# 190326-12:02:31,187 nipype.workflow INFO:
# 	 [Job 2] Completed (prepreprocflow.trim_PEs).
# 190326-12:02:31,190 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:31,264 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.sort_pe_list" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list".
# 190326-12:02:31,300 nipype.workflow INFO:
# 	 [Node] Running "sort_pe_list" ("nipype.interfaces.utility.wrappers.Function")
# ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs0/SEA-999-NB_mux_rest_pe0_1_roi.nii.gz', '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs1/SEA-999-NB_mux_rest_pe0_2_roi.nii.gz', '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs2/SEA-999-NB_mux_rest_pe1_1_roi.nii.gz', '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs3/SEA-999-NB_mux_rest_pe1_2_roi.nii.gz']
# 190326-12:02:31,312 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs2/SEA-999-NB_mux_rest_pe1_1_roi.nii.gz', '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs0/SEA-999-NB_mux_rest_pe0_1_roi.nii.gz']
# 190326-12:02:31,314 nipype.interface DEBUG:
# 	 merged_file_merged_pes1.nii.gz
# 190326-12:02:32,173 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs3/SEA-999-NB_mux_rest_pe1_2_roi.nii.gz', '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/trim_PEs/mapflow/_trim_PEs1/SEA-999-NB_mux_rest_pe0_2_roi.nii.gz']
# 190326-12:02:32,176 nipype.interface DEBUG:
# 	 merged_file_merged_pes2.nii.gz
# 190326-12:02:33,23 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes1.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes2.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/_0x66b8e22f3c1f18afaa5259d6280d3ac8_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/_node.pklz
# 190326-12:02:33,25 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/_report
# 190326-12:02:33,29 nipype.workflow DEBUG:
# 	 Removing files:
# 190326-12:02:33,36 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/result_sort_pe_list.pklz
# 190326-12:02:33,40 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/_report/report.rst"
# 190326-12:02:33,45 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190326-12:02:33,51 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.sort_pe_list".
# 190326-12:02:33,189 nipype.workflow INFO:
# 	 [Job 3] Completed (prepreprocflow.sort_pe_list).
# 190326-12:02:33,193 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:35,191 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-12:02:35,245 nipype.workflow INFO:
# 	 [Node] Setting-up "_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0".
# 190326-12:02:35,251 nipype.workflow INFO:
# 	 [Node] Setting-up "_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1".
# 190326-12:02:35,253 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1".
# 190326-12:02:35,256 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1
# 190326-12:02:35,259 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1
# 190326-12:02:35,274 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/_report
# 190326-12:02:35,282 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/_report/report.rst"
# 190326-12:02:35,291 nipype.workflow INFO:
# 	 [Node] Running "_topup0" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes1.nii.gz --out=merged_pes1_base --iout=merged_pes1_corrected.nii.gz --fout=merged_pes1_field.nii.gz --jacout=jac --logout=merged_pes1_topup.log --rbmout=xfm --dfout=warpfield
# 190326-12:02:35,306 nipype.interface DEBUG:
# 	 config_b02b0.cnf
# 190326-12:02:35,309 nipype.interface DEBUG:
# 	 encoding_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt
# 190326-12:02:35,311 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes2.nii.gz
# 190326-12:02:35,314 nipype.interface DEBUG:
# 	 merged_pes2_base_merged_pes2_base
# 190326-12:02:35,316 nipype.interface DEBUG:
# 	 out_corrected_merged_pes2_corrected.nii.gz
# 190326-12:02:35,319 nipype.interface DEBUG:
# 	 out_field_merged_pes2_field.nii.gz
# 190326-12:02:35,321 nipype.interface DEBUG:
# 	 out_jac_prefix_jac
# 190326-12:02:35,324 nipype.interface DEBUG:
# 	 out_logfile_merged_pes2_topup.log
# 190326-12:02:35,326 nipype.interface DEBUG:
# 	 out_mat_prefix_xfm
# 190326-12:02:35,328 nipype.interface DEBUG:
# 	 out_warp_prefix_warpfield
# 190326-12:02:35,334 nipype.workflow INFO:
# 	 [Node] Running "_topup1" ("nipype.interfaces.fsl.epi.TOPUP"), a CommandLine Interface with command:
# topup --config=b02b0.cnf --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes2.nii.gz --out=merged_pes2_base --iout=merged_pes2_corrected.nii.gz --fout=merged_pes2_field.nii.gz --jacout=jac --logout=merged_pes2_topup.log --rbmout=xfm --dfout=warpfield
# 190326-12:02:35,339 nipype.interface DEBUG:
# 	 config_b02b0.cnf
# 190326-12:02:35,341 nipype.interface DEBUG:
# 	 encoding_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt
# 190326-12:02:35,344 nipype.interface DEBUG:
# 	 in_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/sort_pe_list/merged_pes2.nii.gz
# 190326-12:02:35,346 nipype.interface DEBUG:
# 	 merged_pes2_base_merged_pes2_base
# 190326-12:02:35,349 nipype.interface DEBUG:
# 	 out_corrected_merged_pes2_corrected.nii.gz
# 190326-12:02:35,352 nipype.interface DEBUG:
# 	 out_field_merged_pes2_field.nii.gz
# 190326-12:02:35,355 nipype.interface DEBUG:
# 	 out_jac_prefix_jac
# 190326-12:02:35,357 nipype.interface DEBUG:
# 	 out_logfile_merged_pes2_topup.log
# 190326-12:02:35,360 nipype.interface DEBUG:
# 	 out_mat_prefix_xfm
# 190326-12:02:35,362 nipype.interface DEBUG:
# 	 out_warp_prefix_warpfield
# 190326-12:02:37,189 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 0/2.
#                      Currently running:
#                        * _topup1
#                        * _topup0
# 190326-13:11:58,853 nipype.workflow INFO:
# 	 [Node] Finished "_topup0".
# 190326-13:12:00,609 nipype.workflow INFO:
# 	 [Job 11] Completed (_topup0).
# 190326-13:12:00,611 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 1/2.
#                      Currently running:
#                        * _topup1
# 190326-13:12:26,141 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_fieldcoef.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_movpar.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/_0xece07f90a5f4e7103a4f8e633aa5b894_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/_node.pklz
# 190326-13:12:26,143 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/_report
# 190326-13:12:26,152 nipype.workflow DEBUG:
# 	 Removing files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_01.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_02.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_03.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_04.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_05.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_06.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_07.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_08.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_09.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/jac_10.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_corrected.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_field.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_topup.log;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_01.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_02.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_03.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_04.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_05.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_06.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_07.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_08.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_09.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/warpfield_10.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/xfm_01.mat;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/xfm_02.mat;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/xfm_03.mat;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/xfm_04.mat;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/xfm_05.mat;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/xfm_06.mat;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/xfm_07.mat;/Users/ca ...
# 190326-13:12:26,214 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/result__topup1.pklz
# 190326-13:12:26,218 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/_report/report.rst"
# 190326-13:12:26,227 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190326-13:12:26,235 nipype.workflow INFO:
# 	 [Node] Finished "_topup1".
# 190326-13:12:26,648 nipype.workflow INFO:
# 	 [Job 12] Completed (_topup1).
# 190326-13:12:26,652 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-13:12:26,720 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.topup" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup".
# 190326-13:12:26,746 nipype.workflow INFO:
# 	 [Node] Setting-up "_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0".
# 190326-13:12:26,759 nipype.workflow INFO:
# 	 [Node] Cached "_topup0" - collecting precomputed outputs
# 190326-13:12:26,761 nipype.workflow INFO:
# 	 [Node] "_topup0" found cached.
# 190326-13:12:26,768 nipype.workflow INFO:
# 	 [Node] Setting-up "_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1".
# 190326-13:12:26,777 nipype.workflow INFO:
# 	 [Node] Cached "_topup1" - collecting precomputed outputs
# 190326-13:12:26,779 nipype.workflow INFO:
# 	 [Node] "_topup1" found cached.
# 190326-13:12:26,795 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.topup".
# 190326-13:12:28,649 nipype.workflow INFO:
# 	 [Job 4] Completed (prepreprocflow.topup).
# 190326-13:12:28,654 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-13:12:30,653 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-13:12:30,710 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0".
# 190326-13:12:30,713 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0".
# 190326-13:12:30,715 nipype.utils DEBUG:
# 	 Removing contents of /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0
# 190326-13:12:30,718 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0
# 190326-13:12:30,718 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1".
# 190326-13:12:30,731 nipype.utils DEBUG:
# 	 Creating directory /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_report
# 190326-13:12:30,741 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_report/report.rst"
# 190326-13:12:30,769 nipype.workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 190326-13:12:30,771 nipype.utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz
# 190326-13:12:30,774 nipype.utils DEBUG:
# 	 Symlinking File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_fieldcoef.nii.gz
# 190326-13:12:30,777 nipype.utils DEBUG:
# 	 Copying File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_fieldcoef.nii.gz
# 190326-13:12:30,792 nipype.utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz
# 190326-13:12:30,796 nipype.utils DEBUG:
# 	 File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz already exists,09d6f7a54c9594d3a04cdf8385816556, copy:1
# 190326-13:12:30,800 nipype.utils DEBUG:
# 	 Copying File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_fieldcoef.nii.gz
# 190326-13:12:30,817 nipype.utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt
# 190326-13:12:30,820 nipype.utils DEBUG:
# 	 Symlinking File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_movpar.txt
# 190326-13:12:30,823 nipype.utils DEBUG:
# 	 Copying File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_movpar.txt
# 190326-13:12:30,826 nipype.workflow INFO:
# 	 [Node] Running "_apply_topup1" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_2.nii.gz --inindex=2 --topup=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1/merged_pes2_base --method=jac --out=func_unwarped.nii.gz
# 190326-13:12:30,834 nipype.utils DEBUG:
# 	 /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt
# 190326-13:12:30,838 nipype.utils DEBUG:
# 	 File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt already exists,bd29bd2de7fffc1833f749c81de50cc7, copy:1
# 190326-13:12:30,842 nipype.utils DEBUG:
# 	 Copying File: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt->/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_movpar.txt
# 190326-13:12:30,853 nipype.interface DEBUG:
# 	 encoding_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt
# 190326-13:12:30,855 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz']
# 190326-13:12:30,858 nipype.interface DEBUG:
# 	 in_index_[2]
# 190326-13:12:30,860 nipype.interface DEBUG:
# 	 method_jac
# 190326-13:12:30,862 nipype.interface DEBUG:
# 	 out_corrected_func_unwarped.nii.gz
# 190326-13:12:30,869 nipype.workflow INFO:
# 	 [Node] Running "_apply_topup0" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt --imain=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz --inindex=2 --topup=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base --method=jac --out=func_unwarped.nii.gz
# 190326-13:12:30,874 nipype.interface DEBUG:
# 	 encoding_file_/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt
# 190326-13:12:30,876 nipype.interface DEBUG:
# 	 in_files_['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz']
# 190326-13:12:30,878 nipype.interface DEBUG:
# 	 in_index_[2]
# 190326-13:12:30,880 nipype.interface DEBUG:
# 	 method_jac
# 190326-13:12:30,883 nipype.interface DEBUG:
# 	 out_corrected_func_unwarped.nii.gz
# 190326-13:12:32,655 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 0/2.
#                      Currently running:
#                        * _apply_topup1
#                        * _apply_topup0
# 190326-13:13:36,246 nipype.workflow DEBUG:
# 	 Needed files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/func_unwarped.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_0x7a9d07cf499b11fae9f8c7e9e6217612_unfinished.json;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/command.txt;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_inputs.pklz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_node.pklz
# 190326-13:13:36,248 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_report
# 190326-13:13:36,252 nipype.workflow DEBUG:
# 	 Removing files: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_fieldcoef.nii.gz;/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/merged_pes1_base_movpar.txt
# 190326-13:13:36,260 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/result__apply_topup0.pklz
# 190326-13:13:36,265 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_report/report.rst"
# 190326-13:13:36,270 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190326-13:13:36,276 nipype.workflow INFO:
# 	 [Node] Finished "_apply_topup0".
# 190326-13:13:36,672 nipype.workflow INFO:
# 	 [Node] Finished "_apply_topup1".
# 190326-13:13:36,732 nipype.workflow INFO:
# 	 [Job 13] Completed (_apply_topup0).
# 190326-13:13:36,734 nipype.workflow INFO:
# 	 [Job 14] Completed (_apply_topup1).
# 190326-13:13:36,736 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-13:13:36,798 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup".
# 190326-13:13:36,800 nipype.workflow DEBUG:
# 	 adding multipath trait: in_files
# 190326-13:13:36,802 nipype.workflow DEBUG:
# 	 adding multipath trait: in_topup_fieldcoef
# 190326-13:13:36,804 nipype.workflow DEBUG:
# 	 adding multipath trait: in_topup_movpar
# 190326-13:13:36,809 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('encoding_file', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt', '935d0dc4d45b34c51c79ec5b49413095')), ('in_files', [[('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz', '52342c2a3eb336e70ff9287ec4a98876')], [('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_2.nii.gz', 'd40ee1fd2649193b0082693edeedb986')]]), ('in_index', [2]), ('in_topup_fieldcoef', [('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_fieldcoef.nii.gz', 'a22be0c6d90ef44bd74b4f49de5d59ef'), ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_fieldcoef.nii.gz', 'b6bb9e8a63f5849428e858b8cefc37b1')]), ('in_topup_movpar', [('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_movpar.txt', '1a426c24cf67525f633c8cc3440f4ac8'), ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_movpar.txt', 'e6263f474ef3069c0f198514a7541cba')]), ('method', 'jac'), ('out_corrected', 'func_unwarped.nii.gz'), ('output_type', 'NIFTI_GZ'), ('needed_outputs', ['out_corrected'])], 23dd31d28970364ede84885e9eab6744, /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/_0x23dd31d28970364ede84885e9eab6744.json, []
# 190326-13:13:36,810 nipype.workflow DEBUG:
# 	 [Node] No hashfiles found in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup".
# 190326-13:13:36,812 nipype.workflow DEBUG:
# 	 [MapNode] Resume - hashfile=/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/_0x23dd31d28970364ede84885e9eab6744_unfinished.json
# 190326-13:13:36,819 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/_report/report.rst"
# 190326-13:13:36,834 nipype.workflow DEBUG:
# 	 setting input 0 in_topup_fieldcoef /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_fieldcoef.nii.gz
# 190326-13:13:36,836 nipype.workflow DEBUG:
# 	 setting input 0 in_topup_movpar /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_movpar.txt
# 190326-13:13:36,839 nipype.workflow DEBUG:
# 	 setting input 0 in_files ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz']
# 190326-13:13:36,843 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_topup0" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0".
# 190326-13:13:36,844 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190326-13:13:36,851 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('encoding_file', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt', '935d0dc4d45b34c51c79ec5b49413095')), ('in_files', [('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_1.nii.gz', '52342c2a3eb336e70ff9287ec4a98876')]), ('in_index', [2]), ('in_topup_fieldcoef', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_fieldcoef.nii.gz', 'a22be0c6d90ef44bd74b4f49de5d59ef')), ('in_topup_movpar', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup0/merged_pes1_base_movpar.txt', '1a426c24cf67525f633c8cc3440f4ac8')), ('method', 'jac'), ('out_corrected', 'func_unwarped.nii.gz'), ('output_type', 'NIFTI_GZ'), ('needed_outputs', ['out_corrected'])], 7a9d07cf499b11fae9f8c7e9e6217612, /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_0x7a9d07cf499b11fae9f8c7e9e6217612.json, ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup0/_0x7a9d07cf499b11fae9f8c7e9e6217612.json']
# 190326-13:13:36,852 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "_apply_topup0".
# 190326-13:13:36,854 nipype.workflow DEBUG:
# 	 Only updating node hashes or skipping execution
# 190326-13:13:36,860 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190326-13:13:36,862 nipype.workflow INFO:
# 	 [Node] Cached "_apply_topup0" - collecting precomputed outputs
# 190326-13:13:36,863 nipype.workflow INFO:
# 	 [Node] "_apply_topup0" found cached.
# 190326-13:13:36,866 nipype.workflow DEBUG:
# 	 setting input 1 in_topup_fieldcoef /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_fieldcoef.nii.gz
# 190326-13:13:36,868 nipype.workflow DEBUG:
# 	 setting input 1 in_topup_movpar /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_movpar.txt
# 190326-13:13:36,870 nipype.workflow DEBUG:
# 	 setting input 1 in_files ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_2.nii.gz']
# 190326-13:13:36,873 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_topup1" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1".
# 190326-13:13:36,874 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190326-13:13:36,881 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('encoding_file', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/misc/SEA_rest_encoding.txt', '935d0dc4d45b34c51c79ec5b49413095')), ('in_files', [('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/SEA_mux_raw/SEA-999-NB_mux_rest_pe0_2.nii.gz', 'd40ee1fd2649193b0082693edeedb986')]), ('in_index', [2]), ('in_topup_fieldcoef', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_fieldcoef.nii.gz', 'b6bb9e8a63f5849428e858b8cefc37b1')), ('in_topup_movpar', ('/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/topup/mapflow/_topup1/merged_pes2_base_movpar.txt', 'e6263f474ef3069c0f198514a7541cba')), ('method', 'jac'), ('out_corrected', 'func_unwarped.nii.gz'), ('output_type', 'NIFTI_GZ'), ('needed_outputs', ['out_corrected'])], ec33ef2f628d10e8a12c0fb805055638, /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1/_0xec33ef2f628d10e8a12c0fb805055638.json, ['/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/mapflow/_apply_topup1/_0xec33ef2f628d10e8a12c0fb805055638.json']
# 190326-13:13:36,882 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "_apply_topup1".
# 190326-13:13:36,884 nipype.workflow DEBUG:
# 	 Only updating node hashes or skipping execution
# 190326-13:13:36,889 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190326-13:13:36,890 nipype.workflow INFO:
# 	 [Node] Cached "_apply_topup1" - collecting precomputed outputs
# 190326-13:13:36,892 nipype.workflow INFO:
# 	 [Node] "_apply_topup1" found cached.
# 190326-13:13:36,899 nipype.workflow DEBUG:
# 	 saved results in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/result_apply_topup.pklz
# 190326-13:13:36,903 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/apply_topup/_report/report.rst"
# 190326-13:13:36,910 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190326-13:13:36,916 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.apply_topup".
# 190326-13:13:38,738 nipype.workflow INFO:
# 	 [Job 5] Completed (prepreprocflow.apply_topup).
# 190326-13:13:38,743 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 190326-13:13:38,795 nipype.workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.datasink" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/prepreprocflow/_subject_id_SEA-999-NB/datasink".
# 190326-13:13:38,819 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190326-13:13:38,824 nipype.interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/processed/SEA_proc/unwarped_funcs/_subject_id_SEA-999-NB/_apply_topup0/func_unwarped.nii.gz -> /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/processed/SEA_proc/unwarped_funcs/SEA-999-NB/_apply_topup0/func_unwarped.nii.gz
# 190326-13:13:39,961 nipype.interface INFO:
# 	 sub: /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/processed/SEA_proc/unwarped_funcs/_subject_id_SEA-999-NB/_apply_topup1/func_unwarped.nii.gz -> /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/processed/SEA_proc/unwarped_funcs/SEA-999-NB/_apply_topup1/func_unwarped.nii.gz
# 190326-13:13:40,739 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 1/2.
#                      Currently running:
#                        * prepreprocflow.datasink
# 190326-13:13:41,215 nipype.workflow INFO:
# 	 [Node] Finished "prepreprocflow.datasink".
# 190326-13:13:42,743 nipype.workflow INFO:
# 	 [Job 6] Completed (prepreprocflow.datasink).
# 190326-13:13:42,747 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.

# %% [markdown]
# ### Basic Preprocessing

# %%
if sequence=='spiral': 
    func_template = {'func': raw_data + '/%s/rest*.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = raw_data + '/%s/rest*.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')
    #Slice timing correction based on interleaved acquisition using FSL
    slicetime_correct = Node(SliceTimer(interleaved=interleave,
                                        slice_direction=slice_dir,
                                        time_repetition=TR,
                                        out_file='st_func.nii.gz'),
                             name='slicetime_correct')
    
elif sequence=='mux6':
    func_template = {'func': output_dir + '/unwarped_funcs/%s/*/func_unwarped.nii.gz'}
    select_func = Node(DataGrabber(sort_filelist=True,
                                   template = output_dir + '/unwarped_funcs/%s/*/func_unwarped.nii.gz',
                                   field_template = func_template,
                                   base_directory=raw_data,
                                   infields=['subject_id'], 
                                   template_args={'func':[['subject_id']]}), 
                       name='select_func')
    #Slice timing correction 
    slicetime_correct = Node(SliceTimer(time_repetition=TR,
                                        #custom_timings=custom_timings,
                                        interleaved=True,
                                        out_file='st_func.nii.gz'),
                             name='slicetime_correct')

# %%
## struct processing
# reorient to standard
reorientstruct = Node(Reorient2Std(), name='reorientstruct')

# convert files to nifti
reslice_struct = Node(MRIConvert(out_type='niigz',
                                 conform_size=2,
                                 crop_size=(128, 128, 128),
                                ),
                   name='reslice_struct')
# Segment structural scan
segment = Node(FAST(no_bias=True, 
                    segments=True, 
                    number_classes=3), 
               name='segment')

# register BOLD to anat
coregT2 = Node(FLIRT(out_matrix_file='xform.mat'),
           name='coregT2')

# apply transform to func
applyT2xform = Node(FLIRT(apply_xfm=True),
                    name='applyT2xform')

# register anat to template
reg_temp = Node(FLIRT(reference=template_brain, 
                      out_matrix_file='xform.mat',
                      out_file='preproc_anat.nii.gz'),
                name='reg_temp')

# apply transform to func
applyxform = Node(FLIRT(reference=template_brain,
                        apply_xfm=True, 
                        out_file='preproc_func.nii.gz'),
                  name='applyxform')


# register BOLD to anat
#coregT2 = Node(Registration(args='--float',
#                            collapse_output_transforms=True,
#                            initial_moving_transform_com=True,
#                            num_threads=1,
#                            output_inverse_warped_image=True,
#                            output_warped_image=True,
#                            sigma_units=['vox']*2,
#                            transforms=['Affine', 'Affine'],
#                            terminal_output='file',
#                            winsorize_lower_quantile=0.005,
#                            winsorize_upper_quantile=0.995,
#                            convergence_threshold=[1e-06],
#                            convergence_window_size=[10],
#                           metric=['Mattes', 'CC'],
#                            metric_weight=[1.0]*2,
#                            number_of_iterations=[[100, 75, 50],
#                                                  [70, 50, 20]],
#                            radius_or_number_of_bins=[32, 4],
#                            sampling_percentage=[0.25, 1],
#                            sampling_strategy=['Regular',
#                                               'None'],
#                            shrink_factors=[[4, 2, 1]]*2,
#                            smoothing_sigmas=[[2, 1, 0]]*2,
#                            transform_parameters=[(0.1,),
#                                                  (0.1,)],
#                            use_histogram_matching=False,
#                            write_composite_transform=True,
#                            dimension=3),
#               name='coregT2')

# apply transform to func
#applyT2xform = Node(ApplyTransforms(reference_image=template_brain, 
#                                    dimension=4, input_image_type=3), 
#                    name = 'applyT2xform')

# register anat to template
#reg_temp = Node(Registration(args='--float',
#                             collapse_output_transforms=True,
#                             initial_moving_transform_com=True,
#                             num_threads=1,
#                             output_inverse_warped_image=True,
#                             output_warped_image=True,
#                             sigma_units=['vox']*2,
#                             transforms=['Affine', 'SyN'],
#                             terminal_output='file',
#                             winsorize_lower_quantile=0.005,
#                             winsorize_upper_quantile=0.995,
#                             convergence_threshold=[1e-06],
#                             convergence_window_size=[10],
#                             metric=['Mattes', 'CC'],
#                             metric_weight=[1.0]*2,
#                             number_of_iterations=[[100, 75, 50],
#                                                   [70, 50, 20]],
#                             radius_or_number_of_bins=[32, 4],
#                             sampling_percentage=[0.25, 1],
#                             sampling_strategy=['Regular',
#                                                'None'],
#                             shrink_factors=[[4, 2, 1]]*2,
#                             smoothing_sigmas=[[2, 1, 0]]*2,
#                             transform_parameters=[(0.1,),
#                                                   (0.1, 3.0, 0.0)],
#                             use_histogram_matching=False,
#                             write_composite_transform=True, 
#                             fixed_image=template_brain),
#                name='reg_temp')

# apply transform to func
#applyxform = Node(ApplyTransforms(reference_image=template_brain, 
#                                  dimension=4, input_image_type=3), 
#                  name = 'applyxform')

# %%
def combine_fd(fd_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import asarray, savetxt
    
    motion = open(fd_list[0]).read().splitlines()

    if len(fd_list)>1:
        for file in fd_list[1:]:
            temp = open(file).read().splitlines()
            motion = motion+temp

    motion = asarray(motion).astype(float)
    filename = 'FD_full.txt'
    savetxt(filename,motion)
    combined_fd = abspath(filename)
    return(combined_fd)


def combine_par(par_list):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import vstack, savetxt, genfromtxt
    
    motion = genfromtxt(par_list[0], dtype=float)
    if len(par_list)>1:
        for file in par_list[1:]:
            temp = genfromtxt(par_list[0], dtype=float)
            motion=vstack((motion,temp))
    
    filename = 'motion.par'
    savetxt(filename, motion, delimiter=' ')
    combined_par = abspath(filename)
    return(combined_par)

# %%
# Data QC nodes
def create_coreg_plot(epi,anat):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    coreg_filename='coregistration.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'coregistration to anatomy')
    display.add_edges(anat)
    display.savefig(coreg_filename) 
    display.close()
    coreg_file = os.path.abspath(coreg_filename)
    
    return(coreg_file)

def check_mask_coverage(epi,brainmask):
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    from nipype.interfaces.nipy.preprocess import Trim
    
    trim = Trim()
    trim.inputs.in_file = epi
    trim.inputs.end_index = 1
    trim.inputs.out_file = 'epi_vol1.nii.gz'
    trim.run()
    epi_vol = abspath('epi_vol1.nii.gz')
    
    maskcheck_filename='maskcheck.png'
    display = plotting.plot_anat(epi_vol, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'brainmask coverage')
    display.add_contours(brainmask,levels=[.5], colors='r')
    display.savefig(maskcheck_filename)
    display.close()
    maskcheck_file = abspath(maskcheck_filename)

    return(maskcheck_file)

make_coreg_img = Node(Function(input_names=['epi','anat'],
                               output_names=['coreg_file'],
                               function=create_coreg_plot), name='make_coreg_img')

make_checkmask_img = Node(
    Function(input_names=['epi','brainmask'],
             output_names=['maskcheck_file'],
             function=check_mask_coverage), name='make_checkmask_img')
make_checkmask_img.inputs.brainmask = template_mask

# %%
## Nodes for func preprocessing
# Reorient to standard space using FSL
reorientfunc = MapNode(Reorient2Std(), name='reorientfunc', iterfield=['in_file'])

# Trim first 4 volumes
trimvols = MapNode(Trim(begin_index=vols_to_trim), name='trimvols', iterfield=['in_file'])

# Motion correction
motion_correct = MapNode(MCFLIRT(save_plots=True), name='motion_correct', iterfield=['in_file'])

# Get frame-wise displacement for each run: in_file; out_file, out_metric_plot, out_metric_values
get_FD = MapNode(MotionOutliers(metric = 'fd',
                                out_metric_values = 'FD.txt',
                                out_metric_plot = 'motionplot.png',
                                threshold=0.001,
                                no_motion_correction=False),
                    name='get_FD', iterfield=['in_file'])

# Merge rest
merge = Node(Merge(dimension='t'), name='merge')

# Merge motion (6 params)
comb_par = Node(Function(input_names=['par_list'],
                         output_names=['combined_par'],
                         function=combine_par), name='comb_par')

# Merge FD
comb_fd = Node(Function(input_names=['fd_list'],
                         output_names=['combined_fd'],
                         function=combine_fd), name='comb_fd')

# Rigid body realignment
realignment = Node(MCFLIRT(), name='realignment')

# unzip the nifti for ART
gunzip = Node(Gunzip(), name='gunzip')

# Artifact detection for scrubbing/motion assessment
art = Node(ArtifactDetect(mask_type='file',
                          parameter_source='FSL',
                          norm_threshold=0.25, #mutually exclusive with rotation and translation thresh
                          zintensity_threshold=2,
                          use_differences=[True, False], 
                          mask_file=template_mask),
           name='art')

# %%
## Preprocessing Workflow

# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                    (node2,node3,[('node2output','node3input')])
#                    ])

preprocwf = Workflow(name='preprocwf')
preprocwf.connect([(infosource,select_func,[('subject_id','subject_id')]), 
                   (select_func,reorientfunc,[('func','in_file')]),
                   (reorientfunc,trimvols,[('out_file','in_file')]),
                   (trimvols,motion_correct,[('out_file','in_file')]),
                   (trimvols,get_FD,[('out_file','in_file')]),
                   (motion_correct,merge,[('out_file','in_files')]),
                   (merge,realignment,[('merged_file','in_file')]),
                   (realignment,slicetime_correct,[('out_file','in_file')]),
                   (get_FD,comb_fd,[('out_metric_values','fd_list')]),
                   (motion_correct,comb_par,[('par_file','par_list')]),
                   (comb_par,art,[('combined_par','realignment_parameters')]),
                   (gunzip,art,[('out_file','realigned_files')]),
                   
                   (infosource,select_anat,[('subject_id','subject_id')]),
                   (select_anat,reslice_struct,[('struct','in_file')]),
                   (reslice_struct,reorientstruct,[('out_file','in_file')]),
                   (reorientstruct,make_coreg_img,[('out_file','anat')]),
                   
                   (reorientstruct,coregT2,[('out_file','reference')]),
                   (reorientstruct,applyT2xform,[('out_file','reference')]),
                   (reorientstruct,reg_temp,[('out_file','in_file')]),
                   (reg_temp,applyxform,[('out_matrix_file','in_matrix_file')]),
                   (slicetime_correct,coregT2,[('slice_time_corrected_file','in_file')]),
                   (slicetime_correct,applyT2xform,[('slice_time_corrected_file','in_file')]),
                   (coregT2,applyT2xform,[('out_matrix_file','in_matrix_file')]),
                   (applyT2xform, applyxform,[('out_file','in_file')]),
                   (applyxform,gunzip,[('out_file','in_file')]),
                   (reg_temp,segment,[('out_file','in_files')]),
                   (coregT2,make_coreg_img,[('out_file','epi')]),
                   (applyxform,make_checkmask_img,[('out_file','epi')]),
                   (applyxform, datasink, [('out_file','preproc_func')]),
                   (reg_temp, datasink,[('out_file','preproc_anat')]),
                   
                   #(reslice_struct,coregT2,[('out_file','fixed_image')]),
                   #(reslice_struct, applyT2xform,[('out_file','reference_image')]),
                   #(reslice_struct,reg_temp,[('out_file','moving_image')]),
                   #(reg_temp,applyxform,[('composite_transform','transforms')]),
                   #(slicetime_correct,coregT2,[('slice_time_corrected_file','moving_image')]),
                   #(slicetime_correct,applyT2xform,[('slice_time_corrected_file','input_image')]),
                   #(coregT2,applyT2xform,[('composite_transform','transforms')]),
                   #(applyT2xform, applyxform,[('output_image','input_image')]),
                   #(applyxform,gunzip,[('output_image','in_file')]),
                   #(reg_temp,segment,[('warped_image','in_files')]),
                   #(coregT2,make_coreg_img,[('warped_image','epi')]),
                   #(applyxform,make_checkmask_img,[('output_image','epi')]),
                   #(applyxform, datasink, [('output_image','preproc_func')]),
                   #(reg_temp, datasink,[('warped_image','preproc_anat')]),

                   (comb_fd, datasink, [('combined_fd','FD_out_metric_values')]),
                   (comb_par,datasink,[('combined_par','motion_params')]),
                   (segment,datasink,[('tissue_class_files','tissue_class_files')]),
                   (art,datasink, [('plot_files','art_plot_files')]),
                   (art,datasink, [('outlier_files','vols_to_censor')]),
                   (make_checkmask_img,datasink,[('maskcheck_file','maskcheck_image')]),
                   (make_coreg_img,datasink,[('coreg_file','coreg_image')])                   
                  ])
preprocwf.base_dir = workflow_dir
#preprocwf.write_graph(graph2use='flat')
preprocwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 190326-17:32:34,932 nipype.workflow INFO:
# 	 Workflow preprocwf settings: ['check', 'execution', 'logging', 'monitoring']
# 190326-17:32:34,996 nipype.workflow INFO:
# 	 Running in parallel.
# 190326-17:32:35,2 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:35,73 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.selectanat" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/selectanat".
# 190326-17:32:35,81 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.select_func" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/select_func".
# 190326-17:32:35,132 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 190326-17:32:35,149 nipype.workflow INFO:
# 	 [Node] Running "select_func" ("nipype.interfaces.io.DataGrabber")
# 190326-17:32:35,169 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.selectanat".
# 190326-17:32:35,190 nipype.workflow INFO:
# 	 [Node] Finished "preprocwf.select_func".
# 190326-17:32:37,6 nipype.workflow INFO:
# 	 [Job 0] Completed (preprocwf.selectanat).
# 190326-17:32:37,13 nipype.workflow INFO:
# 	 [Job 5] Completed (preprocwf.select_func).
# 190326-17:32:37,17 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:37,102 nipype.workflow INFO:
# 	 [Job 1] Cached (preprocwf.reslice_struct).
# 190326-17:32:39,8 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:39,61 nipype.workflow INFO:
# 	 [Job 2] Cached (preprocwf.reorientstruct).
# 190326-17:32:39,68 nipype.workflow INFO:
# 	 [Job 23] Cached (_reorientfunc0).
# 190326-17:32:41,12 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:41,59 nipype.workflow INFO:
# 	 [Job 3] Cached (preprocwf.reg_temp).
# 190326-17:32:41,65 nipype.workflow INFO:
# 	 [Job 24] Cached (_reorientfunc1).
# 190326-17:32:43,57 nipype.workflow INFO:
# 	 [Job 4] Cached (preprocwf.segment).
# 190326-17:32:43,64 nipype.workflow INFO:
# 	 [Job 6] Cached (preprocwf.reorientfunc).
# 190326-17:32:45,15 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:47,20 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:47,66 nipype.workflow INFO:
# 	 [Job 25] Cached (_trimvols0).
# 190326-17:32:47,71 nipype.workflow INFO:
# 	 [Job 26] Cached (_trimvols1).
# 190326-17:32:49,21 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:49,69 nipype.workflow INFO:
# 	 [Job 7] Cached (preprocwf.trimvols).
# 190326-17:32:51,23 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:53,24 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:53,70 nipype.workflow INFO:
# 	 [Job 27] Cached (_get_FD0).
# 190326-17:32:53,76 nipype.workflow INFO:
# 	 [Job 28] Cached (_get_FD1).
# 190326-17:32:55,27 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:55,73 nipype.workflow INFO:
# 	 [Job 8] Cached (preprocwf.get_FD).
# 190326-17:32:55,80 nipype.workflow INFO:
# 	 [Job 29] Cached (_motion_correct0).
# 190326-17:32:57,32 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:57,80 nipype.workflow INFO:
# 	 [Job 9] Cached (preprocwf.comb_fd).
# 190326-17:32:57,86 nipype.workflow INFO:
# 	 [Job 30] Cached (_motion_correct1).
# 190326-17:32:59,38 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:32:59,84 nipype.workflow INFO:
# 	 [Job 10] Cached (preprocwf.motion_correct).
# 190326-17:33:01,41 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:33:01,89 nipype.workflow INFO:
# 	 [Job 11] Cached (preprocwf.comb_par).
# 190326-17:33:01,97 nipype.workflow INFO:
# 	 [Job 12] Cached (preprocwf.merge).
# 190326-17:33:03,46 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:33:03,94 nipype.workflow INFO:
# 	 [Job 13] Cached (preprocwf.realignment).
# 190326-17:33:05,101 nipype.workflow INFO:
# 	 [Job 14] Cached (preprocwf.slicetime_correct).
# 190326-17:33:07,106 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocwf.coregT2" in "/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2".
# 190326-17:33:07,167 nipype.workflow INFO:
# 	 [Node] Running "coregT2" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/slicetime_correct/st_func.nii.gz -ref /Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/reorientstruct/SEA-999-NB_skullstripped_anat_out_reoriented.nii.gz -out st_func_flirt.nii.gz -omat xform.mat
# 190326-17:33:09,56 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 1/2.
#                      Currently running:
#                        * preprocwf.coregT2
# 190326-17:34:15,468 nipype.workflow WARNING:
# 	 [Node] Error on "preprocwf.coregT2" (/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2)
# 190326-17:34:17,210 nipype.workflow ERROR:
# 	 Node coregT2.a0 failed to run on host Cats-MacBook-Pro.local.
# 190326-17:34:17,213 nipype.workflow ERROR:
# 	 Saving crash info to /Users/catcamacho/Box/SNAP/BABIES/infant_rest/crash-20190326-173417-catcamacho-coregT2.a0-d637a4a6-0d5e-44de-ac93-502b90586d56.pklz
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 69, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 473, in run
#     result = self._run_interface(execute=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 557, in _run_interface
#     return self._run_command(execute)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 637, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 371, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/fsl/preprocess.py", line 666, in aggregate_outputs
#     runtime=runtime, needed_outputs=needed_outputs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 472, in aggregate_outputs
#     raise error
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 465, in aggregate_outputs
#     setattr(outputs, key, val)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/interfaces/base/traits_extension.py", line 112, in validate
#     self.info_text, value))
# traits.trait_errors.TraitError: The trait 'out_file' of a FLIRTOutputSpec instance is an existing file name, but the path  '/Users/catcamacho/Box/SNAP/BABIES/BABIES_rest/workflows/preprocwf/_subject_id_SEA-999-NB/coregT2/st_func_flirt.nii.gz' does not exist.
#
# 190326-17:34:17,223 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190326-17:34:19,199 nipype.workflow INFO:
# 	 ***********************************
# 190326-17:34:19,201 nipype.workflow ERROR:
# 	 could not run node: preprocwf.coregT2.a0
# 190326-17:34:19,203 nipype.workflow INFO:
# 	 crashfile: /Users/catcamacho/Box/SNAP/BABIES/infant_rest/crash-20190326-173417-catcamacho-coregT2.a0-d637a4a6-0d5e-44de-ac93-502b90586d56.pklz
# 190326-17:34:19,205 nipype.workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-832f138e0ba2> in <module>
#      64 preprocwf.base_dir = workflow_dir
#      65 #preprocwf.write_graph(graph2use='flat')
# ---> 66 preprocwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     597         if str2bool(self.config['execution']['create_report']):
#     598             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 599         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     600         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     601         if str2bool(self.config['execution']['write_provenance']):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     189
#     190         self._remove_node_dirs()
# --> 191         report_nodes_not_run(notrun)
#     192
#     193         # close any open resources
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nipype/pipeline/plugins/tools.py in report_nodes_not_run(notrun)
#      80                 logger.debug(subnode._id)
#      81         logger.info("***********************************")
# ---> 82         raise RuntimeError(('Workflow did not execute cleanly. '
#      83                             'Check log for details'))
#      84
#
# RuntimeError: Workflow did not execute cleanly. Check log for details

# %%
# Resting state preprocessing
# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)


# Data grabber- select fMRI and sMRI
templates = {'func': output_dir + '/preproc_func/{subject_id}/preproc_func.nii.gz',
             'csf': output_dir + '/tissue_class_files/{subject_id}/preproc_anat_seg_0.nii.gz', 
             'vols_to_censor':output_dir + '/vols_to_censor/{subject_id}/art.preproc_func_outliers.txt', 
             'motion_params':output_dir + '/FD_out_metric_values/{subject_id}/FD_full.txt',
             'wm':template_wm}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# %%
## Pull motion info for all subjects

motion_df_file = output_dir + '/motion_summary/motionSummary.csv'

if isdir(output_dir + '/motion_summary')==False:
    makedirs(output_dir + '/motion_summary')
    motion_df = DataFrame(columns=['meanFD','maxFD','NumCensoredVols','totalVolumes','secondsNotCensored','lengthsNotCensored_descendingSeconds'])
    motion_df.to_csv(motion_df_file)
    
def summarize_motion(motion_df_file, motion_file, vols_to_censor, TR):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import dirname, basename
    from numpy import asarray, mean, insert, zeros, sort
    from pandas import DataFrame, Series, read_csv
    
    motion_df = read_csv(motion_df_file, index_col=0)
    
    motion = asarray(open(motion_file).read().splitlines()).astype(float)
    censvols = asarray(open(vols_to_censor).read().splitlines()).astype(int)
    sec_not_censored = (len(motion)-len(censvols))*TR
    
    if censvols[0]>0:
        periods_not_censored = insert(censvols,0,0)
    else:
        periods_not_censored = censvols
    
    if periods_not_censored[-1]<len(motion):
        periods_not_censored = insert(periods_not_censored,len(periods_not_censored),len(motion))
    
    lengths = zeros(len(periods_not_censored)-1)
    for a in range(0,len(lengths)):
        lengths[a] = periods_not_censored[a+1] - periods_not_censored[a] - 1
    
    lengths = lengths*TR
    
    # sort lengths in descending order
    lengths = sort(lengths)[::-1]

    fp = dirname(motion_file)
    subject = basename(fp)

    motion_df.loc[subject] = [mean(motion),max(motion),len(censvols),len(motion),sec_not_censored,lengths]
    motion_df.to_csv(motion_df_file)

    return()

# Make a list of tissues for component noise removal
def combine_masks(mask1,mask2):
    from nipype.interfaces.fsl.utils import Merge
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    vols = []
    vols.append(mask1)
    vols.append(mask2)
    
    return(vols)
    
# Remove all noise (GLM with noise params)
def create_noise_matrix(vols_to_censor,motion_params,comp_noise):
    from numpy import genfromtxt, zeros,concatenate, savetxt
    from os import path

    motion = genfromtxt(motion_params, delimiter=' ', dtype=None, skip_header=0)
    comp_noise = genfromtxt(comp_noise, delimiter='\t', dtype=None, skip_header=1)
    censor_vol_list = genfromtxt(vols_to_censor, delimiter='\t', dtype=None, skip_header=0)

    c = len(censor_vol_list)
    d = len(comp_noise)
    if c > 0:
        scrubbing = zeros((d,c),dtype=int)
        for t in range(0,c):
            scrubbing[censor_vol_list[t]][t] = 1    
        noise_matrix = concatenate([motion[:,None],comp_noise,scrubbing],axis=1)
    else:
        noise_matrix = concatenate((motion[:,None],comp_noise),axis=1)

    noise_file = 'noise_matrix.txt'
    savetxt(noise_file, noise_matrix, delimiter='\t')
    noise_filepath = path.abspath(noise_file)
    
    return(noise_filepath)

def convertafni(in_file):
    from nipype.interfaces.afni.utils import AFNItoNIFTI
    from os import path
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    cvt = AFNItoNIFTI()
    cvt.inputs.in_file = in_file
    cvt.inputs.out_file = 'func_filtered.nii.gz'
    cvt.run()
    
    out_file = path.abspath('func_filtered.nii.gz')
    return(out_file)

# Brightness threshold should be 0.75 * the contrast between the median brain intensity and the background
def brightthresh(func):
    import nibabel as nib
    from numpy import median, where
    
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    func_nifti1 = nib.load(func)
    func_data = func_nifti1.get_data()
    func_data = func_data.astype(float)
    
    brain_values = where(func_data > 0)
    median_thresh = median(brain_values)
    bright_thresh = 0.75 * median_thresh
    
    return(bright_thresh)

# %%
# Denoising
merge_confs = Node(Function(input_names=['mask1','mask2'],
                            output_names=['vols'], 
                            function=combine_masks), 
                   name='merge_confs')

compcor = Node(CompCor(merge_method='none'), 
               name='compcor')

noise_mat = Node(Function(input_names=['vols_to_censor','motion_params','comp_noise'],
                          output_names=['noise_filepath'], 
                          function=create_noise_matrix), 
                 name='noise_mat')

denoise = Node(GLM(out_res_name='denoised_residuals.nii.gz', 
                   out_data_name='denoised_func.nii.gz'), 
               name='denoise')

# band pass filtering- all rates are in Hz (1/TR or samples/second)
bandpass = Node(Bandpass(highpass=highpass_freq,
                         lowpass=lowpass_freq), 
                name='bandpass')

afni_convert = Node(Function(input_names=['in_file'],
                             output_names=['out_file'],
                             function=convertafni), 
                    name='afni_convert')

# Spatial smoothing 
brightthresh_filt = Node(Function(input_names=['func'], 
                                  output_names=['bright_thresh'], 
                                  function=brightthresh), 
                         name='brightthresh_filt')    
    
smooth_filt = Node(SUSAN(fwhm=fwhm), name='smooth_filt')

motion_summary = Node(Function(input_names=['motion_df_file','motion_file','vols_to_censor','TR'], 
                               output_names=[], 
                               function=summarize_motion), 
                      name='motion_summary')
motion_summary.inputs.motion_df_file = motion_df_file
motion_summary.inputs.TR = TR

# %%
# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                       (node2,node3,[('node2output','node3input')])
#                     ])

rs_procwf = Workflow(name='rs_procwf')
rs_procwf.connect([(infosource,selectfiles,[('subject_id','subject_id')]),
                   (selectfiles,compcor,[('func','realigned_file')]),
                   (selectfiles,merge_confs,[('csf','mask1')]),
                   (selectfiles,merge_confs,[('wm','mask2')]),
                   (merge_confs,compcor,[('vols','mask_files')]),
                   (compcor,noise_mat,[('components_file','comp_noise')]),
                   (selectfiles,noise_mat,[('vols_to_censor','vols_to_censor'),
                                           ('motion_params','motion_params')]),
                   (noise_mat,denoise,[('noise_filepath','design')]),
                   (selectfiles,denoise,[('func','in_file')]),
                   (denoise,bandpass,[('out_data','in_file')]),
                   (bandpass,afni_convert,[('out_file','in_file')]),
                   (afni_convert,brightthresh_filt,[('out_file','func')]),
                   (brightthresh_filt,smooth_filt,[('bright_thresh','brightness_threshold')]),
                   (afni_convert,smooth_filt,[('out_file','in_file')]),  
                   (selectfiles, motion_summary, [('motion_params','motion_file'),
                                                  ('vols_to_censor','vols_to_censor')]),
                   
                   (smooth_filt,datasink,[('smoothed_file','proc_func')])
                   ])

rs_procwf.base_dir = workflow_dir
rs_procwf.write_graph(graph2use='flat')
rs_procwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
